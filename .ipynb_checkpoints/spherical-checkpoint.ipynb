# %%
from mpl_toolkits import mplot3d

# %% [markdown]
# # Plot sphere

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create a structured grid

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %% [markdown]
# Visualize vectors in spherical coordinates
# Vertical wind

# %% [markdown]
# Isurfaces of 3D data in spherical coordinates

# %%
fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')

theta = np.linspace(0, np.pi, 100)
phi = np.linspace(0, 2 * np.pi, 100)

# radius
r = 1

x = r * np.outer(np.cos(phi), np.sin(theta))
y = r * np.outer(np.sin(phi), np.sin(theta))
z = r * np.outer(np.ones(np.size(phi)), np.cos(theta))

ax.plot_surface(y, x, z, rstride=4, cstride=4, color='b')
ax.scatter([1.0], [1.0], [0], marker='o', color='r')

plt.show()

# %%
# Create meshgrid
X, Y = np.meshgrid(np.linspace(0, np.pi, len(afm_data)), np.linspace(0, 2 * np.pi, len(afm_data)))
