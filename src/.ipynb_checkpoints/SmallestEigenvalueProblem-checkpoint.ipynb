# %% [markdown]
# # Smallest eigenvalue problem
#
# $\newcommand{\mapcom}[5]{\begin{align*} #1 \,:\, #2& \longrightarrow #3 \\ #4& \longmapsto #5, \end{align*}}$
# $\newcommand{\Rset}{\mathbb{R}}$
# We look here at the case where we would like to find the smallest eigenvalue of a real symmetric parameterized matrix $$\mapcom{A}{\mathcal{P}\subset\Rset^p}{\Rset^{n\times n}}{\mu}{A(\mu)}$$ with eigenvalues $\lambda_1< \dots\le\lambda_n$. The parameter space $\mathcal{P}$ is considered to be an open bounder connected subset of $\Rset^p$.
# The smallest eigenvalue $\lambda_1=\lambda_1(\mu)\in\Rset$, can be determined by the study of the Rayleigh quotient as follow
# $$
# 	\lambda_1(\mu) = \min_{x\in\Rset^n} \frac{x^TA(\mu)x}{x^Tx} = \min_{x^Tx = 1} x^TA(\mu)x.
# $$
# Therefore by defining a cost function $$\mapcom{f}{S^{n-1}\times\mathcal{P}}{\Rset}{(x,\mu)}{\frac{1}{2}x^TA(\mu)x}$$ the problem is equivalent to solving the following minimization problem
# $$
# 	\lambda_1 = \min_{x \in S^{n-1}} f(x,\mu).
# $$

# %% [markdown]
# ##############################################################################################################
# ##############################################################################################################

# %% [markdown]
# ## First test case, $n=3, p=2$, smooth eigenvalues:
# We consider a mapping $A$ defined for any $\mu=(\mu_1, \mu_2)\in\Rset^2$ by
#
# $$
# A(\mu) = \begin{pmatrix} \lambda_1(\mu) & -1 & 0 \\ -1 & \lambda_2(\mu) & 1 \\ 0 & 1 & \lambda_3(\mu) \end{pmatrix},
# $$
#
# with $\lambda_1(\mu) = 1 + \exp(\frac{\mu_1 - \mu_2}{\sigma}), \lambda_2(\mu) = 2 + \exp(\frac{3\mu_1 + \mu_2}{\sigma}), \lambda_3(\mu) = 3 + \exp(\frac{\mu_1 + \mu_2}{\sigma})$, $\sigma \in\Rset$.

# %%
import autograd.numpy as np

# %%
from pymanopt.manifolds import Sphere

# Dimension of the sphere 
solutionSpaceDimension = 3

# Instantiate the unit sphere manifold
unitSphere = Sphere(solutionSpaceDimension)

# %%
from pymanopt.manifolds import Euclidean

# Dimension of the parameter space 
parameterSpaceDimension = 2

# Instantiate the parameter space 
parameterSpace = Euclidean(parameterSpaceDimension)

# %%
from pymanopt.manifolds import Product

productManifold = Product([unitSphere, parameterSpace])

# %% [markdown]
# ## Computation of  $DA(\mu)[v]$
#
# Here we give an explicit form for the differential of $A$ at $\mu\in\mathcal{P}$ along $v\in\mathcal{P}$. We have that
#
# $$
#     DA(\mu)[v] = \begin{pmatrix} \frac{v_1 - v_2}{\sigma} \exp(\frac{\mu_1 - \mu_2}{\sigma}) & & \\ & \frac{3v_1 + v_2}{\sigma} \exp(\frac{3\mu_1 + \mu_2}{\sigma}) & \\ & & \frac{v_1 + v_2}{\sigma} \exp(\frac{\mu_1 + \mu_2}{\sigma}) \end{pmatrix}
# $$

# %%
def A(mu):
    sigma = 100
    lambda0 = 1 + np.exp((mu[0] - mu[1]) / sigma)
    lambda1 = 2 + np.exp((3 * mu[0] + mu[1]) / sigma)
    lambda2 = 3 + np.exp((mu[0] + mu[1]) / sigma)
    
    return np.array([[lambda0, -1, 0], [-1, lambda1, -1], [0, -1, lambda2]])

def DA(mu,v):
    sigma = 100
    Dlambda0 = (v[0] - v[1]) / sigma * np.exp((mu[0] - mu[1]) / sigma)
    Dlambda1 = (3 * v[0] + v[1]) / sigma * np.exp((3 * mu[0] + mu[1]) / sigma)
    Dlambda2 = (v[0] + v[1]) / sigma * np.exp((mu[0] + mu[1]) / sigma)
    
    return np.array([[Dlambda0, 0, 0], [0, Dlambda1, 0], [0, 0, Dlambda2]])

# %% [markdown]
# ### Compute $D_x\operatorname{grad} f(x,\mu)$ and $D_\mu\operatorname{grad} f(x,\mu)$

# %%
# Define derivatives of gradient wrt solution/parameter

def differentialSolutionAlongV(x, mu, xi):
    return A(mu) @ xi - 2 * (x.T @ A(mu) @ xi) * x - (x.T @ A(mu) @ x) * xi

#def differentialParameterAlongV(x, mu, v):
#    return np.eye(solutionSpaceDimension)
def differentialParameterAlongV(x, mu, v):
    return (np.eye(solutionSpaceDimension) - np.outer(x, x)) @ DA(mu, v) @ x

# %% [markdown]
# ### Define cost function $f$ and instantiate optimization problem

# %%
from pymanopt.core.problem import Problem 

def cost(S):
    return np.dot(S[0], A(S[1]) @ S[0])

problem = Problem(productManifold, cost=cost)

# %% [markdown]
# ### Define initial/target parameters and initial solution to the problem

# %%
initialParameter = np.array([1, 2])
targetParameter = np.array([23., 30.])

B = A(initialParameter)
C = A(targetParameter)

w, v = np.linalg.eig(B)
wC, vC = np.linalg.eig(C)

initialSolution = v[:, np.argmin(w)]
finalSolution = vC[:, np.argmin(wC)]

# %%
from Continuation.PathAdaptiveContinuation import PathAdaptiveMultiParameterContinuation

parameterMagnitude =  0.5 * 1e-1

# Instantiate continuation object
continuation = PathAdaptiveMultiParameterContinuation(problem, 
                                                      initialSolution,
                                                      initialParameter,
                                                      targetParameter,
                                                      differentialSolutionAlongV, 
                                                      differentialParameterAlongV,
                                                      A,
                                                      parameterMagnitude)
results = continuation.Traverse()
# Out:
# ========== New continuation problem ==========
#
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+4.0505651337275708e+02	6.17408299e+01
#     2	+4.0461442536793948e+02	3.34114485e+01
#     3	+4.0443877390799287e+02	6.86742625e+00
#     4	+4.0443238396887728e+02	2.86982884e+00
#     5	+4.0443107622804303e+02	5.20560064e-01
#     6	+4.0443106291716578e+02	4.35779944e-01
#     7	+4.0443103240456389e+02	6.36899775e-02
#     8	+4.0443103186272867e+02	2.74983073e-02
#     9	+4.0443103173961424e+02	2.50592144e-03
#    10	+4.0443103173935623e+02	2.16973509e-03
#    11	+4.0443103173866871e+02	7.21147599e-04
#    12	+4.0443103173858327e+02	4.71259320e-06
#    13	+4.0443103173858327e+02	8.76679989e-06
# Terminated - min stepsize reached after 13 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.839288e+03   |grad|: 8.140890e+02
# acc TR+   k:     1     num_inner:     0     f: +1.447671e+03   |grad|: 1.162668e+03   negative curvature
# acc       k:     2     num_inner:     0     f: +9.167628e+02   |grad|: 1.495004e+02   exceeded trust region
# acc       k:     3     num_inner:     0     f: +9.123223e+02   |grad|: 1.045922e+00   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +9.123221e+02   |grad|: 2.186378e-05   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +9.123221e+02   |grad|: 1.663338e-13   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.4625344910500387e+03	1.42903586e+03
#     1	+4.6491984658071294e+02	5.92660483e+02
#     2	+4.1890078582840044e+02	2.94859731e+02
#     3	+4.0767572124992751e+02	1.40286888e+02
#     4	+4.0514524818971950e+02	6.59078536e+01
#     5	+4.0458739544726279e+02	3.08520074e+01
#     6	+4.0446520405971495e+02	1.44252885e+01
#     7	+4.0443849499060411e+02	6.74187711e+00
#     8	+4.0443266127793117e+02	3.15037394e+00
#     9	+4.0443138749319388e+02	1.47201008e+00
#    10	+4.0443110940140110e+02	6.87772443e-01
#    11	+4.0443104869230842e+02	3.21345344e-01
#    12	+4.0443103543952469e+02	1.50139902e-01
#    13	+4.0443103254648213e+02	7.01485643e-02
#    14	+4.0443103191494356e+02	3.27748542e-02
#    15	+4.0443103177708178e+02	1.53130758e-02
#    16	+4.0443103174698729e+02	7.15457680e-03
#    17	+4.0443103174041789e+02	3.34276155e-03
#    18	+4.0443103173898373e+02	1.56180502e-03
#    19	+4.0443103173867064e+02	7.29706498e-04
#    20	+4.0443103173860237e+02	3.40933445e-04
#    21	+4.0443103173858748e+02	1.59290911e-04
#    22	+4.0443103173858424e+02	7.44238933e-05
#    23	+4.0443103173858344e+02	3.47723285e-05
#    24	+4.0443103173858333e+02	1.62463259e-05
#    25	+4.0443103173858327e+02	1.06511051e-06
#    26	+4.0443103173858327e+02	1.06511051e-06
# Terminated - min stepsize reached after 27 iterations, 0.03 seconds.
#
# v_steepest = [0.98363773 0.18015774]
#
# v_trust = [-0.99227855 -0.12402938]
#
# v_cg = [0.98363773 0.18015774]
#
#
#  New perturbation : [3.59252704 6.31989385]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 0.1
#
# NextObj = 0.00018842960959997157
#
# NextGrad = 0.0423782739570912
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0002563163958628767
#
# NextGrad = 0.04833452966605506
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00036304056397429285
#
# NextGrad = 0.05643891794945905
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0005341461009098492
#
# NextGrad = 0.06742549039148611
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0008134737163174588
#
# NextGrad = 0.08226042504185016
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0012768344746818538
#
# NextGrad = 0.10221693681038159
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.00205606335879982
#
# NextGrad = 0.12897526466284237
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0033812956876471123
#
# NextGrad = 0.1647516914942995
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.005655026764610271
#
# NextGrad = 0.21245734358271262
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.00958091062047961
#
# NextGrad = 0.27587814336822913
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 1, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3451489528862957
# |gradf_0| = 0.4039745597240248
# f_1 = 1.3318238033463554
# |gradf_1| = 0.30008216224273176
# f_2 = 1.3317472875159082
# |gradf_2| = 0.236675238838541
# f_3 = 1.3256735069759513
# |gradf_3| = 0.06794823721167688
# f_4 = 1.3251135237984168
# |gradf_4| = 0.007291241503553463
# f_5 = 1.3251097207903257
# |gradf_5| = 0.0005192493491539765
# f_6 = 1.3251097003337569
# |gradf_6| = 7.563090744065828e-06
# f_7 = 1.325109700326079
# |gradf_7| = 1.4595122255428424e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+2.4000803146633436e+02	1.21985046e+02
#     2	+2.3859795965772446e+02	7.65656687e+01
#     3	+2.3792972475825547e+02	4.03827768e+01
#     4	+2.3769723723596837e+02	1.22625989e+01
#     5	+2.3767482334152800e+02	2.80649193e+00
#     6	+2.3767360634991041e+02	3.68302382e-01
#     7	+2.3767359810233017e+02	2.88433805e-01
#     8	+2.3767358591293549e+02	7.52894834e-02
#     9	+2.3767358547038270e+02	5.34216974e-02
#    10	+2.3767358544604917e+02	5.19529324e-02
#    11	+2.3767358535429599e+02	4.59951757e-02
#    12	+2.3767358508851942e+02	2.06207140e-02
#    13	+2.3767358508687704e+02	2.03658641e-02
#    14	+2.3767358508047295e+02	1.93400728e-02
#    15	+2.3767358505764599e+02	1.51280712e-02
#    16	+2.3767358502426072e+02	4.06538291e-03
#    17	+2.3767358502261612e+02	2.46324885e-03
#    18	+2.3767358502216200e+02	1.78303495e-03
#    19	+2.3767358502199573e+02	1.45663973e-03
#    20	+2.3767358502166212e+02	4.72010459e-06
#    21	+2.3767358502166212e+02	8.99823026e-06
# Terminated - min stepsize reached after 21 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.744143e+03   |grad|: 3.937152e+02
# acc TR+   k:     1     num_inner:     0     f: +1.440276e+03   |grad|: 1.137566e+03   negative curvature
# acc       k:     2     num_inner:     0     f: +7.001062e+02   |grad|: 6.931736e+02   negative curvature
# acc       k:     3     num_inner:     0     f: +6.060373e+02   |grad|: 8.393575e+01   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +6.047870e+02   |grad|: 1.478427e-01   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +6.047870e+02   |grad|: 7.088730e-07   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.7182986634422837e+03	5.35934112e+02
#     1	+8.7810316514885835e+02	1.06722343e+03
#     2	+6.0479987527255889e+02	8.50879145e+00
#     3	+6.0478851959035512e+02	2.93484212e+00
#     4	+6.0478716880894103e+02	1.01179604e+00
#     5	+6.0478700826990462e+02	3.48763468e-01
#     6	+6.0478698919556416e+02	1.20211219e-01
#     7	+6.0478698692948478e+02	4.14334181e-02
#     8	+6.0478698666027822e+02	1.42808378e-02
#     9	+6.0478698662829731e+02	4.92215889e-03
#    10	+6.0478698662449801e+02	1.69651317e-03
#    11	+6.0478698662404668e+02	5.84734511e-04
#    12	+6.0478698662399302e+02	2.01539500e-04
#    13	+6.0478698662398665e+02	6.94642920e-05
#    14	+6.0478698662398597e+02	2.39421445e-05
#    15	+6.0478698662398585e+02	8.25210005e-06
#    16	+6.0478698662398574e+02	2.56362423e-06
#    17	+6.0478698662398574e+02	2.56362423e-06
# Terminated - min stepsize reached after 18 iterations, 0.01 seconds.
#
# v_steepest = [0.98677677 0.16208516]
#
# v_trust = [-0.99846489 -0.05538832]
#
# v_cg = [-0.99846489 -0.05538832]
#
#
#  New perturbation : [2.75985419 6.49790615]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.006251970799694639
#
# NextGrad = 0.23186547048433062
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.006631349433465328
#
# NextGrad = 0.2387226179188943
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.007154496007294009
#
# NextGrad = 0.24786300952369783
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.007882766922358675
#
# NextGrad = 0.2600450504199545
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00890837498828545
#
# NextGrad = 0.2762769615317082
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.01037269496406723
#
# NextGrad = 0.2978966792897186
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.012496785096719698
#
# NextGrad = 0.3266745606045051
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.015632729680528534
#
# NextGrad = 0.3649420863951245
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.020350385273735894
#
# NextGrad = 0.4157455773328615
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.02758370126293741
#
# NextGrad = 0.4830119451376428
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 2, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.375440888808336
# |gradf_0| = 0.41547798527536534
# f_1 = 1.362979562021381
# |gradf_1| = 0.3272415273339134
# f_2 = 1.3550709569660067
# |gradf_2| = 0.006784783619352193
# f_3 = 1.3550678135617953
# |gradf_3| = 4.2425421513367804e-05
# f_4 = 1.3550678133314686
# |gradf_4| = 9.886909086225508e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+1.2248950233827775e+02	7.65386921e+01
#     2	+1.2187713154981131e+02	3.72959633e+01
#     3	+1.2175555145456406e+02	2.25004312e+01
#     4	+1.2172515741069533e+02	1.68694390e+01
#     5	+1.2169816797513596e+02	9.38223136e+00
#     6	+1.2168625369532597e+02	1.09837285e+00
#     7	+1.2168609066884434e+02	1.36500519e-01
#     8	+1.2168609062902340e+02	1.35433294e-01
#     9	+1.2168609047225912e+02	1.31148755e-01
#    10	+1.2168608988684232e+02	1.13730646e-01
#    11	+1.2168608831736438e+02	3.87228816e-02
#    12	+1.2168608828069898e+02	3.51043990e-02
#    13	+1.2168608816583097e+02	1.98844055e-02
#    14	+1.2168608811174880e+02	1.16044967e-03
#    15	+1.2168608811156778e+02	1.65958281e-04
#    16	+1.2168608811156489e+02	8.23904075e-05
#    17	+1.2168608811156426e+02	4.57933660e-05
#    18	+1.2168608811156398e+02	3.94936734e-06
#    19	+1.2168608811156398e+02	1.24362203e-05
# Terminated - min stepsize reached after 19 iterations, 0.02 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.984636e+03   |grad|: 9.521209e+02
# acc TR+   k:     1     num_inner:     0     f: +1.464439e+03   |grad|: 1.692690e+03   negative curvature
# acc       k:     2     num_inner:     0     f: +4.873147e+02   |grad|: 8.007510e+02   negative curvature
# acc       k:     3     num_inner:     0     f: +3.881975e+02   |grad|: 4.297813e+01   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +3.879236e+02   |grad|: 3.455188e-02   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +3.879236e+02   |grad|: 1.758602e-08   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.9063619882496087e+03	9.61431048e+01
#     1	+9.8360289496316318e+02	1.77582700e+03
#     2	+2.2665617461988447e+02	8.43508858e+02
#     3	+1.4239447408391146e+02	3.85093186e+02
#     4	+1.2528348142805078e+02	1.61536104e+02
#     5	+1.2229148188105123e+02	6.63693717e+01
#     6	+1.2178718032919741e+02	2.71331126e+01
#     7	+1.2170293187578457e+02	1.10770640e+01
#     8	+1.2168889251740562e+02	4.52011434e+00
#     9	+1.2168655490431095e+02	1.84416765e+00
#    10	+1.2168616580082677e+02	7.52354638e-01
#    11	+1.2168610104099255e+02	3.06925723e-01
#    12	+1.2168609026330572e+02	1.25210086e-01
#    13	+1.2168608846965867e+02	5.10791240e-02
#    14	+1.2168608817115825e+02	2.08375568e-02
#    15	+1.2168608812148166e+02	8.50060503e-03
#    16	+1.2168608811321447e+02	3.46778968e-03
#    17	+1.2168608811183864e+02	1.41467152e-03
#    18	+1.2168608811160969e+02	5.77109800e-04
#    19	+1.2168608811157161e+02	2.35429716e-04
#    20	+1.2168608811156524e+02	9.60426438e-05
#    21	+1.2168608811156415e+02	3.91802255e-05
#    22	+1.2168608811156399e+02	1.59834218e-05
#    23	+1.2168608811156398e+02	6.52037503e-06
#    24	+1.2168608811156395e+02	1.20045137e-06
#    25	+1.2168608811156395e+02	1.20045137e-06
# Terminated - min stepsize reached after 26 iterations, 0.02 seconds.
#
# v_steepest = [0.9935328  0.11354546]
#
# v_trust = [-0.99863056 -0.05231642]
#
# v_cg = [0.9935328  0.11354547]
#
#
#  New perturbation : [3.61885627 5.24836646]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.006777919922263065
#
# NextGrad = 0.25173262719280504
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0071879095154510075
#
# NextGrad = 0.25916366262530005
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.007753208971566616
#
# NextGrad = 0.2690687967498378
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.008540060604593114
#
# NextGrad = 0.28226969950294306
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.009647996050407892
#
# NextGrad = 0.29985864768240217
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.011229572597414084
#
# NextGrad = 0.3232850807246453
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.013523274756318537
#
# NextGrad = 0.35446689369156964
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.01690885238107631
#
# NextGrad = 0.3959299705577143
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.022000805917687938
#
# NextGrad = 0.4509749743817002
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.029806056895876232
#
# NextGrad = 0.5238575093205569
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 3, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.4244845084818079
# |gradf_0| = 0.45073414080028196
# f_1 = 1.4150514087724504
# |gradf_1| = 0.41983287140685316
# f_2 = 1.4024606771579036
# |gradf_2| = 0.0046398766312549765
# f_3 = 1.4024592150353905
# |gradf_3| = 2.648168628802362e-05
# f_4 = 1.4024592149807547
# |gradf_4| = 3.696511392374727e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+4.7457070605407893e+01	3.90629103e+01
#     2	+4.7351230404944218e+01	2.55078175e+01
#     3	+4.7281828395986885e+01	8.78383502e+00
#     4	+4.7279377923863308e+01	7.54278182e+00
#     5	+4.7273065321751325e+01	2.17255531e+00
#     6	+4.7272577502109357e+01	8.29461233e-01
#     7	+4.7272512272790962e+01	3.85809428e-01
#     8	+4.7272506110903549e+01	3.12919336e-01
#     9	+4.7272494283484789e+01	1.26030420e-02
#    10	+4.7272494265052799e+01	2.54698455e-03
#    11	+4.7272494264439707e+01	1.19149261e-03
#    12	+4.7272494264373734e+01	9.35044418e-04
#    13	+4.7272494264274414e+01	2.31331808e-04
#    14	+4.7272494264273405e+01	2.12255071e-04
#    15	+4.7272494264270108e+01	1.33673762e-04
#    16	+4.7272494264268531e+01	7.01856680e-05
#    17	+4.7272494264268012e+01	2.26967551e-05
#    18	+4.7272494264267948e+01	9.14990590e-07
# Terminated - min grad norm reached after 18 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.060090e+03   |grad|: 2.125271e+03
# acc TR+   k:     1     num_inner:     0     f: +3.535285e+02   |grad|: 1.480404e+03   exceeded trust region
# acc       k:     2     num_inner:     0     f: +5.589240e+01   |grad|: 2.661167e+02   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +4.727276e+01   |grad|: 1.488777e+00   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +4.727249e+01   |grad|: 1.181815e-05   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +4.727249e+01   |grad|: 1.137423e-14   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.3216509525718939e+03	1.97837039e+03
#     1	+7.8702665044473378e+01	5.04919400e+02
#     2	+5.4704917797408875e+01	2.47194980e+02
#     3	+4.8986295520184022e+01	1.18918800e+02
#     4	+4.7664927213228793e+01	5.69360325e+01
#     5	+4.7362170561807005e+01	2.72220767e+01
#     6	+4.7292972510253897e+01	1.30094294e+01
#     7	+4.7277169415640003e+01	6.21615737e+00
#     8	+4.7273561479045171e+01	2.96999380e+00
#     9	+4.7272737869828582e+01	1.41897827e+00
#    10	+4.7272549869158489e+01	6.77937756e-01
#    11	+4.7272506956391460e+01	3.23892604e-01
#    12	+4.7272497161301075e+01	1.54742954e-01
#    13	+4.7272494925526971e+01	7.39298951e-02
#    14	+4.7272494415202715e+01	3.53206745e-02
#    15	+4.7272494298719337e+01	1.68747653e-02
#    16	+4.7272494272131595e+01	8.06206736e-03
#    17	+4.7272494266062850e+01	3.85172321e-03
#    18	+4.7272494264677633e+01	1.84019439e-03
#    19	+4.7272494264361455e+01	8.79168921e-04
#    20	+4.7272494264289293e+01	4.20030617e-04
#    21	+4.7272494264272822e+01	2.00673288e-04
#    22	+4.7272494264269056e+01	9.58734125e-05
#    23	+4.7272494264268197e+01	4.58043583e-05
#    24	+4.7272494264268005e+01	2.18834314e-05
#    25	+4.7272494264267941e+01	9.73431284e-07
# Terminated - min grad norm reached after 26 iterations, 0.02 seconds.
#
# v_steepest = [0.99668118 0.08140415]
#
# v_trust = [0.99668118 0.08140415]
#
# v_cg = [0.99668118 0.08140415]
#
#
#  New perturbation : [4.16238877 4.21848991]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.007300464602021384
#
# NextGrad = 0.27340954908794185
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.007744429692193799
#
# NextGrad = 0.28153297428461327
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.008356680794294302
#
# NextGrad = 0.29236083619211617
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.009209067140828031
#
# NextGrad = 0.3067912028942836
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.010409588984122253
#
# NextGrad = 0.32601788006042914
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.012123853326286627
#
# NextGrad = 0.35162502170277976
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.014610851970196181
#
# NextGrad = 0.3857088192602492
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.01828315234820943
#
# NextGrad = 0.4310301491707438
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.023808601954481645
#
# NextGrad = 0.49119720071265355
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.032281892523092104
#
# NextGrad = 0.570863093398084
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 4, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.4849943395212
# |gradf_0| = 0.49099387258771526
# f_1 = 1.4806639566330542
# |gradf_1| = 0.5321333712090561
# f_2 = 1.461159370041261
# |gradf_2| = 0.0015607501306152103
# f_3 = 1.4611591601071527
# |gradf_3| = 1.6456927898529368e-05
# f_4 = 1.46115916008017
# |gradf_4| = 1.0250598843951034e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+8.0674369566344843e+00	1.32432630e+01
#     2	+8.0517273062655281e+00	5.19967827e+00
#     3	+8.0492595288506852e+00	1.93251308e+00
#     4	+8.0489880173177610e+00	1.08202535e+00
#     5	+8.0488651462206899e+00	1.02696744e-01
#     6	+8.0488646065664415e+00	7.38296647e-02
#     7	+8.0488644659715689e+00	6.42123424e-02
#     8	+8.0488640846671231e+00	2.28621418e-02
#     9	+8.0488640581821471e+00	1.65102270e-02
#    10	+8.0488640494385209e+00	1.37849230e-02
#    11	+8.0488640296600806e+00	1.80610896e-03
#    12	+8.0488640295297706e+00	1.42532057e-03
#    13	+8.0488640293242355e+00	3.01279320e-04
#    14	+8.0488640293157108e+00	1.01338843e-04
#    15	+8.0488640293156255e+00	9.72439457e-05
#    16	+8.0488640293153146e+00	8.06848945e-05
#    17	+8.0488640293146361e+00	7.92323507e-06
#    18	+8.0488640293146290e+00	4.71270720e-06
#    19	+8.0488640293146272e+00	2.40575732e-06
#    20	+8.0488640293146272e+00	4.56652510e-06
# Terminated - min stepsize reached after 20 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.397128e+02   |grad|: 4.372163e+02
# acc       k:     1     num_inner:     0     f: +1.187645e+02   |grad|: 4.561160e+00   maximum inner iterations
# acc       k:     2     num_inner:     0     f: +1.187622e+02   |grad|: 4.343714e-05   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +1.187622e+02   |grad|: 5.945490e-14   maximum inner iterations
# Terminated - min grad norm reached after 3 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.0108949559296176e+03	2.25494293e+03
#     1	+2.1569122324189365e+02	9.26543332e+02
#     2	+1.1879458768227113e+02	1.72812669e+01
#     3	+1.1876994069325636e+02	8.44725544e+00
#     4	+1.1876405161921733e+02	4.12917586e+00
#     5	+1.1876264445590044e+02	2.01844264e+00
#     6	+1.1876230821413222e+02	9.86671058e-01
#     7	+1.1876222786814805e+02	4.82314025e-01
#     8	+1.1876220866911041e+02	2.35769791e-01
#     9	+1.1876220408139855e+02	1.15251558e-01
#    10	+1.1876220298513876e+02	5.63385468e-02
#    11	+1.1876220272318102e+02	2.75400400e-02
#    12	+1.1876220266058466e+02	1.34624325e-02
#    13	+1.1876220264562687e+02	6.58085816e-03
#    14	+1.1876220264205264e+02	3.21692943e-03
#    15	+1.1876220264119854e+02	1.57253580e-03
#    16	+1.1876220264099445e+02	7.68704729e-04
#    17	+1.1876220264094567e+02	3.75766938e-04
#    18	+1.1876220264093404e+02	1.83686644e-04
#    19	+1.1876220264093125e+02	8.97917822e-05
#    20	+1.1876220264093055e+02	4.38930344e-05
#    21	+1.1876220264093041e+02	2.14562893e-05
#    22	+1.1876220264093037e+02	1.04885060e-05
#    23	+1.1876220264093035e+02	5.12711014e-06
#    24	+1.1876220264093035e+02	4.47190564e-06
#    25	+1.1876220264093035e+02	3.32895661e-06
#    26	+1.1876220264093035e+02	1.62729822e-06
#    27	+1.1876220264093035e+02	1.21138618e-06
# Terminated - min stepsize reached after 28 iterations, 0.02 seconds.
#
# v_steepest = [0.99812493 0.06120973]
#
# v_trust = [-0.99887636 -0.04739209]
#
# v_cg = [-0.99887636 -0.04739209]
#
#
#  New perturbation : [4.51129395 3.51507826]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.007873582684576608
#
# NextGrad = 0.2985467076669398
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.008357535477720113
#
# NextGrad = 0.30752011886384584
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.009025163664018176
#
# NextGrad = 0.3194807622913725
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.009955045560497311
#
# NextGrad = 0.33542052184989735
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.011265392611017111
#
# NextGrad = 0.3566578892010612
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.013137621571492453
#
# NextGrad = 0.3849424730880121
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.015855683978112323
#
# NextGrad = 0.4225894642356499
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.019872263704880266
#
# NextGrad = 0.4726483974283721
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.025920677429911443
#
# NextGrad = 0.5391052316594674
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.03520370686828467
#
# NextGrad = 0.6271013756367708
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 5, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.5523210019059215
# |gradf_0| = 0.5389551437766975
# f_1 = 1.5338764045253541
# |gradf_1| = 0.35001314745142753
# f_2 = 1.5263747954408682
# |gradf_2| = 0.007620330395553791
# f_3 = 1.5263712204414612
# |gradf_3| = 5.029372893179013e-05
# f_4 = 1.526371220169498
# |gradf_4| = 2.226223594510576e-06
# f_5 = 1.52637122016895
# |gradf_5| = 5.645474273245667e-09
# Computing gradient of cost function...
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.004119659607660697
#
# NextGrad = 0.22526296333774412
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.004375169829577752
#
# NextGrad = 0.23208594206210226
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.004727783661919949
#
# NextGrad = 0.24118317508450793
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.005219141192027266
#
# NextGrad = 0.25331211250936764
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.005911959521158527
#
# NextGrad = 0.26948154735807245
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0069026319507892175
#
# NextGrad = 0.2910338350431976
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.00834232028792603
#
# NextGrad = 0.31975263368355855
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.010472635433691257
#
# NextGrad = 0.35800250359918995
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.01368642998116032
#
# NextGrad = 0.4089062554128233
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.018631718879362325
#
# NextGrad = 0.4765621134947018
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 6, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.5884880898425968
# |gradf_0| = 0.40860411564851623
# f_1 = 1.5803810125058388
# |gradf_1| = 0.30695655637621216
# f_2 = 1.5747865343391494
# |gradf_2| = 0.0020361085556693643
# f_3 = 1.5747861792650013
# |gradf_3| = 2.651115650185696e-05
# f_4 = 1.5747861792054705
# |gradf_4| = 5.25922743895694e-07

# %% [markdown]
# # Visualization of results

# %%
# %matplotlib notebook
from Visualization.visualization import SubplotAnimation

ani = SubplotAnimation(results, 
                       parameterMagnitude, 
                       targetParameter, 
                       finalSolution, 
                       differentialParameterAlongV, 
                       differentialSolutionAlongV)

ani.show()
# Out:
# <img src="data:image/png;base64,..." width="990.9274355497729">
# [8.78993325e-07 4.90326197e-05]

# %% [markdown]
# ############################################################################################################################
# ############################################################################################################################

# %% [markdown]
# ## Second test case, $n=3, p=2$, $C^0$ eigenvalues:
# We consider a mapping $A$ defined for any $\mu=(\mu_1, \mu_2)\in\Rset^2$ by
#
# $$
# A(\mu) = \begin{pmatrix} \lambda_1(\mu) & -1 & 0 \\ -1 & \lambda_2(\mu) & 1 \\ 0 & 1 & \lambda_3(\mu) \end{pmatrix},
# $$
#
# with
# $$
# \lambda_0(\mu) =
# \begin{cases}
#     1 + \exp(\frac{\mu_1 + \mu_2}{\sigma}) \quad &\text{if } \mu_1 + \mu_2 \le 0,\\
#     1 + \exp(\frac{\mu_1 + \mu_2}{10\sigma}) &\text{else }
# \end{cases} ,
# \lambda_1(\mu) =
# \begin{cases}
#     2 + \exp(\frac{\mu_1 - \mu_2}{\sigma}) \quad &\text{if } \mu_1 - \mu_2 \le 0,\\
#     2 + \exp(\frac{\mu_1 - \mu_2}{10\sigma}) &\text{else }
# \end{cases},
# $$
# $$
# \lambda_2(\mu) =
# \begin{cases}
#     3 + \exp(\frac{3\mu_1 + \mu_2}{\sigma}) \quad &\text{if } 3\mu_1 + \mu_2 \le 0,\\
#     3 + \exp(\frac{3\mu_1 + \mu_2}{10\sigma}) &\text{else }
# \end{cases}
# $$

# %%
def A(mu):
    sigma = 50
    
    if mu[0] + mu[1] <= 0:
        lambda0 = 1 + np.exp((mu[0] + mu[1]) / sigma)
    else:
        lambda0 = 1 + np.exp((mu[0] + mu[1]) / (10 * sigma))
        
    if mu[0] - mu[1] <= 0:
        lambda1 = 2 + np.exp((mu[0] - mu[1]) / sigma)
    else:
        lambda1 = 2 + np.exp((mu[0] - mu[1]) / (5 * sigma))

    if 3 * mu[0] + mu[1] <= 0:
        lambda2 = 3 + np.exp((3 * mu[0] + mu[1]) / sigma)
    else:
        lambda2 = 3 + np.exp((3 * mu[0] + mu[1]) / (20 * sigma))
        
    return np.array([[lambda0, -1, 0], [-1, lambda1, -1], [0, -1, lambda2]])

def DA(mu, v):
    tol = 1.0e-15
    sigma = 50
    
    if np.abs(mu[0] + mu[1]) <= tol:
        Dlambda0 = np.nan
    elif mu[0] + mu[1] < 0:
        Dlambda0 = (1.0 / sigma) * (v[0] + v[1]) * np.exp((mu[0] + mu[1]) / sigma)
    else:
        Dlambda0 = (1.0 / (10.0 * sigma)) * (v[0] + v[1]) * np.exp((mu[0] + mu[1]) / (10.0 * sigma))
        
    if np.abs(mu[0] - mu[1]) <= tol:
        Dlambda1 = np.nan
    elif mu[0] - mu[1] < 0:
        Dlambda1 = (v[0] - v[1]) / sigma * np.exp((mu[0] - mu[1]) / sigma)
    else:
        Dlambda1 = (v[0] - v[1]) / (5 * sigma) * np.exp((mu[0] - mu[1]) / (5 * sigma))

    if np.abs(3 * mu[0] + mu[1]) <= tol:
        Dlambda2 = np.nan
    elif 3 * mu[0] + mu[1] < 0:
        Dlambda2 = (3 * v[0] + v[1]) / sigma * np.exp((3 * mu[0] + mu[1]) / sigma)
    else:
        Dlambda2 = (3 * v[0] + v[1]) / (20 * sigma) * np.exp((3 * mu[0] + mu[1]) / (20.0 * sigma))

    
    return np.array([[Dlambda0, 0, 0], [0, Dlambda1, 0], [0, 0, Dlambda2]])

# %%
# Define derivatives of gradient wrt solution/parameter
def differentialSolutionAlongV(x, mu, xi):
    return A(mu) @ xi - 2 * (x.T @ A(mu) @ xi) * x - (x.T @ A(mu) @ x) * xi

def differentialParameterAlongV(x, mu, v):
    return (np.eye(solutionSpaceDimension) - np.outer(x, x)) @ DA(mu, v) @ x

# %%
initialParameter = np.array([0, -5])
targetParameter = np.array([40., 40.])

B = A(initialParameter)
C = A(targetParameter)

w, v = np.linalg.eig(B)
wC, vC = np.linalg.eig(C)

initialSolution = v[:, np.argmin(w)]
finalSolution = vC[:, np.argmin(wC)]

# %%
def WriteMatrixInEuclideanBasisAtGivenPoint(matrixVectorFunction, x, mu, dimension):
    spaceDimension = len(x)
    indices = np.arange(dimension)
    A = np.zeros((spaceDimension, dimension))

    for index in indices:
        v = np.zeros(dimension)
        v[index] = 1

        A[:, index] = matrixVectorFunction(x, mu, v)

    return A

# %%
np.linalg.matrix_rank(WriteMatrixInEuclideanBasisAtGivenPoint(differentialParameterAlongV, initialSolution, initialParameter, 2))
# Out:
# 2

# %%
from pymanopt.core.problem import Problem 

def cost(S):
    return np.dot(S[0], A(S[1]) @ S[0])

problem = Problem(productManifold, cost=cost)

# %%
from Continuation.PathAdaptiveContinuation import PathAdaptiveMultiParameterContinuation

parameterMagnitude = 1e-2

# Instantiate continuation object
continuation = PathAdaptiveMultiParameterContinuation(problem, 
                                                      initialSolution,
                                                      initialParameter,
                                                      targetParameter,
                                                      differentialSolutionAlongV, 
                                                      differentialParameterAlongV,
                                                      A,
                                                      parameterMagnitude)
results = continuation.Traverse()
# Out:
# ========== New continuation problem ==========
#
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+1.6876729998812209e+03	5.32553330e+01
#     2	+1.6782751110692332e+03	1.30037217e+01
#     3	+1.6782377436421161e+03	1.26687689e+01
#     4	+1.6780983429055086e+03	1.09630594e+01
#     5	+1.6777277767592479e+03	3.62404496e+00
#     6	+1.6776822148951510e+03	5.71367933e-02
#     7	+1.6776822140204549e+03	5.48918767e-02
#     8	+1.6776822108139168e+03	4.57218771e-02
#     9	+1.6776822036484514e+03	5.36434736e-03
#    10	+1.6776822035498647e+03	6.40780711e-04
#    11	+1.6776822035484461e+03	5.08956169e-05
#    12	+1.6776822035484379e+03	1.17569394e-05
#    13	+1.6776822035484374e+03	7.63004700e-07
# Terminated - min grad norm reached after 13 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.897118e+03   |grad|: 1.152300e+02
# acc TR+   k:     1     num_inner:     0     f: +1.848909e+03   |grad|: 1.392818e+02   negative curvature
# acc TR+   k:     2     num_inner:     0     f: +1.755491e+03   |grad|: 1.296839e+02   negative curvature
# acc       k:     3     num_inner:     0     f: +1.678110e+03   |grad|: 1.111200e+01   exceeded trust region
# acc       k:     4     num_inner:     0     f: +1.677682e+03   |grad|: 4.262042e-02   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +1.677682e+03   |grad|: 6.765262e-07   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.9244142600784126e+03	8.79278618e+01
#     1	+1.8285342439501187e+03	1.43149796e+02
#     2	+1.7018134750266959e+03	8.09329804e+01
#     3	+1.6793354463916828e+03	2.18571240e+01
#     4	+1.6777374548526163e+03	3.99062817e+00
#     5	+1.6776840118663281e+03	7.21440699e-01
#     6	+1.6776822632571700e+03	1.31075040e-01
#     7	+1.6776822055239170e+03	2.38410736e-02
#     8	+1.6776822036138215e+03	4.33733654e-03
#     9	+1.6776822035506016e+03	7.89109337e-04
#    10	+1.6776822035485093e+03	1.43566890e-04
#    11	+1.6776822035484399e+03	2.61199270e-05
#    12	+1.6776822035484374e+03	4.75214547e-06
#    13	+1.6776822035484374e+03	8.64584613e-07
# Terminated - min grad norm reached after 14 iterations, 0.01 seconds.
#
# v_steepest = [0.94510262 0.32677368]
#
# v_trust = [0.94510261 0.32677372]
#
# v_cg = [0.94510261 0.32677372]
#
#
#  New perturbation : [2.56653914 0.79479199]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 0.1
#
# NextObj = 1.3196422859573786e-05
#
# NextGrad = 0.02330966015672481
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 1.794629900309097e-05
#
# NextGrad = 0.024651990149549503
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 2.5413004719032628e-05
#
# NextGrad = 0.02662404901050164
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 3.7383766705811894e-05
#
# NextGrad = 0.02950978776065653
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 5.692720959826758e-05
#
# NextGrad = 0.033691194346272185
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 8.935368240736707e-05
#
# NextGrad = 0.03966472272579395
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.00014391020527315668
#
# NextGrad = 0.048063769917022846
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0002367768983748686
#
# NextGrad = 0.05969730426476191
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.00039637027532446467
#
# NextGrad = 0.07561248524430376
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0006727357302207526
#
# NextGrad = 0.09718463466728948
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 1, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.257961140762513
# |gradf_0| = 0.1201536693432569
# f_1 = 1.2572327641578496
# |gradf_1| = 0.07649303654931526
# f_2 = 1.2572014887791216
# |gradf_2| = 0.05377226220886654
# f_3 = 1.2569153611363328
# |gradf_3| = 0.03235711266826852
# f_4 = 1.2568137478670238
# |gradf_4| = 0.007299571297234866
# f_5 = 1.256809968666492
# |gradf_5| = 0.0007252781602113963
# f_6 = 1.2568099164735997
# |gradf_6| = 2.6666393410579198e-05
# f_7 = 1.256809916373798
# |gradf_7| = 9.348865126403209e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+1.5973306366980751e+03	2.44588694e+02
#     2	+1.5831020258256588e+03	1.50343574e+01
#     3	+1.5830472277034655e+03	2.18167894e-01
#     4	+1.5830472164814837e+03	3.51645866e-02
#     5	+1.5830472161909720e+03	6.03399863e-03
#     6	+1.5830472161821663e+03	1.81528529e-04
#     7	+1.5830472161821585e+03	1.41709646e-05
#     8	+1.5830472161821585e+03	2.10425211e-05
# Terminated - min stepsize reached after 8 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +2.407364e+03   |grad|: 3.096716e+02
# acc TR+   k:     1     num_inner:     0     f: +2.200439e+03   |grad|: 7.318564e+02   negative curvature
# acc       k:     2     num_inner:     0     f: +1.769962e+03   |grad|: 3.078934e+02   negative curvature
# acc       k:     3     num_inner:     0     f: +1.743094e+03   |grad|: 2.347420e+01   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.742950e+03   |grad|: 5.526311e-02   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +1.742950e+03   |grad|: 3.295953e-07   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+2.7278187218611906e+03	8.73227834e+02
#     1	+1.9196027873445578e+03	7.87931000e+02
#     2	+1.7856849937030754e+03	4.05085537e+02
#     3	+1.7516598299445184e+03	1.83349315e+02
#     4	+1.7447043295991352e+03	8.20145655e+01
#     5	+1.7433081553904208e+03	3.69795230e+01
#     6	+1.7430236677570033e+03	1.67776864e+01
#     7	+1.7429650376382588e+03	7.63746359e+00
#     8	+1.7429528812723624e+03	3.48232064e+00
#     9	+1.7429503533758375e+03	1.58897727e+00
#    10	+1.7429498269819774e+03	7.25301771e-01
#    11	+1.7429497172994265e+03	3.31123204e-01
#    12	+1.7429496944386715e+03	1.51179343e-01
#    13	+1.7429496896732494e+03	6.90255532e-02
#    14	+1.7429496886798165e+03	3.15162119e-02
#    15	+1.7429496884727123e+03	1.43900127e-02
#    16	+1.7429496884295363e+03	6.57036856e-03
#    17	+1.7429496884205355e+03	2.99998389e-03
#    18	+1.7429496884186592e+03	1.36977238e-03
#    19	+1.7429496884182677e+03	6.25429004e-04
#    20	+1.7429496884181863e+03	2.85566784e-04
#    21	+1.7429496884181690e+03	1.30387931e-04
#    22	+1.7429496884181658e+03	5.95342804e-05
#    23	+1.7429496884181649e+03	5.16835005e-06
#    24	+1.7429496884181649e+03	5.16835005e-06
# Terminated - min stepsize reached after 25 iterations, 0.02 seconds.
#
# v_steepest = [ 0.99717468 -0.07511762]
#
# v_trust = [-0.98470337 -0.17423913]
#
# v_cg = [-0.98470337 -0.17423913]
#
#
#  New perturbation : [ 5.21057168 -1.92265608]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 2.3052729446915166e-05
#
# NextGrad = 0.013073263627742191
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 2.7323654606892234e-05
#
# NextGrad = 0.014143444375701808
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 3.362407081874963e-05
#
# NextGrad = 0.015593535857245183
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 4.310167433496659e-05
#
# NextGrad = 0.017557678163496102
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 5.765318438433198e-05
#
# NextGrad = 0.02021468987443777
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 8.045898159370068e-05
#
# NextGrad = 0.023801765901661012
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.00011691748260123092
#
# NextGrad = 0.02863281428757777
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.00017628455794471698
#
# NextGrad = 0.03512334163078535
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.00027455840962775646
#
# NextGrad = 0.043824188661530754
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0004395664928429355
#
# NextGrad = 0.05546681320315263
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 2, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.2898273858989349
# |gradf_0| = 0.043777443859477065
# f_1 = 1.289692363409884
# |gradf_1| = 0.03175587550291847
# f_2 = 1.289552334395655
# |gradf_2| = 6.729669989475772e-05
# f_3 = 1.2895523340696358
# |gradf_3| = 7.423080564878358e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+9.7417407337920645e+02	7.88868601e+03
#     2	+4.3945661064273321e+02	3.31320203e+03
#     3	+3.1310216700883916e+02	2.13023875e+02
#     4	+3.1306207769273993e+02	2.03951904e+02
#     5	+3.1291558741696082e+02	1.68675158e+02
#     6	+3.1260063465004367e+02	1.25907834e+01
#     7	+3.1259914967229474e+02	4.99286779e+00
#     8	+3.1259890467708192e+02	1.69781794e+00
#     9	+3.1259889928016474e+02	1.54824080e+00
#    10	+3.1259888206603796e+02	9.20911768e-01
#    11	+3.1259887907807683e+02	7.61056648e-01
#    12	+3.1259887267405986e+02	5.45182957e-02
#    13	+3.1259887264977647e+02	2.80570705e-02
#    14	+3.1259887264234408e+02	1.08821717e-02
#    15	+3.1259887264125121e+02	4.48179300e-03
#    16	+3.1259887264103901e+02	1.00359955e-03
#    17	+3.1259887264102832e+02	1.85472291e-04
#    18	+3.1259887264102815e+02	1.38560810e-04
#    19	+3.1259887264102798e+02	8.29226950e-05
#    20	+3.1259887264102787e+02	9.60002748e-06
# Terminated - min stepsize reached after 20 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.479935e+04   |grad|: 3.693713e+03
# acc TR+   k:     1     num_inner:     0     f: +1.117951e+04   |grad|: 1.455897e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +1.335379e+03   |grad|: 8.905984e+03   negative curvature
# acc       k:     3     num_inner:     0     f: +3.348219e+02   |grad|: 1.423045e+03   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +3.126007e+02   |grad|: 1.285571e+01   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +3.125989e+02   |grad|: 1.198518e-03   maximum inner iterations
# acc       k:     6     num_inner:     0     f: +3.125989e+02   |grad|: 1.047312e-11   maximum inner iterations
# Terminated - min grad norm reached after 6 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+2.3611221719243695e+03	1.19743905e+04
#     1	+4.3043303920529354e+02	3.19582130e+03
#     2	+3.1351811715958411e+02	2.87194693e+02
#     3	+3.1260249041442324e+02	1.80408873e+01
#     4	+3.1259888602343352e+02	1.09733686e+00
#     5	+3.1259887269033840e+02	6.66108129e-02
#     6	+3.1259887264120948e+02	4.04292931e-03
#     7	+3.1259887264102855e+02	2.45382916e-04
#     8	+3.1259887264102787e+02	1.48933468e-05
#     9	+3.1259887264102787e+02	1.40190096e-05
# Terminated - min stepsize reached after 10 iterations, 0.01 seconds.
#
# v_steepest = [-0.95583203  0.29391347]
#
# v_trust = [-0.95583203  0.29391347]
#
# v_cg = [-0.95583203  0.29391347]
#
#
#  New perturbation : [40.93927821 22.69237161]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.0003420060137089287
#
# NextGrad = 0.059621783460758575
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0003609492389577973
#
# NextGrad = 0.06124404489613265
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00038700095379451405
#
# NextGrad = 0.06340718923247637
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00042314821755584653
#
# NextGrad = 0.06629157684405462
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0004738540161604021
#
# NextGrad = 0.07013770339704452
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0005459226178341492
#
# NextGrad = 0.07526622337784954
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0006499435496001293
#
# NextGrad = 0.08210460615415015
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0008027323291559529
#
# NextGrad = 0.09122258741651992
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0010314998689571198
#
# NextGrad = 0.10337925026813394
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0013810349338194694
#
# NextGrad = 0.11958540461397203
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 3, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.4093492933702583
# |gradf_0| = 0.10338927994135566
# f_1 = 1.4093050509059475
# |gradf_1| = 0.11677615717509987
# f_2 = 1.4083167178492682
# |gradf_2| = 0.00043596721686053067
# f_3 = 1.4083166953263715
# |gradf_3| = 4.500518414494339e-06
# f_4 = 1.408316695323499
# |gradf_4| = 4.378274143866367e-09
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+1.7671581313251116e+02	3.71856940e+01
#     2	+1.7669890560534719e+02	1.98722922e+01
#     3	+1.7669257160407383e+02	4.98295063e+00
#     4	+1.7669246319851217e+02	4.30068802e+00
#     5	+1.7669217806846169e+02	1.35518110e+00
#     6	+1.7669214719958441e+02	1.81459382e-01
#     7	+1.7669214692147895e+02	1.29145359e-01
#     8	+1.7669214689282947e+02	1.22493298e-01
#     9	+1.7669214679101609e+02	9.51625767e-02
#    10	+1.7669214665128118e+02	2.98591025e-02
#    11	+1.7669214663634114e+02	4.31954119e-03
#    12	+1.7669214663608994e+02	1.99556810e-03
#    13	+1.7669214663607016e+02	1.68169150e-03
#    14	+1.7669214663602338e+02	3.07144014e-04
#    15	+1.7669214663602278e+02	2.49060662e-04
#    16	+1.7669214663602176e+02	3.09734882e-05
#    17	+1.7669214663602176e+02	1.58946026e-05
# Terminated - min stepsize reached after 17 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +8.847758e+03   |grad|: 1.444113e+04
# acc TR+   k:     1     num_inner:     0     f: +3.584142e+03   |grad|: 1.237589e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +5.568145e+02   |grad|: 4.649927e+03   exceeded trust region
# acc       k:     3     num_inner:     0     f: +1.769770e+02   |grad|: 1.289987e+02   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.766921e+02   |grad|: 1.061188e-03   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +1.766921e+02   |grad|: 3.703182e-13   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+2.5471526732674192e+03	1.07669642e+04
#     1	+5.9345354458300687e+02	4.86255480e+03
#     2	+2.2462811668766483e+02	1.67065220e+03
#     3	+1.8171703322499806e+02	5.41730707e+02
#     4	+1.7721290220648220e+02	1.74426796e+02
#     5	+1.7674604503089768e+02	5.61169470e+01
#     6	+1.7669772420550945e+02	1.80522061e+01
#     7	+1.7669272380380855e+02	5.80709876e+00
#     8	+1.7669220636106482e+02	1.86804147e+00
#     9	+1.7669215281632964e+02	6.00915442e-01
#    10	+1.7669214727555561e+02	1.93303661e-01
#    11	+1.7669214670220026e+02	6.21822957e-02
#    12	+1.7669214664286983e+02	2.00029206e-02
#    13	+1.7669214663673037e+02	6.43457792e-03
#    14	+1.7669214663609506e+02	2.06988738e-03
#    15	+1.7669214663602938e+02	6.65845346e-04
#    16	+1.7669214663602253e+02	2.14190409e-04
#    17	+1.7669214663602185e+02	6.89011819e-05
#    18	+1.7669214663602179e+02	2.21642650e-05
#    19	+1.7669214663602179e+02	7.12984299e-06
#    20	+1.7669214663602179e+02	2.54275984e-06
#    21	+1.7669214663602179e+02	4.35644061e-06
#    22	+1.7669214663602179e+02	4.35644061e-06
# Terminated - min stepsize reached after 23 iterations, 0.02 seconds.
#
# v_steepest = [-0.99507076  0.09916744]
#
# v_trust = [-0.99507076  0.09916744]
#
# v_cg = [-0.99507076  0.09916744]
#
#
#  New perturbation : [-2.36714775  5.74166789]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00023643999406441907
#
# NextGrad = 0.04532957084100831
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00025108344747026834
#
# NextGrad = 0.04670547328854196
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.0002712922847891708
#
# NextGrad = 0.04854024914486127
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.000299453771131164
#
# NextGrad = 0.05098698540487079
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0003391647423778288
#
# NextGrad = 0.054249841432448966
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.000395956539523068
#
# NextGrad = 0.0586010587123195
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.00047851163908307903
#
# NextGrad = 0.06440359923727172
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0006007300105730362
#
# NextGrad = 0.07214124551797536
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0007852728995507707
#
# NextGrad = 0.08245856711042711
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0010696868941495463
#
# NextGrad = 0.09621387096453193
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 4, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.4015539585729262
# |gradf_0| = 0.0824494306830393
# f_1 = 1.401156980581205
# |gradf_1| = 0.07255318232786238
# f_2 = 1.4007677972362922
# |gradf_2| = 0.00010971102197553636
# f_3 = 1.4007677962188416
# |gradf_3| = 1.6130393921655932e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+7.8195555719005995e+01	3.31126632e+01
#     2	+7.8185802626873908e+01	2.31254021e+01
#     3	+7.8176539636809650e+01	1.16209089e+00
#     4	+7.8176523100404651e+01	6.30998543e-01
#     5	+7.8176516451721923e+01	1.23595758e-01
#     6	+7.8176516271597521e+01	7.00209608e-02
#     7	+7.8176516186743910e+01	4.04954021e-03
#     8	+7.8176516186466813e+01	6.64089223e-04
#     9	+7.8176516186459267e+01	8.68191050e-05
#    10	+7.8176516186459253e+01	6.95965544e-05
#    11	+7.8176516186459182e+01	4.60789413e-05
#    12	+7.8176516186459168e+01	4.27221909e-05
#    13	+7.8176516186459153e+01	4.41084014e-06
#    14	+7.8176516186459153e+01	1.87812396e-05
# Terminated - min stepsize reached after 14 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.426399e+04   |grad|: 3.529393e+03
# acc TR+   k:     1     num_inner:     0     f: +1.120434e+04   |grad|: 1.206017e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +2.351255e+03   |grad|: 1.049382e+04   negative curvature
# acc       k:     3     num_inner:     0     f: +1.731511e+02   |grad|: 2.331296e+03   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +7.818043e+01   |grad|: 1.501375e+01   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +7.817652e+01   |grad|: 2.430904e-05   maximum inner iterations
# acc       k:     6     num_inner:     0     f: +7.817652e+01   |grad|: 5.218016e-13   maximum inner iterations
# Terminated - min grad norm reached after 6 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.1238251758970689e+04	1.21140221e+04
#     1	+1.3962771670819207e+03	7.55904086e+03
#     2	+5.3321977002742949e+02	3.50626142e+03
#     3	+3.5296020392593039e+02	1.47617030e+03
#     4	+3.2120274849528732e+02	6.08762197e+02
#     5	+3.1580741839574091e+02	2.50153656e+02
#     6	+3.1489652909390463e+02	1.02735166e+02
#     7	+3.1474289750323749e+02	4.21887575e+01
#     8	+3.1471698943212039e+02	1.73249259e+01
#     9	+3.1471262040578335e+02	7.11453833e+00
#    10	+3.1471188362965393e+02	2.92161284e+00
#    11	+3.1471175938219102e+02	1.19977251e+00
#    12	+3.1471173842948792e+02	4.92691740e-01
#    13	+3.1471173489608776e+02	2.02326008e-01
#    14	+3.1471173430022577e+02	8.30860605e-02
#    15	+3.1471173419974133e+02	3.41196550e-02
#    16	+3.1471173418279608e+02	1.40113861e-02
#    17	+3.1471173417993839e+02	5.75383720e-03
#    18	+3.1471173417945647e+02	2.36283851e-03
#    19	+3.1471173417937524e+02	9.70310008e-04
#    20	+3.1471173417936154e+02	3.98462066e-04
#    21	+3.1471173417935910e+02	1.63630197e-04
#    22	+3.1471173417935876e+02	6.71954594e-05
#    23	+3.1471173417935870e+02	2.75941100e-05
#    24	+3.1471173417935870e+02	1.13316427e-05
#    25	+3.1471173417935870e+02	4.65338853e-06
#    26	+3.1471173417935870e+02	1.91093526e-06
# Terminated - min stepsize reached after 27 iterations, 0.02 seconds.
#
# v_steepest = [-0.99431888  0.10644235]
#
# v_trust = [-0.99431888  0.10644235]
#
# v_cg = [ 0.99394283 -0.10989838]
#
#
#  New perturbation : [-2.30985753  5.86012646]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00023549616818696606
#
# NextGrad = 0.04513522142250663
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00025008421849248563
#
# NextGrad = 0.04650554084437754
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.0002702167346280149
#
# NextGrad = 0.04833287046038347
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00029827210332267207
#
# NextGrad = 0.05076967493723523
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0003378338406672121
#
# NextGrad = 0.05401928334966689
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0003944128937849456
#
# NextGrad = 0.05835282958950498
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0004766598655576715
#
# NextGrad = 0.06413179849966495
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0005984239072454045
#
# NextGrad = 0.0718380032855938
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.000782283724336974
#
# NextGrad = 0.08211338931009109
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.001065649597202789
#
# NextGrad = 0.09581276879728343
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 5, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3942149199869978
# |gradf_0| = 0.08210448397536216
# f_1 = 1.3938114949580132
# |gradf_1| = 0.07161241315518517
# f_2 = 1.3934317507656602
# |gradf_2| = 9.038866207886836e-05
# f_3 = 1.3934317500936437
# |gradf_3| = 1.1835968266654025e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+1.8720825673806129e+01	1.66907779e+01
#     2	+1.8718036981701736e+01	1.09795202e+01
#     3	+1.8716115358913047e+01	3.41379290e+00
#     4	+1.8715915513324724e+01	5.73562089e-01
#     5	+1.8715909741472430e+01	4.34703298e-02
#     6	+1.8715909712264580e+01	1.53132664e-02
#     7	+1.8715909710545741e+01	1.17086168e-02
#     8	+1.8715909708555365e+01	4.92946677e-03
#     9	+1.8715909708137605e+01	7.90835906e-04
#    10	+1.8715909708126933e+01	1.44643853e-04
#    11	+1.8715909708126802e+01	1.16682987e-04
#    12	+1.8715909708126567e+01	1.09985898e-05
#    13	+1.8715909708126567e+01	7.87832477e-06
# Terminated - min stepsize reached after 13 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +3.750544e+03   |grad|: 1.226303e+04
# acc TR+   k:     1     num_inner:     0     f: +5.072656e+02   |grad|: 4.255251e+03   exceeded trust region
# acc       k:     2     num_inner:     0     f: +1.785442e+02   |grad|: 1.031375e+02   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +1.783554e+02   |grad|: 2.074630e-03   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.783554e+02   |grad|: 5.587595e-13   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+9.7881104625553362e+03	1.31869841e+04
#     1	+5.3950118049865489e+02	5.33322653e+03
#     2	+1.3864739410976364e+02	2.59623988e+03
#     3	+4.4838727094446483e+01	1.21563857e+03
#     4	+2.4331611898121103e+01	5.64025119e+02
#     5	+1.9919731866969592e+01	2.61179743e+02
#     6	+1.8973820011839802e+01	1.20893946e+02
#     7	+1.8771158986942897e+01	5.59545511e+01
#     8	+1.8727744939117358e+01	2.58976638e+01
#     9	+1.8718444990805484e+01	1.19863043e+01
#    10	+1.8716452803986101e+01	5.54766545e+00
#    11	+1.8716026047560714e+01	2.56764775e+00
#    12	+1.8715934629822723e+01	1.18839480e+00
#    13	+1.8715915046738370e+01	5.50029655e-01
#    14	+1.8715910851739700e+01	2.54572505e-01
#    15	+1.8715909953106170e+01	1.17824851e-01
#    16	+1.8715909760604980e+01	5.45333667e-02
#    17	+1.8715909719368252e+01	2.52399055e-02
#    18	+1.8715909710534707e+01	1.16818907e-02
#    19	+1.8715909708642428e+01	5.40677821e-03
#    20	+1.8715909708237067e+01	2.50244171e-03
#    21	+1.8715909708150235e+01	1.15821554e-03
#    22	+1.8715909708131630e+01	5.36061729e-04
#    23	+1.8715909708127647e+01	2.48107686e-04
#    24	+1.8715909708126798e+01	1.14832715e-04
#    25	+1.8715909708126610e+01	5.31485050e-05
#    26	+1.8715909708126578e+01	2.45989445e-05
#    27	+1.8715909708126560e+01	1.82848088e-06
#    28	+1.8715909708126556e+01	1.82080774e-06
# Terminated - min stepsize reached after 29 iterations, 0.02 seconds.
#
# v_steepest = [-0.9933199   0.11539317]
#
# v_trust = [ 0.99303799 -0.11779449]
#
# v_cg = [-0.9933199   0.11539317]
#
#
#  New perturbation : [-2.15697107  6.0123287 ]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.0002348477024591844
#
# NextGrad = 0.044989258581346864
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00024939492203834845
#
# NextGrad = 0.046355126108118636
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00026947105897590085
#
# NextGrad = 0.04817651720078157
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00029744780978546714
#
# NextGrad = 0.05060539946445479
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0003368985980514161
#
# NextGrad = 0.05384443858925601
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00039331883058557615
#
# NextGrad = 0.05816388326537849
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.00047533468647720234
#
# NextGrad = 0.0639240375257689
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0005967561705473301
#
# NextGrad = 0.07160514015228545
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0007800980996024443
#
# NextGrad = 0.08184703844251817
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0010626648004889994
#
# NextGrad = 0.09550175063445282
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 6, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3873843402074695
# |gradf_0| = 0.08183845687633944
# f_1 = 1.3869755798069079
# |gradf_1| = 0.07085090441352622
# f_2 = 1.38660335905629
# |gradf_2| = 8.681374920743288e-05
# f_3 = 1.3866033584364288
# |gradf_3| = 1.2897245063163976e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+2.5637979419682884e-29	1.02941204e-12
# Terminated - min grad norm reached after 1 iterations, 0.00 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +2.824670e+00   |grad|: 3.742184e+02
# acc       k:     1     num_inner:     0     f: +1.659201e-07   |grad|: 9.070779e-02   maximum inner iterations
# acc       k:     2     num_inner:     0     f: +2.111239e-24   |grad|: 3.235663e-10   maximum inner iterations
# Terminated - min grad norm reached after 2 iterations, 0.00 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+6.4526407487355144e+01	1.78406769e+03
#     1	+1.1882036507601066e+00	2.42726332e+02
#     2	+2.0537128728249605e-02	3.19127444e+01
#     3	+3.5451066872905444e-04	4.19285280e+00
#     4	+6.1193251195600821e-06	5.50867020e-01
#     5	+1.0562743471883918e-07	7.23741341e-02
#     6	+1.8232651105577424e-09	9.50867329e-03
#     7	+3.1471895142713178e-11	1.24927044e-03
#     8	+5.4324528496301408e-13	1.64131900e-04
#     9	+9.3771113804768881e-15	2.15640114e-05
#    10	+1.6186089815338003e-16	2.83312664e-06
#    11	+2.7939384416232999e-18	3.72223194e-07
# Terminated - min grad norm reached after 12 iterations, 0.01 seconds.
#
# v_steepest = [-0.9920618   0.12575124]
#
# v_trust = [-0.9920618   0.12575124]
#
# v_cg = [-0.9920618   0.12575124]
#
#
#  New perturbation : [-1.88241268  5.82136942]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.0002091203927312435
#
# NextGrad = 0.043563953755798836
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0002220678563844558
#
# NextGrad = 0.044814915832363356
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00023993595612403773
#
# NextGrad = 0.046486094007739835
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0002648352809271337
#
# NextGrad = 0.04871945635098981
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0002999457440089337
#
# NextGrad = 0.05170515091756894
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00035015744237432145
#
# NextGrad = 0.05569772225648021
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0004231461973283057
#
# NextGrad = 0.06103757093222058
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0005312003285287137
#
# NextGrad = 0.06817925944493308
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0006943537177164227
#
# NextGrad = 0.07772880985143434
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0009458006192757384
#
# NextGrad = 0.09049289056687769
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 7, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3813594399487314
# |gradf_0| = 0.07709569215085915
# f_1 = 1.380990903038785
# |gradf_1| = 0.06632763533389624
# f_2 = 1.3806643003240695
# |gradf_2| = 7.370326645922707e-05
# f_3 = 1.3806642998729766
# |gradf_3| = 1.1701307560331131e-07

# %%
# %matplotlib notebook
from Visualization.visualization import SubplotAnimationWithDiscontinuities

ani = SubplotAnimationWithDiscontinuities(results, 
                                          parameterMagnitude, 
                                          targetParameter, 
                                          finalSolution, 
                                          differentialParameterAlongV, 
                                          differentialSolutionAlongV)

ani.show()
# Out:
# <img src="data:image/png;base64,..." width="990.9274355497729">
# [6.34927898e-06 2.42606041e-05]

# %% [markdown]
# ## Test with sphere (classical approach)

# %%
from Continuation.StepSizeAdaptiveContinuation import StepSizeAdaptiveContinuation

parameterMagnitude = 8.9

# Instantiate continuation object
continuation = StepSizeAdaptiveContinuation(problem,
                                            initialSolution,
                                            initialParameter,
                                            targetParameter,
                                            differentialSolutionAlongV,
                                            differentialParameterAlongV,
                                            A,
                                            parameterMagnitude)
results = continuation.Traverse()
# Out:
# ========== New continuation problem ==========
#
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+1.3162540412437429e+03	5.68434189e-14
# Terminated - min grad norm reached after 1 iterations, 0.00 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.856017e+03   |grad|: 5.358367e+02
# acc TR+   k:     1     num_inner:     0     f: +1.659884e+03   |grad|: 5.001874e+02   negative curvature
# acc TR+   k:     2     num_inner:     0     f: +1.391985e+03   |grad|: 2.746384e+02   exceeded trust region
# acc       k:     3     num_inner:     0     f: +1.316254e+03   |grad|: 8.038873e-14   maximum inner iterations
# Terminated - min grad norm reached after 3 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.7939262109808660e+03	5.32683282e+02
#     1	+1.4343024231112399e+03	3.35525344e+02
#     2	+1.3197634970154968e+03	6.12272341e+01
#     3	+1.3171274840033277e+03	3.05827955e+01
#     4	+1.3164702141181701e+03	1.52192691e+01
#     5	+1.3163074682139227e+03	7.56669888e+00
#     6	+1.3162672411051935e+03	3.76113581e+00
#     7	+1.3162573021700609e+03	1.86941979e+00
#     8	+1.3162548468139651e+03	9.29155801e-01
#     9	+1.3162542402485424e+03	4.61815749e-01
#    10	+1.3162540904050175e+03	2.29534812e-01
#    11	+1.3162540533883252e+03	1.14084933e-01
#    12	+1.3162540442438863e+03	5.67032565e-02
#    13	+1.3162540419848847e+03	2.81830314e-02
#    14	+1.3162540414268315e+03	1.40077185e-02
#    15	+1.3162540412889725e+03	6.96220980e-03
#    16	+1.3162540412549160e+03	3.46040401e-03
#    17	+1.3162540412465032e+03	1.71991311e-03
#    18	+1.3162540412444246e+03	8.54842702e-04
#    19	+1.3162540412439114e+03	4.24879629e-04
#    20	+1.3162540412437845e+03	2.11176511e-04
#    21	+1.3162540412437534e+03	1.04960360e-04
#    22	+1.3162540412437456e+03	5.21680991e-05
#    23	+1.3162540412437427e+03	3.10225019e-07
# Terminated - min grad norm reached after 24 iterations, 0.02 seconds.
#
# v_trust = [0.66436384 0.74740932]
#
# v_cg = [0.66436384 0.74740932]
#
#
#  New perturbation : [5.91283817 6.65194294]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 0.1
#
# NextObj = 0.00019724120224529074
#
# NextGrad = 0.05245135477988478
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0002677912250736991
#
# NextGrad = 0.059988902406527954
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.0003786000374033094
#
# NextGrad = 0.0702086799706546
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0005561027015774656
#
# NextGrad = 0.08402243898078254
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0008456569278487702
#
# NextGrad = 0.10263322102083187
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0013256900050766518
#
# NextGrad = 0.12763042200313193
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.002132607570158873
#
# NextGrad = 0.1611168796939083
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.003504646997088967
#
# NextGrad = 0.2058746656519871
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.005858934171087071
#
# NextGrad = 0.2655745294702185
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.009926231840392541
#
# NextGrad = 0.3450271221703908
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 1, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.2944342171145655
# |gradf_0| = 0.3382950736226939
# f_1 = 1.2868274348059554
# |gradf_1| = 0.1944795793607138
# f_2 = 1.285309762562322
# |gradf_2| = 0.0971897327832458
# f_3 = 1.284159849744001
# |gradf_3| = 0.0363503060474962
# f_4 = 1.2840349982588115
# |gradf_4| = 0.0008939206479576038
# f_5 = 1.2840349343648585
# |gradf_5| = 3.785839342425291e-05
# f_6 = 1.2840349342238915
# |gradf_6| = 7.92272775062431e-08
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+8.9921808248748562e+02	2.84217094e-14
# Terminated - min grad norm reached after 1 iterations, 0.00 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.033750e+03   |grad|: 3.236764e+02
# acc TR+   k:     1     num_inner:     0     f: +9.377272e+02   |grad|: 1.835395e+02   exceeded trust region
# acc       k:     2     num_inner:     0     f: +8.992181e+02   |grad|: 5.684342e-14   maximum inner iterations
# Terminated - min grad norm reached after 2 iterations, 0.00 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.3075797221227440e+03	4.54081570e+02
#     1	+1.0006362496744632e+03	2.86945524e+02
#     2	+9.0228213612083914e+02	5.28105705e+01
#     3	+8.9998128299780001e+02	2.63900502e+01
#     4	+8.9940709748289100e+02	1.31372848e+01
#     5	+8.9926482711420238e+02	6.53366951e+00
#     6	+8.9922963862870949e+02	3.24867377e+00
#     7	+8.9922093912947389e+02	1.61521247e+00
#     8	+8.9921878862511153e+02	8.03058047e-01
#     9	+8.9921825703776904e+02	3.99266311e-01
#    10	+8.9921812563454353e+02	1.98507999e-01
#    11	+8.9921809315299697e+02	9.86945708e-02
#    12	+8.9921808512389066e+02	4.90691449e-02
#    13	+8.9921808313917791e+02	2.43962857e-02
#    14	+8.9921808264857737e+02	1.21293892e-02
#    15	+8.9921808252730591e+02	6.03051151e-03
#    16	+8.9921808249732885e+02	2.99826055e-03
#    17	+8.9921808248991897e+02	1.49068057e-03
#    18	+8.9921808248808713e+02	7.41139242e-04
#    19	+8.9921808248763432e+02	3.68480940e-04
#    20	+8.9921808248752245e+02	1.83202016e-04
#    21	+8.9921808248749483e+02	9.10847074e-05
#    22	+8.9921808248748789e+02	4.52856585e-05
#    23	+8.9921808248748630e+02	2.25152051e-05
#    24	+8.9921808248748573e+02	1.11941501e-05
#    25	+8.9921808248748562e+02	6.30947954e-08
# Terminated - min grad norm reached after 26 iterations, 0.02 seconds.
#
# v_trust = [0.66436384 0.74740932]
#
# v_cg = [0.66436384 0.74740932]
#
#
#  New perturbation : [5.91283817 6.65194294]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 9.721968742515408e-05
#
# NextGrad = 0.02994296355754147
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00010311986064071021
#
# NextGrad = 0.03083013758247756
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00011125710119608279
#
# NextGrad = 0.03201335553859061
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00012258735823467148
#
# NextGrad = 0.033591483047981735
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00013854875574170755
#
# NextGrad = 0.03569642069071784
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00016134948660129211
#
# NextGrad = 0.038504125709924446
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.00019445055126343647
#
# NextGrad = 0.04224928660284947
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0002433851426077993
#
# NextGrad = 0.047244848942606686
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.00031716341994325603
#
# NextGrad = 0.05390798414615041
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.000430700218375657
#
# NextGrad = 0.0627946107366825
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 2, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3004780982252404
# |gradf_0| = 0.05386664586165196
# f_1 = 1.300360082314692
# |gradf_1| = 0.05208286574073759
# f_2 = 1.3001605799724405
# |gradf_2| = 7.111114890996811e-05
# f_3 = 1.3001605794599531
# |gradf_3| = 1.5289620150757796e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+5.6139212373122837e+02	6.35528743e-14
# Terminated - min grad norm reached after 1 iterations, 0.00 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.296718e+03   |grad|: 1.198554e+02
# acc TR+   k:     1     num_inner:     0     f: +1.228142e+03   |grad|: 2.423811e+02   negative curvature
# acc TR+   k:     2     num_inner:     0     f: +1.016644e+03   |grad|: 3.693211e+02   negative curvature
# acc       k:     3     num_inner:     0     f: +6.690693e+02   |grad|: 2.639830e+02   negative curvature
# acc       k:     4     num_inner:     0     f: +5.613921e+02   |grad|: 5.684342e-14   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+5.6210830254931113e+02	2.32401206e+01
#     1	+5.6156621128776828e+02	1.14621883e+01
#     2	+5.6143436985858102e+02	5.64696449e+00
#     3	+5.6140237149415623e+02	2.78128405e+00
#     4	+5.6139460931420012e+02	1.36976850e+00
#     5	+5.6139272659201458e+02	6.74593422e-01
#     6	+5.6139226995004924e+02	3.32227329e-01
#     7	+5.6139215919532546e+02	1.63616915e-01
#     8	+5.6139213233273210e+02	8.05788284e-02
#     9	+5.6139212581744709e+02	3.96838384e-02
#    10	+5.6139212423722222e+02	1.95436821e-02
#    11	+5.6139212385395274e+02	9.62496386e-03
#    12	+5.6139212376099408e+02	4.74014715e-03
#    13	+5.6139212373844782e+02	2.33444980e-03
#    14	+5.6139212373297948e+02	1.14968074e-03
#    15	+5.6139212373165299e+02	5.66200140e-04
#    16	+5.6139212373133137e+02	2.78844889e-04
#    17	+5.6139212373125326e+02	1.37326833e-04
#    18	+5.6139212373123451e+02	6.76313601e-05
#    19	+5.6139212373122984e+02	3.33074081e-05
#    20	+5.6139212373122837e+02	5.00632379e-07
# Terminated - min grad norm reached after 21 iterations, 0.01 seconds.
#
# v_trust = [0.66436384 0.74740932]
#
# v_cg = [0.66436384 0.74740932]
#
#
#  New perturbation : [5.91283822 6.65194289]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00010275640991919133
#
# NextGrad = 0.030737611761331083
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00010899272655473524
#
# NextGrad = 0.031648498996663645
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00011759356474172478
#
# NextGrad = 0.03286333547680892
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00012956934032204437
#
# NextGrad = 0.03448362224346771
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0001464401175907959
#
# NextGrad = 0.036644773603278766
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00017053990655724327
#
# NextGrad = 0.03952743109120285
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0002055269042722241
# NextGrad = 0.04337252703313603
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.00025724955552330897
#
# NextGrad = 0.04850132749443408
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0003352313305728938
#
# NextGrad = 0.0553420873504785
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.00045523664187530066
#
# NextGrad = 0.06446547965866202
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 3, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3168921456213436
# |gradf_0| = 0.0553011983112879
# f_1 = 1.3167650733055303
# |gradf_1| = 0.053240496735659566
# f_2 = 1.3165565392227838
# |gradf_2| = 7.200943452474505e-05
# f_3 = 1.3165565386999294
# |gradf_3| = 1.5976991507705797e-07
# Computing gradient of cost function...
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00010860251878708205
#
# NextGrad = 0.03155426608901758
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00011519384791536247
#
# NextGrad = 0.03248953404257476
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00012428431101274562
#
# NextGrad = 0.03373687897489228
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00013694185210288978
#
# NextGrad = 0.03540051142086132
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0001547730829487559
#
# NextGrad = 0.037619458122105195
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0001802449069676637
#
# NextGrad = 0.04057917640814487
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.000217223811592282
#
# NextGrad = 0.044527017555548616
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.00027189123225879186
#
# NextGrad = 0.049792801178561226
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.00035431283588671647
#
# NextGrad = 0.056816175427600195
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0004811504166228886
#
# NextGrad = 0.06618297898239589
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 4, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3335752164970514
# |gradf_0| = 0.056775763597532704
# f_1 = 1.333438536978671
# |gradf_1| = 0.05443258640792236
# f_2 = 1.3332205072444507
# |gradf_2| = 7.453376522127365e-05
# f_3 = 1.3332205066864447
# |gradf_3| = 1.754835089663402e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+1.2337020621871415e+02	2.00971835e-14
# Terminated - min grad norm reached after 1 iterations, 0.00 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +3.032718e+02   |grad|: 2.154907e+02
# acc TR+   k:     1     num_inner:     0     f: +2.272109e+02   |grad|: 1.862837e+02   exceeded trust region
# acc TR+   k:     2     num_inner:     0     f: +1.367453e+02   |grad|: 7.536377e+01   exceeded trust region
# acc       k:     3     num_inner:     0     f: +1.233702e+02   |grad|: 2.009718e-14   maximum inner iterations
# Terminated - min grad norm reached after 3 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.2347203007381998e+02	6.67762773e+00
#     1	+1.2339442228919756e+02	3.25677497e+00
#     2	+1.2337596292180120e+02	1.58793230e+00
#     3	+1.2337157457823412e+02	7.74189633e-01
#     4	+1.2337053146788588e+02	3.77446897e-01
#     5	+1.2337028352765208e+02	1.84019030e-01
#     6	+1.2337022459436066e+02	8.97158601e-02
#     7	+1.2337021058644038e+02	4.37396821e-02
#     8	+1.2337020725688339e+02	2.13246542e-02
#     9	+1.2337020646547768e+02	1.03965289e-02
#    10	+1.2337020627736764e+02	5.06867839e-03
#    11	+1.2337020623265553e+02	2.47116136e-03
#    12	+1.2337020622202789e+02	1.20477923e-03
#    13	+1.2337020621950180e+02	5.87372812e-04
#    14	+1.2337020621890136e+02	2.86365179e-04
#    15	+1.2337020621875864e+02	1.39613231e-04
#    16	+1.2337020621872475e+02	6.80664256e-05
#    17	+1.2337020621871669e+02	3.31848083e-05
#    18	+1.2337020621871474e+02	1.61787767e-05
#    19	+1.2337020621871430e+02	7.88773025e-06
#    20	+1.2337020621871415e+02	1.96631056e-07
# Terminated - min grad norm reached after 21 iterations, 0.01 seconds.
#
# v_trust = [0.66436384 0.74740932]
#
# v_cg = [0.66436384 0.74740932]
#
#
#  New perturbation : [5.91283815 6.65194295]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00011477115626568057
#
# NextGrad = 0.03239318994065549
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0001217371733457373
#
# NextGrad = 0.03335351527542582
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.0001313444011294962
#
# NextGrad = 0.034634270785939565
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00014472150435418385
#
# NextGrad = 0.0363424515814783
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00016356644669390796
#
# NextGrad = 0.03862079688558027
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0001904864043607013
#
# NextGrad = 0.04165971310074008
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0002295677242385441
#
# NextGrad = 0.04571314792680832
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.00028734333118562994
#
# NextGrad = 0.05111971068404861
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.00037445121180401664
#
# NextGrad = 0.05833075667891925
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0005085003926394993
#
# NextGrad = 0.0679477065713762
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 5, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3505244742785352
# |gradf_0| = 0.0582908513191382
# f_1 = 1.3503776201940534
# |gradf_1| = 0.05566047053814817
# f_2 = 1.3501496041157208
# |gradf_2| = 7.709428297452035e-05
# f_3 = 1.350149603521012
# |gradf_3| = 1.927967944938861e-07
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+2.3174247462457060e+01	7.10542736e-15
# Terminated - min grad norm reached after 1 iterations, 0.00 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +4.008165e+01   |grad|: 6.664444e+01
# acc TR+   k:     1     num_inner:     0     f: +2.422549e+01   |grad|: 1.711209e+01   exceeded trust region
# acc       k:     2     num_inner:     0     f: +2.317425e+01   |grad|: 7.105427e-15   maximum inner iterations
# Terminated - min grad norm reached after 2 iterations, 0.00 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+2.3833559085002145e+02	1.17750246e+02
#     1	+1.3300104759819970e+02	1.36549837e+02
#     2	+3.9989419432110189e+01	6.64740876e+01
#     3	+2.6556390458077296e+01	3.05649272e+01
#     4	+2.3757103484290496e+01	1.27525660e+01
#     5	+2.3271218963821021e+01	5.20615158e+00
#     6	+2.3190280723999699e+01	2.11723253e+00
#     7	+2.3176895642439444e+01	8.60481951e-01
#     8	+2.3174684781416410e+01	3.49678464e-01
#     9	+2.3174319679010072e+01	1.42098140e-01
#    10	+2.3174259387862790e+01	5.77439708e-02
#    11	+2.3174249431745054e+01	2.34652231e-02
#    12	+2.3174247787653101e+01	9.53548303e-03
#    13	+2.3174247516157930e+01	3.87490180e-03
#    14	+2.3174247471324882e+01	1.57463066e-03
#    15	+2.3174247463921439e+01	6.39877303e-04
#    16	+2.3174247462698879e+01	2.60024762e-04
#    17	+2.3174247462496993e+01	1.05665378e-04
#    18	+2.3174247462463654e+01	4.29388800e-05
#    19	+2.3174247462458155e+01	1.74489266e-05
#    20	+2.3174247462457238e+01	7.09066092e-06
#    21	+2.3174247462457092e+01	2.88140775e-06
#    22	+2.3174247462457064e+01	1.17090786e-06
#    23	+2.3174247462457053e+01	4.75817839e-07
# Terminated - min grad norm reached after 24 iterations, 0.02 seconds.
#
# v_trust = [0.66436384 0.74740932]
#
# v_cg = [0.66436383 0.74740932]
#
#
#  New perturbation : [5.91283815 6.65194295]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00012127481014090336
#
# NextGrad = 0.03325459051624667
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00012863597071066657
#
# NextGrad = 0.03424065785611816
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.0001387881797665358
#
# NextGrad = 0.03555573667701364
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00015292414274870048
#
# NextGrad = 0.03730968261922134
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00017283817178959104
#
# NextGrad = 0.03964904859741904
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00020128539084174335
#
# NextGrad = 0.04276932490611759
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0002425840393596168
#
# NextGrad = 0.04693123517783427
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0003036377733043327
#
# NextGrad = 0.052482417276918075
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0003956882327276201
#
# NextGrad = 0.05988625104921642
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0005373435312923114
#
# NextGrad = 0.06976016000725781
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 6, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3677364702847525
# |gradf_0| = 0.059846882659456174
# f_1 = 1.3675788620772973
# |gradf_1| = 0.05692568812921083
# f_2 = 1.3673403393335812
# |gradf_2| = 7.968446370388461e-05
# f_3 = 1.3673403387006873
# |gradf_3| = 2.1184903565875478e-07
# Computing gradient of cost function...
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 7.456138347028407e-05
#
# NextGrad = 0.028010070173915377
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 7.910178238734744e-05
#
# NextGrad = 0.028730919516271214
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 8.536437397288488e-05
#
# NextGrad = 0.02969655073240429
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 9.408556116308198e-05
#
# NextGrad = 0.030991286358125876
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00010637347170505684
#
# NextGrad = 0.03272887689735627
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0001239300561919343
#
# NextGrad = 0.03506263625862765
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0001494235709287306
#
# NextGrad = 0.03819877720340782
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.00018712092696904215
#
# NextGrad = 0.04241381139621928
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0002439719833613463
#
# NextGrad = 0.04807719655639592
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.00033148373022529043
#
# NextGrad = 0.05568096367809765
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 7, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3809085457083716
# |gradf_0| = 0.046961161459711936
# f_1 = 1.3808105440713814
# |gradf_1| = 0.04457478155845639
# f_2 = 1.380664300106505
# |gradf_2| = 4.8084025057701705e-05
# f_3 = 1.3806642998729763
# |gradf_3| = 1.0481682530695334e-07

# %%
# %matplotlib notebook
from Visualization.visualization import SubplotAnimationCircleWithDiscontinuities

ani = SubplotAnimationCircleWithDiscontinuities(results, 
                                          parameterMagnitude, 
                                          targetParameter, 
                                          finalSolution, 
                                          differentialParameterAlongV, 
                                          differentialSolutionAlongV)

ani.show()
# Out:
# <img src="data:image/png;base64,..." width="990.9274355497729">

# %% [markdown]
# ##############################################################################################################################
# ##############################################################################################################################

# %% [markdown]
# ## Third test case, $n=3, p=2$, $C^0$ eigenvalues with ill region:
# We consider a mapping $A$ defined for any $\mu=(\mu_1, \mu_2)\in\Rset^2$ by
#
# $$
# A(\mu) = \begin{pmatrix} \lambda_1(\mu) & -1 & 0 \\ -1 & \lambda_2(\mu) & 1 \\ 0 & 1 & \lambda_3(\mu) \end{pmatrix},
# $$
#
# with
# $
# \begin{align}
# \lambda_0(\mu) =
# \begin{cases}
#     \exp(\mu_1 + \mu_2) \quad &\text{if } \mu_1 + \mu_2 \le -\varepsilon,\\
#     ax^2 + bx + c &\text{if } -\varepsilon \le \mu_1 + \mu_2 \le \varepsilon\\
#     \exp(\frac{1}{\alpha(\mu_1 + \mu_2)}) &\text{if } \mu_1 + \mu_2 \ge \varepsilon.
# \end{cases}
# \end{align},$
#
# for suited $a,b,c$ and for given $\alpha, \varepsilon \in\Rset$

# %%
alpha = 0.2
eps = 3.

def A(mu):
    
    b = 1.0 / (2 * eps) * (np.exp(1.0 / (alpha*eps)) - np.exp(-eps))
    a = b / (2 * eps)
    c = (1.0 / 4) * (np.exp(1.0 / (alpha*eps)) + 3 * np.exp(-eps))
    
    if mu[0] + mu[1] <= -eps:
        lambda0 = 1 + np.exp((mu[0] + mu[1]))
    elif mu[0] + mu[1] >= eps:
        lambda0 = 1 + np.exp(1.0 / (alpha * (mu[0] + mu[1])))
    else:
        lambda0 = a * (mu[0] + mu[1]) ** 2 + b * (mu[0] + mu[1]) + c + 1
        
    if mu[0] - mu[1] <= -eps:
        lambda1 = 2 + np.exp((mu[0] - mu[1]))
    elif mu[0] + mu[1] >= eps:
        lambda1 = 2 + np.exp(1.0 / (alpha * (mu[0] - mu[1])))
    else:
        lambda1 = a * (mu[0] + mu[1]) ** 2 + b * (mu[0] + mu[1]) + c + 2 

        
    if 3 * mu[0] + mu[1] <= -eps:
        lambda2 = 3 + np.exp(3 * mu[0] + mu[1])
    elif 3 * mu[0] + mu[1] >= eps:
        lambda2 = 3 + np.exp(1.0 / (alpha * (3 * mu[0] + mu[1])))
    else:
        lambda2 = a * (3 * mu[0] + mu[1]) ** 2 + b * (3 * mu[0] + mu[1]) + c + 3 
        
    return np.array([[lambda0, -1, 0], [-1, lambda1, -1], [0, -1, lambda2]])

def DA(mu, v):
    tol = 1.0e-15
    
    b = 1.0 / (2 * eps) * (np.exp(1.0 / (alpha*eps)) - np.exp(-eps))
    a = b / (2 * eps)
    c = (1.0 / 4) * (np.exp(1.0 / (alpha*eps)) + 3 * np.exp(-eps))
    
    if np.abs(mu[0] + mu[1]) <= eps:
        Dlambda0 = np.nan
    elif mu[0] + mu[1] <= -eps:
        Dlambda0 = (v[0] + v[1]) * np.exp((mu[0] + mu[1]))
    elif mu[0] + mu[1] >= eps:
        Dlambda0 = (-1.0 / (alpha * (mu[0] + mu[1])**2)) * (v[0] + v[1]) * np.exp(1.0 / (alpha * (mu[0] + mu[1])))
    else:
        Dlambda0 = 2 * a * (mu[0] + mu[1]) + b
        
    if np.abs(mu[0] - mu[1]) <= eps:
        Dlambda1 = np.nan    
    elif mu[0] - mu[1] <= -eps:
        Dlambda1 = (v[0] - v[1]) * np.exp((mu[0] - mu[1]))
    elif mu[0] + mu[1] >= eps:
        Dlambda1 = (-1.0 / (alpha * (mu[0] - mu[1])**2)) * (v[0] - v[1]) * np.exp(1.0 / (alpha * (mu[0] - mu[1])))
    else:
        Dlambda1 = 2 * a * (mu[0] - mu[1]) + b

    if np.abs(3 * mu[0] + mu[1]) <= eps:
        Dlambda2 = np.nan
    if 3 * mu[0] + mu[1] <= -eps:
        Dlambda2 = (3 * v[0] + v[1]) * np.exp((3 * mu[0] + mu[1]))
    elif 3 * mu[0] + mu[1] >= eps:
        Dlambda2 = (-1.0 / (alpha * (3 * mu[0] + mu[1])**2)) * (3 * v[0] + v[1]) * np.exp(1.0 / (alpha * (3 * mu[0] + mu[1])))
    else:
        Dlambda2 = 2 * a * (3 * mu[0] + mu[1]) + b

    
    return np.array([[Dlambda0, 0, 0], [0, Dlambda1, 0], [0, 0, Dlambda2]])

# %%
# Define derivatives of gradient wrt solution/parameter
def differentialSolutionAlongV(x, mu, xi):
    return A(mu) @ xi - 2 * (x.T @ A(mu) @ xi) * x - (x.T @ A(mu) @ x) * xi

def differentialParameterAlongV(x, mu, v):
    return (np.eye(solutionSpaceDimension) - np.outer(x, x)) @ DA(mu, v) @ x

# %%
initialParameter = np.array([-10., 22])
targetParameter = np.array([30., 40.1])

B = A(initialParameter)
C = A(targetParameter)

w, v = np.linalg.eig(B)
wC, vC = np.linalg.eig(C)

initialSolution = v[:, np.argmin(w)]
finalSolution = vC[:, np.argmin(wC)]

# %%
def WriteMatrixInEuclideanBasisAtGivenPoint(matrixVectorFunction, x, mu, dimension):
    spaceDimension = len(x)
    indices = np.arange(dimension)
    A = np.zeros((spaceDimension, dimension))

    for index in indices:
        v = np.zeros(dimension)
        v[index] = 1

        A[:, index] = matrixVectorFunction(x, mu, v)

    return A

# %%
np.linalg.matrix_rank(WriteMatrixInEuclideanBasisAtGivenPoint(differentialParameterAlongV, initialSolution, initialParameter, 2))
# Out:
# 2

# %%
from pymanopt.core.problem import Problem 

def cost(S):
    return np.dot(S[0], A(S[1]) @ S[0])

problem = Problem(productManifold, cost=cost)

# %%
from Continuation.PathAdaptiveContinuation import PathAdaptiveMultiParameterContinuation

parameterMagnitude = 1e-2

# Instantiate continuation object
continuation = PathAdaptiveMultiParameterContinuation(problem, 
                                                      initialSolution,
                                                      initialParameter,
                                                      targetParameter,
                                                      differentialSolutionAlongV, 
                                                      differentialParameterAlongV,
                                                      A,
                                                      parameterMagnitude)
results = continuation.Traverse()
# Out:
# Compiling cost function...
# Computing gradient of cost function...
#
#
#
# ========== New continuation problem ==========
#
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+9.3473290871521124e+02	2.58661785e+03
#     2	+8.3871063889476750e+02	1.02999319e+03
#     3	+8.2197907932115902e+02	3.14933529e+02
#     4	+8.2035739275831236e+02	7.05064587e+01
#     5	+8.2027445218911373e+02	1.28208249e+01
#     6	+8.2027356380341087e+02	1.06227657e+01
#     7	+8.2027163224495996e+02	9.25277549e-01
#     8	+8.2027161748626384e+02	2.03340466e-02
#     9	+8.2027161747913351e+02	2.14590662e-04
#    10	+8.2027161747913283e+02	2.05876726e-05
#    11	+8.2027161747913283e+02	9.94791344e-05
# Terminated - min stepsize reached after 11 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +3.226771e+03   |grad|: 1.030208e+04
# acc TR+   k:     1     num_inner:     0     f: +8.629244e+02   |grad|: 1.562564e+03   exceeded trust region
# acc       k:     2     num_inner:     0     f: +8.202763e+02   |grad|: 1.650254e+01   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +8.202716e+02   |grad|: 1.264653e-03   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +8.202716e+02   |grad|: 7.604754e-12   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+8.4293074889035979e+03	1.23348034e+04
#     1	+8.9291728961550257e+02	2.03402003e+03
#     2	+8.3317338051269076e+02	8.62190795e+02
#     3	+8.2249983137547883e+02	3.59007403e+02
#     4	+8.2065282552488566e+02	1.48600003e+02
#     5	+8.2033660756934250e+02	6.13739475e+01
#     6	+8.2028268207996496e+02	2.53266577e+01
#     7	+8.2027350018998118e+02	1.04477327e+01
#     8	+8.2027193776156253e+02	4.30928397e+00
#     9	+8.2027167195977040e+02	1.77730953e+00
#    10	+8.2027162674603539e+02	7.33011339e-01
#    11	+8.2027161905536491e+02	3.02311074e-01
#    12	+8.2027161774723641e+02	1.24679675e-01
#    13	+8.2027161752473489e+02	5.14205295e-02
#    14	+8.2027161748688923e+02	2.12068971e-02
#    15	+8.2027161748045205e+02	8.74616345e-03
#    16	+8.2027161747935725e+02	3.60709848e-03
#    17	+8.2027161747917080e+02	1.48764185e-03
#    18	+8.2027161747913919e+02	6.13534188e-04
#    19	+8.2027161747913374e+02	2.53034154e-04
#    20	+8.2027161747913283e+02	1.04356505e-04
#    21	+8.2027161747913271e+02	4.30387749e-05
#    22	+8.2027161747913271e+02	3.98776878e-05
#    23	+8.2027161747913260e+02	3.84132301e-05
# Terminated - min stepsize reached after 24 iterations, 0.02 seconds.
#
# v_steepest = [ 0.99627383 -0.08624644]
#
# v_trust = [ 0.99627383 -0.08624644]
#
# v_cg = [ 0.99627383 -0.08624644]
#
#
#  New perturbation : [ 11.27011635 -10.45060455]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 0.1
#
# NextObj = 9.419819880784885e-06
#
# NextGrad = 0.018086584162335106
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 1.2419201090629883e-05
#
# NextGrad = 0.01868506426901432
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 1.7074763623003975e-05
#
# NextGrad = 0.01958466683522453
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 2.4449077385080287e-05
#
# NextGrad = 0.020940436419391986
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 3.635593750939137e-05
#
# NextGrad = 0.02297450708988987
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 5.591952236083664e-05
#
# NextGrad = 0.0259902819009128
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 8.855996171908131e-05
#
# NextGrad = 0.030383554208077198
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.00014373389801369818
#
# NextGrad = 0.036655586068831625
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0002380126586516429
#
# NextGrad = 0.045438419168126826
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0004005306877139514
#
# NextGrad = 0.05754102274515406
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 1, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.094456479916555
# |gradf_0| = 0.9970936495080021
# f_1 = 1.050400709453942
# |gradf_1| = 0.6997914752597777
# f_2 = 1.0342244109911196
# |gradf_2| = 0.36343924383639364
# f_3 = 1.029779402787406
# |gradf_3| = 0.35346443116237297
# f_4 = 1.0177617916594688
# |gradf_4| = 0.006717887554374863
# f_5 = 1.0177586402954466
# |gradf_5| = 0.0006148706340199286
# f_6 = 1.017758613147966
# |gradf_6| = 1.2450329337749209e-06
# f_7 = 1.0177586131478042
# |gradf_7| = 4.809742775595539e-08
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+7.8815933178062153e+02	3.14753867e+00
#     2	+7.8810669688613689e+02	2.29617697e+00
#     3	+7.8807945913389972e+02	1.70479063e+00
#     4	+7.8805991978317343e+02	1.09106692e+00
#     5	+7.8804890293422295e+02	4.76306414e-01
#     6	+7.8804632488358106e+02	3.03952928e-02
#     7	+7.8804632306832377e+02	2.76566130e-02
#     8	+7.8804631731700943e+02	1.61559050e-02
#     9	+7.8804631691679492e+02	1.50314484e-02
#    10	+7.8804631556435231e+02	1.03663923e-02
#    11	+7.8804631435061583e+02	1.06320382e-03
#    12	+7.8804631434056046e+02	4.99477902e-04
#    13	+7.8804631433938164e+02	3.82371361e-04
#    14	+7.8804631433799705e+02	1.57803326e-04
#    15	+7.8804631433772624e+02	3.43677841e-05
#    16	+7.8804631433771374e+02	8.77646342e-06
#    17	+7.8804631433771328e+02	6.82753147e-06
#    18	+7.8804631433771306e+02	4.84268537e-06
#    19	+7.8804631433771283e+02	3.38402835e-06
#    20	+7.8804631433771283e+02	4.40835939e-07
# Terminated - min grad norm reached after 20 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +8.062100e+02   |grad|: 3.285808e+01
# acc TR+   k:     1     num_inner:     0     f: +7.954167e+02   |grad|: 2.376779e+01   exceeded trust region
# acc       k:     2     num_inner:     0     f: +7.880830e+02   |grad|: 1.790514e+00   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +7.880463e+02   |grad|: 2.977502e-03   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +7.880463e+02   |grad|: 6.065819e-09   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+8.2036633305515659e+02	3.29281404e+01
#     1	+7.9617625748602222e+02	2.41291842e+01
#     2	+7.8973315938392375e+02	1.18811344e+01
#     3	+7.8827077439148320e+02	4.41542123e+00
#     4	+7.8807231201494733e+02	1.50773504e+00
#     5	+7.8804924929649394e+02	5.06942642e-01
#     6	+7.8804664401968648e+02	1.69935337e-01
#     7	+7.8804635132465842e+02	5.69225071e-02
#     8	+7.8804631848574763e+02	1.90628852e-02
#     9	+7.8804631480285457e+02	6.38355574e-03
#    10	+7.8804631438986962e+02	2.13760078e-03
#    11	+7.8804631434356111e+02	7.15792571e-04
#    12	+7.8804631433836857e+02	2.39688199e-04
#    13	+7.8804631433778627e+02	8.02612172e-05
#    14	+7.8804631433772101e+02	2.68760045e-05
#    15	+7.8804631433771374e+02	8.99960874e-06
#    16	+7.8804631433771283e+02	3.01357869e-06
#    17	+7.8804631433771283e+02	2.01134775e-06
#    18	+7.8804631433771283e+02	6.73513148e-07
# Terminated - min grad norm reached after 19 iterations, 0.01 seconds.
#
# v_steepest = [0.98736852 0.15844056]
#
# v_trust = [0.98736852 0.15844055]
#
# v_cg = [0.98736852 0.15844053]
#
#
#  New perturbation : [0.74570265 0.39073519]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.0002556885690760957
#
# NextGrad = 0.056362509366720714
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0002730358833620272
#
# NextGrad = 0.05805006578039931
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00029705260117074417
#
# NextGrad = 0.06030983247618375
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0003306516662160419
#
# NextGrad = 0.06333817528908235
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00037825343831743297
#
# NextGrad = 0.06739939718851914
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.000446705254353974
#
# NextGrad = 0.07284878077705051
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0005468316710195431
#
# NextGrad = 0.08016281845500657
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0006960773005011411
#
# NextGrad = 0.08997866788720683
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0009230530286734595
#
# NextGrad = 0.10314567017577166
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0012754114936452954
#
# NextGrad = 0.12079297083065939
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 2, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.0009243669774555
# |gradf_0| = 0.10153498875240272
# f_1 = 1.0002682534142646
# |gradf_1| = 0.0633724613327415
# f_2 = 1.0000002811682158
# |gradf_2| = 0.0008259207049698798
# f_3 = 1.0000002162635375
# |gradf_3| = 4.984837034535286e-06
# f_4 = 1.000000216261882
# |gradf_4| = 1.558999165912717e-08
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+7.5040352380471802e+02	5.46654051e+00
#     2	+7.5019868287873373e+02	2.16414522e+00
#     3	+7.5016472231056957e+02	7.30919933e-01
#     4	+7.5016429191033808e+02	6.93271654e-01
#     5	+7.5016275914015750e+02	5.41185539e-01
#     6	+7.5016056057931803e+02	1.53188130e-01
#     7	+7.5016040568111930e+02	6.68316596e-02
#     8	+7.5016036940225035e+02	4.22226817e-03
#     9	+7.5016036938798572e+02	4.00974700e-03
#    10	+7.5016036933713519e+02	3.13721994e-03
#    11	+7.5016036926260790e+02	8.38243584e-04
#    12	+7.5016036925912272e+02	5.24654457e-04
#    13	+7.5016036925756384e+02	2.89975442e-04
#    14	+7.5016036925689104e+02	3.96555212e-05
#    15	+7.5016036925688343e+02	2.53633805e-05
#    16	+7.5016036925687922e+02	1.14652852e-05
#    17	+7.5016036925687899e+02	1.10307083e-05
#    18	+7.5016036925687831e+02	5.97508265e-06
#    19	+7.5016036925687808e+02	1.02487890e-06
#    20	+7.5016036925687808e+02	6.75539404e-07
# Terminated - min grad norm reached after 20 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +8.249177e+02   |grad|: 9.073402e+00
# acc TR+   k:     1     num_inner:     0     f: +8.203976e+02   |grad|: 1.539195e+01   negative curvature
# acc TR+   k:     2     num_inner:     0     f: +8.050721e+02   |grad|: 3.131605e+01   negative curvature
# acc       k:     3     num_inner:     0     f: +7.664915e+02   |grad|: 3.694242e+01   negative curvature
# acc       k:     4     num_inner:     0     f: +7.513968e+02   |grad|: 1.226975e+01   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +7.501604e+02   |grad|: 5.455553e-02   maximum inner iterations
# acc       k:     6     num_inner:     0     f: +7.501604e+02   |grad|: 2.621780e-06   maximum inner iterations
# acc       k:     7     num_inner:     0     f: +7.501604e+02   |grad|: 1.598721e-14   maximum inner iterations
# Terminated - min grad norm reached after 7 iterations, 0.02 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+7.8382668452744758e+02	4.10936945e+01
#     1	+7.5549842663841275e+02	2.40004819e+01
#     2	+7.5078308490698180e+02	8.64687062e+00
#     3	+7.5020531337369960e+02	2.34355674e+00
#     4	+7.5016331989206446e+02	6.01309727e-01
#     5	+7.5016056023249621e+02	1.53021876e-01
#     6	+7.5016038158294759e+02	3.88782286e-02
#     7	+7.5016037005191333e+02	9.87403667e-03
#     8	+7.5016036930814971e+02	2.50750652e-03
#     9	+7.5016036926018455e+02	6.36764834e-04
#    10	+7.5016036925709136e+02	1.61701277e-04
#    11	+7.5016036925689195e+02	4.10626679e-05
#    12	+7.5016036925687899e+02	1.04275122e-05
#    13	+7.5016036925687808e+02	2.64797701e-06
#    14	+7.5016036925687808e+02	6.72430946e-07
# Terminated - min grad norm reached after 15 iterations, 0.01 seconds.
#
# v_steepest = [0.99389363 0.1103424 ]
#
# v_trust = [0.99389363 0.11034239]
#
# v_cg = [0.99389364 0.11034238]
#
#
#  New perturbation : [0.99266166 0.37896545]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00024320831369539775
#
# NextGrad = 0.052920375192808976
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0002597925833575099
#
# NextGrad = 0.054569121054169334
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.0002827569888450565
#
# NextGrad = 0.056774343775752786
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0003148908939858419
#
# NextGrad = 0.05972549040914577
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00036042876661901424
#
# NextGrad = 0.0636768550985724
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00042593254893330545
#
# NextGrad = 0.0689694271920136
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0005217795517136192
#
# NextGrad = 0.07605965946736064
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0006646994904836445
#
# NextGrad = 0.08555721933282308
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0008821393910658504
#
# NextGrad = 0.09827455165663379
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0012198259225203456
#
# NextGrad = 0.1152921629760475
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 3, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 0.983504605317799
# |gradf_0| = 0.09721264026801595
# f_1 = 0.9828408692930061
# |gradf_1| = 0.0570745689825943
# f_2 = 0.9826214696129583
# |gradf_2| = 0.000778858583293247
# f_3 = 0.9826214141658942
# |gradf_3| = 4.263251113256517e-06
# f_4 = 0.9826214141646059
# |gradf_4| = 7.059344187571589e-09
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+7.0564943452571890e+02	5.99792308e+00
#     2	+7.0564244147740874e+02	5.86000554e+00
#     3	+7.0561554569979944e+02	5.40899310e+00
#     4	+7.0552670214125760e+02	3.52440554e+00
#     5	+7.0546999910664249e+02	1.27856463e+00
#     6	+7.0546513850371730e+02	8.39322060e-01
#     7	+7.0546181969669624e+02	2.66450020e-01
#     8	+7.0546145312354327e+02	3.09913034e-02
#     9	+7.0546144819258461e+02	4.31124279e-03
#    10	+7.0546144812842249e+02	2.51608764e-03
#    11	+7.0546144812431407e+02	2.35498398e-03
#    12	+7.0546144811020588e+02	1.68850125e-03
#    13	+7.0546144810711530e+02	1.50356367e-03
#    14	+7.0546144809798147e+02	7.18294119e-04
#    15	+7.0546144809656926e+02	4.96190615e-04
#    16	+7.0546144809529210e+02	4.74662386e-05
#    17	+7.0546144809528596e+02	3.28403919e-05
#    18	+7.0546144809528028e+02	2.86774698e-06
#    19	+7.0546144809528028e+02	1.38873746e-06
# Terminated - min stepsize reached after 19 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +7.166288e+02   |grad|: 4.341547e+01
# acc TR+   k:     1     num_inner:     0     f: +7.061259e+02   |grad|: 1.126177e+01   exceeded trust region
# acc       k:     2     num_inner:     0     f: +7.054614e+02   |grad|: 1.277178e-02   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +7.054614e+02   |grad|: 8.972274e-08   maximum inner iterations
# Terminated - min grad norm reached after 3 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+7.5283439749859087e+02	5.61234195e+01
#     1	+7.1239750245393020e+02	3.41697495e+01
#     2	+7.0588581591497450e+02	8.94786159e+00
#     3	+7.0547213955665620e+02	1.42822167e+00
#     4	+7.0546168850607023e+02	2.14278199e-01
#     5	+7.0546145344911156e+02	3.19788640e-02
#     6	+7.0546144821436008e+02	4.76929216e-03
#     7	+7.0546144809792838e+02	7.11216890e-04
#     8	+7.0546144809533916e+02	1.06058100e-04
#     9	+7.0546144809528164e+02	1.58155639e-05
#    10	+7.0546144809528039e+02	2.35844294e-06
#    11	+7.0546144809528039e+02	1.65505320e-06
#    12	+7.0546144809528039e+02	1.16144471e-06
#    13	+7.0546144809528039e+02	8.15051612e-07
# Terminated - min grad norm reached after 14 iterations, 0.01 seconds.
#
# v_steepest = [0.99434266 0.10621995]
#
# v_trust = [0.99434266 0.10621996]
#
# v_cg = [0.99434266 0.10621997]
#
#
#  New perturbation : [1.14182619 0.52808278]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00022728618951617374
#
# NextGrad = 0.048991266147880394
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00024284095232107727
#
# NextGrad = 0.050555347972703946
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00026438200351408536
#
# NextGrad = 0.05264551364622084
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0002945280109590831
#
# NextGrad = 0.055439810457496005
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0003372551978388927
#
# NextGrad = 0.05917676654059061
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00039872669926399595
#
# NextGrad = 0.06417568603905852
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0004886912504564744
#
# NextGrad = 0.07086345177372344
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0006228683807109059
#
# NextGrad = 0.07980983568666
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0008270524468213525
#
# NextGrad = 0.091774025581456
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.001144223505771813
#
# NextGrad = 0.10776603686938702
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 4, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 0.9668094387442809
# |gradf_0| = 0.09108032390434122
# f_1 = 0.9666603321136257
# |gradf_1| = 0.09784197888306762
# f_2 = 0.965981497371151
# |gradf_2| = 0.0010236375777014526
# f_3 = 0.9659813985592146
# |gradf_3| = 9.769812142389122e-06
# f_4 = 0.965981398550604
# |gradf_4| = 3.2248907308279573e-08
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+6.5214957668108127e+02	3.10023867e+00
#     2	+6.5213167382818654e+02	1.95329711e+00
#     3	+6.5212303563428475e+02	1.01116385e+00
#     4	+6.5212030083995091e+02	3.70824885e-01
#     5	+6.5212003317152107e+02	2.25661378e-01
#     6	+6.5211995303722574e+02	1.58096937e-01
#     7	+6.5211987588637771e+02	5.88715094e-03
#     8	+6.5211987579696370e+02	2.39381736e-03
#     9	+6.5211987578046819e+02	6.27315760e-04
#    10	+6.5211987577983973e+02	4.36104210e-04
#    11	+6.5211987577925447e+02	3.01290802e-05
#    12	+6.5211987577925288e+02	1.89694220e-05
#    13	+6.5211987577925208e+02	8.17618047e-06
#    14	+6.5211987577925197e+02	7.56883613e-06
#    15	+6.5211987577925186e+02	2.15027259e-06
#    16	+6.5211987577925174e+02	2.12606551e-06
#    17	+6.5211987577925174e+02	2.19896238e-06
# Terminated - min stepsize reached after 17 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +7.360969e+02   |grad|: 8.845388e+01
# acc TR+   k:     1     num_inner:     0     f: +7.006185e+02   |grad|: 9.559734e+01   negative curvature
# acc       k:     2     num_inner:     0     f: +6.545918e+02   |grad|: 2.802200e+01   exceeded trust region
# acc       k:     3     num_inner:     0     f: +6.521206e+02   |grad|: 4.831988e-01   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +6.521199e+02   |grad|: 3.207716e-05   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +6.521199e+02   |grad|: 1.216253e-13   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+7.6771555817777835e+02	2.18351184e+01
#     1	+7.6092857964280711e+02	4.20467644e+00
#     2	+7.6078770727451649e+02	1.65201652e+00
#     3	+7.6076593281090936e+02	6.51350780e-01
#     4	+7.6076254213637810e+02	2.58141167e-01
#     5	+7.6076200911864726e+02	1.02573615e-01
#     6	+7.6076192492914652e+02	4.08040678e-02
#     7	+7.6076191160440237e+02	1.62394711e-02
#     8	+7.6076190949372426e+02	6.46429370e-03
#     9	+7.6076190915927441e+02	2.57337207e-03
#    10	+7.6076190910627179e+02	1.02446463e-03
#    11	+7.6076190909787158e+02	4.07846260e-04
#    12	+7.6076190909654019e+02	1.62367104e-04
#    13	+7.6076190909632919e+02	6.46398618e-05
#    14	+7.6076190909629577e+02	2.57337524e-05
#    15	+7.6076190909629031e+02	1.02448580e-05
#    16	+7.6076190909628940e+02	4.07857851e-06
#    17	+7.6076190909628940e+02	3.46486443e-06
#    18	+7.6076190909628940e+02	3.39969355e-06
#    19	+7.6076190909628940e+02	3.39869440e-06
# Terminated - min stepsize reached after 20 iterations, 0.02 seconds.
#
# v_steepest = [0.99196556 0.12650819]
#
# v_trust = [0.99196556 0.12650818]
#
# v_cg = [-0.97818697 -0.20772637]
#
#
#  New perturbation : [1.14235308 0.91298253]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00021162598541013544
#
# NextGrad = 0.04539025353794899
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0002262160342104691
#
# NextGrad = 0.046870481289603416
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.0002464260094533488
#
# NextGrad = 0.048847246603874905
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0002747176241000293
#
# NextGrad = 0.05148782600691176
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00031483073934412964
#
# NextGrad = 0.05501598340175557
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00037256519052886183
#
# NextGrad = 0.059730870764879124
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.00045709973254037806
#
# NextGrad = 0.0660320488283124
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0005832418335144363
#
# NextGrad = 0.07445254972440687
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0007752995498672144
#
# NextGrad = 0.08570255863931785
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0010737912741324296
#
# NextGrad = 0.10072715303316336
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 5, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 0.9509454447364065
# |gradf_0| = 0.08526626729858855
# f_1 = 0.9506481895957588
# |gradf_1| = 0.08119950214107871
# f_2 = 0.950169273304406
# |gradf_2| = 0.0008110997445089101
# f_3 = 0.950169215874833
# |gradf_3| = 6.210633310741742e-06
# f_4 = 0.950169215871968
# |gradf_4| = 1.643915400748593e-08
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+5.8731561521699598e+02	6.66627193e-01
#     2	+5.8731515367498014e+02	4.30313313e-01
#     3	+5.8731487669881744e+02	1.72079002e-01
#     4	+5.8731482915283596e+02	5.39218656e-02
#     5	+5.8731482408929924e+02	7.98145057e-03
#     6	+5.8731482399357765e+02	3.15322054e-03
#     7	+5.8731482397806485e+02	1.10914573e-03
#     8	+5.8731482397717491e+02	8.54651774e-04
#     9	+5.8731482397605112e+02	3.15001157e-04
#    10	+5.8731482397593595e+02	1.85920646e-04
#    11	+5.8731482397592117e+02	1.61973585e-04
#    12	+5.8731482397588070e+02	5.94805018e-05
#    13	+5.8731482397587672e+02	3.60585188e-05
#    14	+5.8731482397587570e+02	2.59177695e-05
#    15	+5.8731482397587502e+02	1.84267838e-05
#    16	+5.8731482397587433e+02	2.36382047e-06
#    17	+5.8731482397587433e+02	2.70086152e-06
# Terminated - min stepsize reached after 17 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +7.650631e+02   |grad|: 4.509916e+01
# acc TR+   k:     1     num_inner:     0     f: +7.432139e+02   |grad|: 6.289865e+01   negative curvature
# acc       k:     2     num_inner:     0     f: +7.205945e+02   |grad|: 9.097211e+00   exceeded trust region
# acc       k:     3     num_inner:     0     f: +7.203129e+02   |grad|: 5.692137e-02   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +7.203129e+02   |grad|: 2.178814e-07   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+5.8817982947882933e+02	2.19887562e+01
#     1	+5.8735135899308011e+02	4.52949080e+00
#     2	+5.8731631383629713e+02	9.14747535e-01
#     3	+5.8731488465490906e+02	1.84606682e-01
#     4	+5.8731482644720995e+02	3.72557725e-02
#     5	+5.8731482407652800e+02	7.51869114e-03
#     6	+5.8731482397997388e+02	1.51737012e-03
#     7	+5.8731482397604123e+02	3.06225206e-04
#     8	+5.8731482397588115e+02	6.18002698e-05
#     9	+5.8731482397587479e+02	1.24721065e-05
#    10	+5.8731482397587433e+02	2.51703498e-06
#    11	+5.8731482397587433e+02	5.07970732e-07
# Terminated - min grad norm reached after 12 iterations, 0.01 seconds.
#
# v_steepest = [0.99097448 0.13405069]
#
# v_trust = [-0.99193528 -0.12674541]
#
# v_cg = [0.99097448 0.13405068]
#
#
#  New perturbation : [1.23424044 1.36698852]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00020017476347644614
#
# NextGrad = 0.043014373519842386
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00021414965531429964
#
# NextGrad = 0.0444538747902999
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00023351625313849933
#
# NextGrad = 0.0463751715109191
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00026064217855448213
#
# NextGrad = 0.04893995537363869
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00029912782645136193
#
# NextGrad = 0.05236425335109538
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00035456217274876245
#
# NextGrad = 0.05693656721081962
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0004357985637594153
#
# NextGrad = 0.0630419351343075
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0005571319323728341
#
# NextGrad = 0.07119380651827367
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0007420472091973496
#
# NextGrad = 0.08207624548058173
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0010297171037619846
#
# NextGrad = 0.09659977976589347
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 6, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 0.935595431387175
# |gradf_0| = 0.0818300876499161
# f_1 = 0.9352332218834135
# |gradf_1| = 0.0717773146708809
# f_2 = 0.9348525305089456
# |gradf_2| = 0.0007056425854798453
# f_3 = 0.9348524890188787
# |gradf_3| = 5.026829324003313e-06
# f_4 = 0.9348524890171186
# |gradf_4| = 9.977333234558513e-09
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+5.0744046137207761e+02	1.36467898e+00
#     2	+5.0743899793114485e+02	6.15387251e-01
#     3	+5.0743896780570907e+02	5.90054850e-01
#     4	+5.0743885787446402e+02	4.86534820e-01
#     5	+5.0743862517653389e+02	2.84041360e-02
#     6	+5.0743862439680993e+02	4.03893469e-03
#     7	+5.0743862438497479e+02	2.07717085e-03
#     8	+5.0743862438136767e+02	8.10994978e-04
#     9	+5.0743862438081754e+02	3.16286771e-04
#    10	+5.0743862438073415e+02	1.24547853e-04
#    11	+5.0743862438072091e+02	4.51455555e-05
#    12	+5.0743862438071983e+02	2.92097609e-05
#    13	+5.0743862438071892e+02	8.27516842e-06
#    14	+5.0743862438071892e+02	5.65268710e-06
# Terminated - min stepsize reached after 14 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +6.918509e+02   |grad|: 1.059145e+02
# acc TR+   k:     1     num_inner:     0     f: +6.732259e+02   |grad|: 1.181474e+01   exceeded trust region
# acc       k:     2     num_inner:     0     f: +6.730211e+02   |grad|: 2.103210e-02   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +6.730211e+02   |grad|: 1.043453e-08   maximum inner iterations
# Terminated - min grad norm reached after 3 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+6.7599503997626380e+02	4.45572929e+01
#     1	+6.7303241941774945e+02	2.78534686e+00
#     2	+6.7302107289189235e+02	1.18758383e-01
#     3	+6.7302105226817912e+02	5.04742057e-03
#     4	+6.7302105223092485e+02	2.14509117e-04
#     5	+6.7302105223085766e+02	9.11634687e-06
#     6	+6.7302105223085744e+02	3.87432377e-07
# Terminated - min grad norm reached after 7 iterations, 0.00 seconds.
#
# v_steepest = [0.99210501 0.12540989]
#
# v_trust = [-0.99299369 -0.11816736]
#
# v_cg = [-0.99299369 -0.11816736]
#
#
#  New perturbation : [1.61386573 1.79848619]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.0001910300553231714
#
# NextGrad = 0.04145159195705564
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00020459381125736975
#
# NextGrad = 0.042878298007878936
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00022340236253715062
#
# NextGrad = 0.04478170612281999
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0002497666886519534
#
# NextGrad = 0.04732133834856353
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00028720569631546233
#
# NextGrad = 0.050710128222815704
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0003411891080491447
#
# NextGrad = 0.055232224857136136
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.00042039242341718186
#
# NextGrad = 0.06126664681640738
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0005388399666640398
#
# NextGrad = 0.06931867540878277
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.000719596385003074
#
# NextGrad = 0.08006148578714789
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.001001168413026221
#
# NextGrad = 0.09439128188730667
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 7, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 0.9205433622820015
# |gradf_0| = 0.07994663137195075
# f_1 = 0.9201654611176732
# |gradf_1| = 0.06789417260148516
# f_2 = 0.9198229269732844
# |gradf_2| = 0.0006679480295633035
# f_3 = 0.9198228903278114
# |gradf_3| = 4.665809274431707e-06
# f_4 = 0.9198228903263123
# |gradf_4| = 8.142091605404703e-09
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+4.0802108953335727e+02	2.09035924e+00
#     2	+4.0802056363341478e+02	1.82108225e+00
#     3	+4.0801912808733039e+02	6.64415361e-01
#     4	+4.0801899462459431e+02	4.17333771e-01
#     5	+4.0801893251476662e+02	2.23117862e-01
#     6	+4.0801890920221797e+02	5.56260600e-02
#     7	+4.0801890887015588e+02	4.92873843e-02
#     8	+4.0801890790551829e+02	2.23023429e-02
#     9	+4.0801890787752995e+02	2.10081739e-02
#    10	+4.0801890777979497e+02	1.56720184e-02
#    11	+4.0801890770039938e+02	9.30639131e-03
#    12	+4.0801890768736871e+02	7.77899262e-03
#    13	+4.0801890765772396e+02	1.06960133e-03
#    14	+4.0801890765737346e+02	6.64943732e-04
#    15	+4.0801890765722885e+02	3.90678394e-04
#    16	+4.0801890765721407e+02	3.50610637e-04
#    17	+4.0801890765716917e+02	1.81773447e-04
#    18	+4.0801890765715490e+02	6.56019562e-05
#    19	+4.0801890765715370e+02	4.32877441e-05
#    20	+4.0801890765715274e+02	1.19383341e-05
#    21	+4.0801890765715268e+02	8.32472774e-06
#    22	+4.0801890765715268e+02	1.48734603e-06
# Terminated - min stepsize reached after 22 iterations, 0.02 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +8.354036e+02   |grad|: 3.680220e+02
# acc TR+   k:     1     num_inner:     0     f: +6.999464e+02   |grad|: 3.174664e+02   negative curvature
# acc       k:     2     num_inner:     0     f: +6.276397e+02   |grad|: 1.237554e+02   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +6.176900e+02   |grad|: 3.854192e+00   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +6.176806e+02   |grad|: 8.460503e-06   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +6.176806e+02   |grad|: 1.115009e-13   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+8.4238469610407253e+02	4.35062565e+02
#     1	+4.7022552680502861e+02	3.32451449e+02
#     2	+4.2247819926851821e+02	1.67951218e+02
#     3	+4.1079054665199163e+02	7.43243610e+01
#     4	+4.0852437961318742e+02	3.18039010e+01
#     5	+4.0811021342192362e+02	1.35216538e+01
#     6	+4.0803537340177468e+02	5.74240999e+00
#     7	+4.0802187627124135e+02	2.43827537e+00
#     8	+4.0801944285480465e+02	1.03529155e+00
#     9	+4.0801900414573697e+02	4.39585305e-01
#    10	+4.0801892505275032e+02	1.86648574e-01
#    11	+4.0801891079335229e+02	7.92513658e-02
#    12	+4.0801890822256905e+02	3.36503124e-02
#    13	+4.0801890775908998e+02	1.42880040e-02
#    14	+4.0801890767553061e+02	6.06672175e-03
#    15	+4.0801890766046597e+02	2.57594515e-03
#    16	+4.0801890765774999e+02	1.09375274e-03
#    17	+4.0801890765726040e+02	4.64410151e-04
#    18	+4.0801890765717212e+02	1.97189712e-04
#    19	+4.0801890765715621e+02	8.37272455e-05
#    20	+4.0801890765715331e+02	3.55507981e-05
#    21	+4.0801890765715279e+02	1.50949580e-05
#    22	+4.0801890765715274e+02	6.40935687e-06
#    23	+4.0801890765715274e+02	9.66498887e-07
# Terminated - min grad norm reached after 24 iterations, 0.02 seconds.
#
# v_steepest = [0.99315183 0.11683085]
#
# v_trust = [-0.99376113 -0.11152945]
#
# v_cg = [0.99315183 0.11683085]
#
#
#  New perturbation : [2.21230864 2.43705107]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00018090378700597043
#
# NextGrad = 0.03991908974232898
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0001940318557798193
#
# NextGrad = 0.04133324361410365
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00021225115874845546
#
# NextGrad = 0.04321937567507502
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0002378150090158737
#
# NextGrad = 0.045735129308030836
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0002741603870251019
#
# NextGrad = 0.04909080697129602
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0003266388268549081
#
# NextGrad = 0.05356690861181183
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0004037523329198933
#
# NextGrad = 0.05953745735177875
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0005192656344055191
#
# NextGrad = 0.06750099468976534
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.000695847042924691
#
# NextGrad = 0.07812172373457957
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0009713857090177802
#
# NextGrad = 0.09228402306818513
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 8, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 0.9058289668454248
# |gradf_0| = 0.07808750188488485
# f_1 = 0.9054427132363855
# |gradf_1| = 0.06449006707610683
# f_2 = 0.9051322954868627
# |gradf_2| = 0.000625393806350254
# f_3 = 0.9051322637707491
# |gradf_3| = 4.359049045917315e-06
# f_4 = 0.9051322637694508
# |gradf_4| = 6.228853217281661e-09
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+2.8468863274752357e+02	3.24269089e+00
#     2	+2.8468651056675242e+02	1.06957063e+00
#     3	+2.8468625164674904e+02	2.56139015e-02
#     4	+2.8468625157135926e+02	1.79769057e-02
#     5	+2.8468625149824021e+02	5.41453746e-04
#     6	+2.8468625149817422e+02	4.08830582e-05
#     7	+2.8468625149817387e+02	1.48052548e-05
#     8	+2.8468625149817376e+02	1.06255768e-05
#     9	+2.8468625149817376e+02	4.71985911e-06
# Terminated - min stepsize reached after 9 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.121405e+03   |grad|: 1.026859e+03
# acc TR+   k:     1     num_inner:     0     f: +7.070112e+02   |grad|: 1.090918e+03   negative curvature
# acc       k:     2     num_inner:     0     f: +2.846916e+02   |grad|: 4.841456e+00   exceeded trust region
# acc       k:     3     num_inner:     0     f: +2.846863e+02   |grad|: 4.844029e-05   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +2.846863e+02   |grad|: 4.832213e-14   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.4055048733494968e+03	4.52734773e+02
#     1	+6.6610882731654237e+02	1.06173309e+03
#     2	+2.9485909005592458e+02	2.10977142e+02
#     3	+2.8627607002625359e+02	8.37240223e+01
#     4	+2.8492957044654719e+02	3.27743448e+01
#     5	+2.8472336375353677e+02	1.28011799e+01
#     6	+2.8469190880415385e+02	4.99809641e+00
#     7	+2.8468711379288084e+02	1.95132476e+00
#     8	+2.8468638292726081e+02	7.61812278e-01
#     9	+2.8468627153017945e+02	2.97416195e-01
#    10	+2.8468625455138221e+02	1.16112957e-01
#    11	+2.8468625196353275e+02	4.53311309e-02
#    12	+2.8468625156910213e+02	1.76975172e-02
#    13	+2.8468625150898441e+02	6.90920541e-03
#    14	+2.8468625149982154e+02	2.69739068e-03
#    15	+2.8468625149842489e+02	1.05307572e-03
#    16	+2.8468625149821207e+02	4.11126376e-04
#    17	+2.8468625149817962e+02	1.60505930e-04
#    18	+2.8468625149817467e+02	6.26623712e-05
#    19	+2.8468625149817399e+02	2.44637239e-05
#    20	+2.8468625149817376e+02	5.36218735e-06
#    21	+2.8468625149817376e+02	7.71285584e-06
#    22	+2.8468625149817376e+02	7.71285584e-06
# Terminated - min stepsize reached after 23 iterations, 0.02 seconds.
#
# v_steepest = [0.99404483 0.10897194]
#
# v_trust = [0.99404483 0.10897194]
#
# v_cg = [0.99404483 0.10897195]
#
#
#  New perturbation : [3.18708328 3.46172007]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.0001691425294660931
#
# NextGrad = 0.038282763606079726
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00018177728010193572
#
# NextGrad = 0.03968404964597048
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.000199331430854377
#
# NextGrad = 0.04155270197740729
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00022399526668892555
#
# NextGrad = 0.04404464702298609
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0002591172601255076
#
# NextGrad = 0.04736782523860253
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00030992299009480195
#
# NextGrad = 0.05179950752153259
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0003847324041929001
#
# NextGrad = 0.05770934077494649
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0004970424111125915
#
# NextGrad = 0.06558999296355103
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0006691196925416865
#
# NextGrad = 0.07609785432398271
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0009382388431101729
#
# NextGrad = 0.09010697901762008
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
# ----- Step 9, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 0.8915457231487751
# |gradf_0| = 0.07610881239842775
# f_1 = 0.891156867915049
# |gradf_1| = 0.061247177506918146
# f_2 = 0.8908757954401301
# |gradf_2| = 0.0005813447703410141
# f_3 = 0.8908757683716371
# |gradf_3| = 4.0575554181077415e-06
# f_4 = 0.8908757683705117
# |gradf_4| = 4.5407868856811535e-09
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+1.3927584847423933e+02	4.54251558e+00
#     2	+1.3927407407344765e+02	9.08539706e-01
#     3	+1.3927401860920298e+02	4.54153546e-01
#     4	+1.3927400477158358e+02	2.27542501e-01
#     5	+1.3927400125558825e+02	1.11910141e-01
#     6	+1.3927400049450705e+02	6.34614368e-02
#     7	+1.3927400013483987e+02	3.48098815e-03
#     8	+1.3927400013384855e+02	1.02477809e-03
#     9	+1.3927400013376393e+02	3.25131720e-04
#    10	+1.3927400013375461e+02	3.80216277e-05
#    11	+1.3927400013375444e+02	4.74684197e-06
#    12	+1.3927400013375444e+02	7.78621580e-06
# Terminated - min stepsize reached after 12 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.007320e+03   |grad|: 2.093420e+03
# acc TR+   k:     1     num_inner:     0     f: +5.029840e+02   |grad|: 4.722980e+02   exceeded trust region
# acc       k:     2     num_inner:     0     f: +4.815241e+02   |grad|: 3.977811e+00   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +4.815225e+02   |grad|: 8.220651e-06   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +4.815225e+02   |grad|: 1.588822e-13   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+9.7297730573660044e+02	2.04089639e+03
#     1	+5.8824513076668279e+02	1.03550673e+03
#     2	+4.9705226858162416e+02	4.02223772e+02
#     3	+4.8355199949078553e+02	1.45779955e+02
#     4	+4.8178349558282923e+02	5.22908169e+01
#     5	+4.8155603207031231e+02	1.87320114e+01
#     6	+4.8152684348423566e+02	6.70932222e+00
#     7	+4.8152309892840128e+02	2.40307647e+00
#     8	+4.8152261855564558e+02	8.60710171e-01
#     9	+4.8152255693060818e+02	3.08280970e-01
#    10	+4.8152254902497202e+02	1.10417191e-01
#    11	+4.8152254801078794e+02	3.95482022e-02
#    12	+4.8152254788068205e+02	1.41650080e-02
#    13	+4.8152254786399129e+02	5.07349124e-03
#    14	+4.8152254786185006e+02	1.81717606e-03
#    15	+4.8152254786157539e+02	6.50859279e-04
#    16	+4.8152254786154015e+02	2.33118744e-04
#    17	+4.8152254786153566e+02	8.34963110e-05
#    18	+4.8152254786153503e+02	2.99059349e-05
#    19	+4.8152254786153492e+02	1.07114307e-05
#    20	+4.8152254786153492e+02	3.03838872e-06
#    21	+4.8152254786153492e+02	4.76211853e-06
#    22	+4.8152254786153492e+02	4.76211853e-06
# Terminated - min stepsize reached after 23 iterations, 0.02 seconds.
#
# v_steepest = [0.99481042 0.1017459 ]
#
# v_trust = [-0.99505431 -0.09933238]
#
# v_cg = [-0.99505431 -0.09933238]
#
#
#  New perturbation : [4.90366574 5.23388228]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00015499745973235335
#
# NextGrad = 0.036407106213680124
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00016704510109621928
#
# NextGrad = 0.03779582787836624
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00018380991184607787
#
# NextGrad = 0.039647554946155315
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.00020740969119870112
#
# NextGrad = 0.04211666527771285
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0002410923186012548
#
# NextGrad = 0.045408997354103586
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.00028994223801870334
#
# NextGrad = 0.04979897975467234
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.00036207876129112915
#
# NextGrad = 0.05565243636556167
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.00047070915917535316
#
# NextGrad = 0.06345692367271077
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0006376746499404673
#
# NextGrad = 0.07386203511716986
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.0008996128470326603
#
# NextGrad = 0.08773282380292931
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 10, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 0.8778383790190646
# |gradf_0| = 0.0738953730978327
# f_1 = 0.8774533483436318
# |gradf_1| = 0.058058911931121907
# f_2 = 0.877199915540975
# |gradf_2| = 0.0005348129274496577
# f_3 = 0.8771998929051464
# |gradf_3| = 3.7379055515574486e-06
# f_4 = 0.8771998929041842
# |gradf_4| = 3.1102572246804997e-09
# Computing gradient of cost function...
# Compiling cost function...
#  iter		   cost val	    grad. norm
#     1	+1.1278263681021116e+01	3.08103980e+00
#     2	+1.1278014628790144e+01	1.04080361e+00
#     3	+1.1278010940997966e+01	9.79157700e-01
#     4	+1.1277998105712427e+01	7.24811515e-01
#     5	+1.1277989119338045e+01	4.71080178e-01
#     6	+1.1277983434010316e+01	1.73046175e-01
#     7	+1.1277982869318663e+01	1.04295357e-01
#     8	+1.1277982729796282e+01	7.85263635e-02
#     9	+1.1277982598088094e+01	4.14621818e-02
#    10	+1.1277982551560884e+01	1.21683401e-02
#    11	+1.1277982547642594e+01	3.97030556e-03
#    12	+1.1277982547176908e+01	1.95164540e-04
#    13	+1.1277982547176201e+01	1.19562349e-04
#    14	+1.1277982547175966e+01	8.01018709e-05
#    15	+1.1277982547175778e+01	1.87404380e-05
#    16	+1.1277982547175771e+01	2.46355991e-06
#    17	+1.1277982547175769e+01	9.71002452e-06
#    18	+1.1277982547175769e+01	6.62142752e-06
# Terminated - min stepsize reached after 18 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +7.470700e+03   |grad|: 5.608017e+03
# acc TR+   k:     1     num_inner:     0     f: +4.716854e+03   |grad|: 8.428840e+03   negative curvature
# acc       k:     2     num_inner:     0     f: +2.705872e+02   |grad|: 2.913304e+03   negative curvature
# acc       k:     3     num_inner:     0     f: +1.154311e+01   |grad|: 9.461569e+01   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.127798e+01   |grad|: 2.428325e-03   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +1.127798e+01   |grad|: 2.238562e-13   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+6.4744913738052924e+02	4.45917457e+03
#     1	+2.0498255446138991e+01	5.57681918e+02
#     2	+1.1305303737879527e+01	3.03731834e+01
#     3	+1.1278060647137073e+01	1.62392562e+00
#     4	+1.1277982770419612e+01	8.68221321e-02
#     5	+1.1277982547813901e+01	4.64189590e-03
#     6	+1.1277982547177601e+01	2.48176345e-04
#     7	+1.1277982547175778e+01	1.32686080e-05
#     8	+1.1277982547175768e+01	6.98900354e-06
#     9	+1.1277982547175760e+01	3.68133340e-06
#    10	+1.1277982547175757e+01	3.67963196e-06
# Terminated - min stepsize reached after 11 iterations, 0.01 seconds.
#
# v_steepest = [0.99546089 0.09517149]
#
# v_trust = [0.99546089 0.09517149]
#
# v_cg = [0.99546089 0.09517149]
#
#
#  New perturbation : [8.25066036 8.63150082]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.00013741299349534497
#
# NextGrad = 0.03409689087744033
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.00014872234543505947
#
# NextGrad = 0.0354737840422073
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.00016449703244503233
#
# NextGrad = 0.03730966023164014
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0001867664481292053
#
# NextGrad = 0.03975751367614693
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.00021865713094726402
#
# NextGrad = 0.04302132209611946
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0002650855774796179
#
# NextGrad = 0.04737301701435806
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0003339362291682191
#
# NextGrad = 0.053175081313747125
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.0004380837699208273
#
# NextGrad = 0.06091061612217466
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.0005988914923477084
#
# NextGrad = 0.07122329185474648
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.000852298634755777
#
# NextGrad = 0.08497030681021724
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 11, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 0.8649325781616051
# |gradf_0| = 0.07126587634299551
# f_1 = 0.8645591090472039
# |gradf_1| = 0.054765457353977136
# f_2 = 0.8643329218738148
# |gradf_2| = 0.00048484973707529265
# f_3 = 0.8643329034852427
# |gradf_3| = 3.371598779910138e-06
# f_4 = 0.86433290348445
# |gradf_4| = 1.9725874435637822e-09
# Computing gradient of cost function...
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 8.886663506846304e-06
#
# NextGrad = 0.008669928397091105
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 9.487898853244303e-06
#
# NextGrad = 0.008957005512483419
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 1.0320156602294794e-05
#
# NextGrad = 0.009339847298966635
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 1.1484252399940331e-05
#
# NextGrad = 0.009850416051576915
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 1.3133124453279521e-05
#
# NextGrad = 0.010531345086924283
#
#
# Potential new step size = 0.4213991769547325
# NextObj = 1.5503609884004454e-05
#
# NextGrad = 0.01143949772313543
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 1.897001451944824e-05
#
# NextGrad = 0.01265070896863743
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 2.4135452056706086e-05
#
# NextGrad = 0.014266102062744736
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 3.198902813839055e-05
#
# NextGrad = 0.016420503684336757
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 4.417834400050058e-05
#
# NextGrad = 0.01929365774447068
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 12, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 0.8610022667761197
# |gradf_0| = 0.01641803177678526
# f_1 = 0.8609818428520589
# |gradf_1| = 0.012375604694242528
# f_2 = 0.8609702398268584
# |gradf_2| = 2.6981734163206267e-05
# f_3 = 0.8609702397712626
# |gradf_3| = 4.02512953269067e-08

# %%
# %matplotlib notebook
from Visualization.visualization import SubplotAnimationWithDiscontinuityRegions

ani = SubplotAnimationWithDiscontinuityRegions(results,
                                               parameterMagnitude, 
                                               targetParameter, 
                                               finalSolution, 
                                               differentialParameterAlongV, 
                                               differentialSolutionAlongV,
                                               eps)

ani.show()
# Out:
# <img src="data:image/png;base64,..." width="990.9274355497729">
# [2.55990927e-04 3.42452545e-09]
