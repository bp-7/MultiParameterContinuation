# %% [markdown]
# # Smallest eigenvalue problem
#
# $\newcommand{\mapcom}[5]{\begin{align*} #1 \,:\, #2& \longrightarrow #3 \\ #4& \longmapsto #5, \end{align*}}$
# $\newcommand{\Rset}{\mathbb{R}}$
# We look here at the case where we would like to find the smallest eigenvalue of a real symmetric parameterized matrix $$\mapcom{A}{\mathcal{P}\subset\Rset^p}{\Rset^{n\times n}}{\mu}{A(\mu)}$$ with eigenvalues $\lambda_1< \dots\le\lambda_n$. The parameter space $\mathcal{P}$ is considered to be an open bounder connected subset of $\Rset^p$.
# The smallest eigenvalue $\lambda_1=\lambda_1(\mu)\in\Rset$, can be determined by the study of the Rayleigh quotient as follow
# $$
# 	\lambda_1(\mu) = \min_{x\in\Rset^n} \frac{x^TA(\mu)x}{x^Tx} = \min_{x^Tx = 1} x^TA(\mu)x.
# $$
# Therefore by defining a cost function $$\mapcom{f}{S^{n-1}\times\mathcal{P}}{\Rset}{(x,\mu)}{\frac{1}{2}x^TA(\mu)x}$$ the problem is equivalent to solving the following minimization problem
# $$
# 	\lambda_1 = \min_{x \in S^{n-1}} f(x,\mu).
# $$

# %% [markdown]
# ## Construction of the mapping $A$
# We will build our mapping $A$ as follow
# $$\mapcom{A}{\mathcal{P}\subset\Rset^p}{\Rset^{n\times n}}{\mu}{R(\mu)\begin{pmatrix} \lambda_1(\mu) & & \\ & \lambda_2(\mu) & \\ &  & \lambda_3(\mu) \end{pmatrix}R^T(\mu)}$$ where $R$ is a given orthogonal matrix and $\lambda_i:\mathcal{P}\to\Rset, i=1,\dots, n$ are eigenvalues of $A(\mu)$ for $\mu\in\mathcal{P}$

# %% [markdown]
# ##############################################################################################################
# ##############################################################################################################

# %% [markdown]
# ## First test case, $n=3, p=2$ :
# We consider a mapping $R$ defined for any $\mu=(\mu_1, \mu_2)\in\Rset^2$ by
#
# $$
# R(\mu) = I + \sin(\theta(\mu))[w]_\times + (1-\cos(\theta(\mu)))[w]^2_\times,
# $$
#
# for a unit vector $w=\frac{1}{\sqrt{3}}(1, 1, 1)\in\Rset^3$ and $\theta(\mu) = \mu_1 + \mu_2$ and $\lambda_1(\mu) = (\mu_2 + \mu_1)^2 + 1$, $\lambda_2(\mu) = \lambda_1(\mu) + \delta_1$ and $\lambda_3(\mu) = \lambda_2(\mu) + \delta_2$, for $\delta_1, \delta_2 >0$

# %%
import autograd.numpy as np

# %%
from pymanopt.manifolds import Sphere

# Dimension of the sphere 
solutionSpaceDimension = 3

# Instantiate the unit sphere manifold
unitSphere = Sphere(solutionSpaceDimension)

# %%
from pymanopt.manifolds import Euclidean

# Dimension of the parameter space 
parameterSpaceDimension = 2

# Instantiate the parameter space 
parameterSpace = Euclidean(parameterSpaceDimension)

# %%
from pymanopt.manifolds import Product

productManifold = Product([unitSphere, parameterSpace])

# %% [markdown]
# ## Computation of  $DA(\mu)[v]$
#
# Here we give an explicit form for the differential of $A$ at $\mu\in\mathcal{P}$ along $v\in\mathcal{P}$. We have that
#
# $$
#     DA(\mu)[v] = R(\mu)\Lambda(\mu)DR(\mu)[v]^T + R(\mu)D\Lambda(\mu)[v]R(\mu)^T + DR(\mu)[v]\Lambda(\mu)R(\mu)^T
# $$
#
# where
#
# $$
#     D\Lambda(\mu)[v] = \begin{pmatrix} v^T\nabla\lambda_1(\mu) & & \\ & v^T\nabla\lambda_1(\mu) & \\ & & v^T\nabla\lambda_1(\mu) \end{pmatrix}
# $$
# with $v^T\nabla\lambda_1(\mu) = -v_1\sin(\mu_1) + v_2\cos(\mu_2)$ and
#
# $$
#     DR(\mu)[v] = (v_1 + v_2)(\cos(\theta(\mu))I + \sin(\theta(\mu))[w]_\times)[w]_\times
# $$

# %%
def theta(mu):
    return mu[0] + mu[1]

def lambdaMin(mu):
    #return 3 + np.cos(mu[0]) + np.sin(mu[1])
    return (mu[0] + mu[1]) ** 2 + 1

def DlambdaMin(mu, v):
    #return -v[0] * np.sin(mu[0]) + v[1] * np.cos(mu[1])
    return 2 * (mu[0] + mu[1]) * np.dot(v, np.array([1, 1]))

def Skew(u):
    return np.array([[0, -u[2], u[1]], [u[2], 0, -u[0]], [-u[1], u[0], 0]])

def R(mu):
    w = (1.0 / np.sqrt(3)) * np.array([1., 1., 1.])
    S = Skew(w)
    
    return np.eye(solutionSpaceDimension) + np.sin(theta(mu)) * S + (1 - np.cos(theta(mu))) * S @ S
    #return np.exp(theta(mu) * S)
    
def DR(mu, v):
    w = (1.0 / np.sqrt(3)) * np.array([1., 1., 1.])
    S = Skew(w)
    
    return (v[0] + v[1]) * (np.cos(theta(mu)) * np.eye(solutionSpaceDimension) + np.sin(theta(mu)) * S) @ S
    
    #return DlambdaMin(mu, v) * S @ R(mu)

def Lambda(mu):
    lambdaMinAtMu = lambdaMin(mu)
    delta1 = 1
    d = np.array([lambdaMinAtMu, lambdaMinAtMu + delta1, lambdaMinAtMu + 2])
    return np.diag(d)

def DLambda(mu, v):
    return DlambdaMin(mu, v) * np.eye(solutionSpaceDimension)

def A(mu):
    return R(mu) @ Lambda(mu) @ R(mu).T 

def DA(mu, v):
    R_ = R(mu)
    Lambda_ = Lambda(mu)
    DR_ = DR(mu, v)
    return R_ @ Lambda_ @ DR_ + R_ @ DLambda(mu, v) @ R_.T + R_ @ Lambda_ @ DR_.T

# %%
def A(mu):
    sigma = 100
    lambda0 = 1 + np.exp((mu[0] - mu[1]) / sigma)
    lambda1 = 2 + np.exp((3 * mu[0] + mu[1]) / sigma)
    lambda2 = 3 + np.exp((mu[0] + mu[1]) / sigma)
    
    return np.array([[lambda0, -1, 0], [-1, lambda1, -1], [0, -1, lambda2]])

def DA(mu,v):
    sigma = 100
    Dlambda0 = (v[0] - v[1]) / sigma * np.exp((mu[0] - mu[1]) / sigma)
    Dlambda1 = (3 * v[0] + v[1]) / sigma * np.exp((3 * mu[0] + mu[1]) / sigma)
    Dlambda2 = (v[0] + v[1]) / sigma * np.exp((mu[0] + mu[1]) / sigma)
    
    return np.array([[Dlambda0, 0, 0], [0, Dlambda1, 0], [0, 0, Dlambda2]])

# %% [markdown]
# ### Compute $D_x\operatorname{grad} f(x,\mu)$ and $D_\mu\operatorname{grad} f(x,\mu)$

# %%
# Define derivatives of gradient wrt solution/parameter

def differentialSolutionAlongV(x, mu, xi):
    return A(mu) @ xi - 2 * (x.T @ A(mu) @ xi) * x - (x.T @ A(mu) @ x) * xi

#def differentialParameterAlongV(x, mu, v):
#    return np.eye(solutionSpaceDimension)
def differentialParameterAlongV(x, mu, v):
    return (np.eye(solutionSpaceDimension) - np.outer(x, x)) @ DA(mu, v) @ x

# %% [markdown]
# ### Define cost function $f$ and instantiate optimization problem

# %%
from pymanopt.core.problem import Problem 

def cost(S):
    return np.dot(S[0], A(S[1]) @ S[0])

problem = Problem(productManifold, cost=cost)

# %% [markdown]
# ### Define initial/target parameters and initial solution to the problem

# %%
initialParameter = np.array([1, 2])
targetParameter = np.array([23.4, 40.1])

B = A(initialParameter)

w, v = np.linalg.eig(B)

smallestIndex = np.argmin(v)
largestIndex = np.argmin(v)

initialSolution = v[:, smallestIndex]
finalSolution = v[:, largestIndex]

print(B @ initialSolution - w[smallestIndex] * initialSolution)
print(w)
print(v)
# Out:
# [ 2.22044605e-16 -2.22044605e-16  1.66533454e-16]
# [1.27978908 3.02429043 4.76769595]
# [[-0.79779605  0.56557311  0.20892228]
#  [-0.56664322 -0.58493867 -0.58031216]
#  [-0.20600223 -0.58135514  0.78713993]]

# %%
def WriteMatrixInEuclideanBasisAtGivenPoint(matrixVectorFunction, x, mu, dimension):
    spaceDimension = len(x)
    indices = np.arange(dimension)
    A = np.zeros((spaceDimension, dimension))

    for index in indices:
        v = np.zeros(dimension)
        v[index] = 1

        A[:, index] = matrixVectorFunction(x, mu, v)

    return A

# %%
np.linalg.matrix_rank(WriteMatrixInEuclideanBasisAtGivenPoint(differentialParameterAlongV, initialSolution, initialParameter, 2))
# Out:
# 2

# %%
from Continuation.PathAdaptiveContinuation import PathAdaptiveMultiParameterContinuation

# Instantiate continuation object
continuation = PathAdaptiveMultiParameterContinuation(problem, 
                                                      initialSolution,
                                                      initialParameter,
                                                      targetParameter,
                                                      differentialSolutionAlongV, 
                                                      differentialParameterAlongV,
                                                      A,
                                                      0.1)
results = continuation.Traverse()
# Out:
# ========== New continuation problem ==========
#
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+3.9415351661451823e+03	6.60925170e+03
#     2	+4.4870351148388056e+02	6.92489890e+02
#     3	+4.3069023579784630e+02	2.32909578e+02
#     4	+4.3044352980927641e+02	2.20732040e+02
#     5	+4.2957438140228243e+02	1.68096785e+02
#     6	+4.2861199658394486e+02	7.48650060e+01
#     7	+4.2837311445677517e+02	5.49416336e-01
#     8	+4.2837310183357948e+02	7.37437031e-02
#     9	+4.2837310171656003e+02	5.18679722e-02
#    10	+4.2837310160204470e+02	1.10992042e-03
#    11	+4.2837310160199240e+02	7.30599135e-05
#    12	+4.2837310160199240e+02	5.82551622e-05
# Terminated - min stepsize reached after 12 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +6.791509e+03   |grad|: 3.821204e+03
# acc TR+   k:     1     num_inner:     0     f: +4.916140e+03   |grad|: 5.726260e+03   negative curvature
# acc       k:     2     num_inner:     0     f: +1.881516e+03   |grad|: 2.106817e+03   negative curvature
# acc       k:     3     num_inner:     0     f: +1.667910e+03   |grad|: 3.838910e+01   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.667840e+03   |grad|: 1.810405e-02   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +1.667840e+03   |grad|: 3.897629e-09   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+7.0387980514395877e+03	3.26480655e+03
#     1	+2.5435097262982072e+03	6.03826071e+03
#     2	+6.4741787422353536e+02	2.25637736e+03
#     3	+4.3121556718925285e+02	2.58671333e+02
#     4	+4.2840113524654777e+02	2.56607668e+01
#     5	+4.2837338611765972e+02	2.58480198e+00
#     6	+4.2837310449977167e+02	2.60856187e-01
#     7	+4.2837310163151665e+02	2.63304797e-02
#     8	+4.2837310160229310e+02	2.65781576e-03
#     9	+4.2837310160199536e+02	2.68282180e-04
#    10	+4.2837310160199229e+02	2.70806363e-05
#    11	+4.2837310160199218e+02	2.73354350e-06
#    12	+4.2837310160199218e+02	2.75925668e-07
# Terminated - min grad norm reached after 13 iterations, 0.01 seconds.
#
# v_steepest = [0.97472095 0.22342577]
#
# v_trust = [-0.9970329  -0.07697666]
#
# v_cg = [0.97472095 0.22342577]
#
# Optimizing...
#                                             f: +1.121040e+03   |grad|: 3.699238e+03
# acc TR+   k:     1     num_inner:     0     f: +4.306020e+02   |grad|: 2.290305e+02   exceeded trust region
# acc       k:     2     num_inner:     0     f: +4.283731e+02   |grad|: 3.603292e-01   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +4.283731e+02   |grad|: 1.100910e-06   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +4.283731e+02   |grad|: 8.526513e-14   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
#
#  New perturbation : [ 3.58814445 15.67545332]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 0.1
#
# NextObj = 0.0007387789921506904
#
# NextGrad = 0.07741625819829702
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0010052982495905027
#
# NextGrad = 0.08970360585173914
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.001424295428621658
#
# NextGrad = 0.10617605897852264
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.0020959612848716613
#
# NextGrad = 0.1282265709450068
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0031920190752676714
#
# NextGrad = 0.15769509488602618
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0050087051818614725
#
# NextGrad = 0.19700339058676442
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.008058992682765442
#
# NextGrad = 0.24931675915216878
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.013231693821473378
#
# NextGrad = 0.31871634358487455
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.022061035586576683
#
# NextGrad = 0.4103288732428819
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.03716776839140712
#
# NextGrad = 0.5302758497945
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 1, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.3778895711018795
# |gradf_0| = 0.790480676701701
# f_1 = 1.31979574229978
# |gradf_1| = 0.5198222044287577
# f_2 = 1.311919377764113
# |gradf_2| = 0.31235226224595075
# f_3 = 1.3019028616660873
# |gradf_3| = 0.13611651924965246
# f_4 = 1.2995785632666756
# |gradf_4| = 0.001816514088553241
# f_5 = 1.299578312610743
# |gradf_5| = 9.241878613993517e-05
# f_6 = 1.2995783120138116
# |gradf_6| = 2.462099797598244e-07
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+1.2974282924178249e+02	2.95842929e+02
#     2	+1.2865208817914794e+02	2.26371911e+02
#     3	+1.2739728513879385e+02	9.60328273e+01
#     4	+1.2712661531095327e+02	1.31877151e+01
#     5	+1.2712345836516977e+02	8.26508818e+00
#     6	+1.2712202405357770e+02	4.51016908e+00
#     7	+1.2712143542254078e+02	8.08253055e-01
#     8	+1.2712143113945407e+02	7.14157773e-01
#     9	+1.2712141881930481e+02	3.12967364e-01
#    10	+1.2712141589867592e+02	1.61975971e-02
#    11	+1.2712141589245159e+02	7.36059723e-03
#    12	+1.2712141589220664e+02	6.78122830e-03
#    13	+1.2712141589140136e+02	4.36487913e-03
#    14	+1.2712141589092924e+02	1.80582028e-03
#    15	+1.2712141589083609e+02	3.80267805e-04
#    16	+1.2712141589083230e+02	1.31814243e-04
#    17	+1.2712141589083215e+02	1.08879791e-04
#    18	+1.2712141589083178e+02	2.15707720e-05
#    19	+1.2712141589083178e+02	1.42359094e-05
# Terminated - min stepsize reached after 19 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.543826e+03   |grad|: 4.520947e+03
# acc       k:     1     num_inner:     0     f: +8.671070e+02   |grad|: 3.423963e+02   maximum inner iterations
# acc       k:     2     num_inner:     0     f: +8.634306e+02   |grad|: 6.621482e-01   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +8.634306e+02   |grad|: 1.857447e-06   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +8.634306e+02   |grad|: 7.460699e-13   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+9.2875491264162374e+03	2.04830706e+03
#     1	+4.1685197525365347e+03	8.20362403e+03
#     2	+1.2556544943905440e+03	3.48751694e+03
#     3	+8.6469720266710806e+02	2.01312714e+02
#     4	+8.6343135752280568e+02	4.81617605e+00
#     5	+8.6343063235119894e+02	1.18472486e-01
#     6	+8.6343063191238343e+02	2.91663641e-03
#     7	+8.6343063191211741e+02	7.18051701e-05
#     8	+8.6343063191211718e+02	3.67864778e-05
#     9	+8.6343063191211706e+02	1.88460660e-05
#    10	+8.6343063191211695e+02	9.65502048e-06
#    11	+8.6343063191211695e+02	9.65502048e-06
# Terminated - min stepsize reached after 12 iterations, 0.01 seconds.
#
# v_steepest = [0.99241514 0.12293169]
#
# v_trust = [-0.9993177  -0.03693421]
#
# v_cg = [-0.9993177  -0.03693421]
#
# Optimizing...
#                                             f: +6.169011e+03   |grad|: 8.540425e+03
# acc TR+   k:     1     num_inner:     0     f: +2.896957e+03   |grad|: 8.178123e+03   negative curvature
# acc       k:     2     num_inner:     0     f: +1.592697e+02   |grad|: 1.032325e+03   exceeded trust region
# acc       k:     3     num_inner:     0     f: +1.271233e+02   |grad|: 7.992486e+00   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.271214e+02   |grad|: 2.346684e-04   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +1.271214e+02   |grad|: 3.274862e-13   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
#
#  New perturbation : [ 6.49676454 12.29630077]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.028760628101780927
#
# NextGrad = 0.5301035470773312
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.030495266678372435
#
# NextGrad = 0.5455996430139389
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.03288577426295847
#
# NextGrad = 0.5662235830928829
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.03621065665098988
#
# NextGrad = 0.5936515614116942
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0408870273743942
#
# NextGrad = 0.6300875326937521
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.0475511080764075
#
# NextGrad = 0.6784080952291993
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.05719002788777616
#
# NextGrad = 0.742322477965329
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.07135715193264791
#
# NextGrad = 0.8265155292378399
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.09251865287975591
#
# NextGrad = 0.9366892293145364
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.12459085671982084
#
# NextGrad = 1.0793057619808777
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 2, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.4641920110688968
# |gradf_0| = 0.9368697279434854
# f_1 = 1.4246998867436163
# |gradf_1| = 0.8693332620872904
# f_2 = 1.3716446019536472
# |gradf_2| = 0.026586627173305975
# f_3 = 1.371572117063448
# |gradf_3| = 0.0008886398842527735
# f_4 = 1.3715720339420683
# |gradf_4| = 5.910989768802984e-05
# f_5 = 1.3715720337045414
# |gradf_5| = 1.4368404565587366e-06
# f_6 = 1.3715720337044013
# |gradf_6| = 1.5664669612574448e-08
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+5.1397043100258713e+02	2.43292331e+03
#     2	+3.9092651171892800e+02	4.61995970e+02
#     3	+3.8849440633244365e+02	3.16049871e+02
#     4	+3.8640041784492860e+02	4.39030975e+01
#     5	+3.8637345083822669e+02	2.58117027e+01
#     6	+3.8637057228618676e+02	2.30558264e+01
#     7	+3.8636197441043572e+02	1.13765750e+01
#     8	+3.8636005535176673e+02	6.29812246e+00
#     9	+3.8635922197179332e+02	8.28000695e-01
#    10	+3.8635921615866641e+02	6.43181933e-01
#    11	+3.8635920818943470e+02	2.02311798e-01
#    12	+3.8635920733113107e+02	2.79964386e-02
#    13	+3.8635920732041910e+02	1.68153684e-02
#    14	+3.8635920731797665e+02	1.29812724e-02
#    15	+3.8635920731483026e+02	4.61993013e-03
#    16	+3.8635920731461295e+02	3.34390726e-03
#    17	+3.8635920731453388e+02	2.73554616e-03
#    18	+3.8635920731437398e+02	3.16030972e-05
#    19	+3.8635920731437398e+02	2.61751818e-05
# Terminated - min stepsize reached after 19 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +8.136846e+02   |grad|: 5.998454e+03
# acc       k:     1     num_inner:     0     f: +1.125592e+01   |grad|: 4.243362e+02   maximum inner iterations
# acc       k:     2     num_inner:     0     f: +7.464858e+00   |grad|: 2.739152e-01   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +7.464856e+00   |grad|: 5.793851e-08   maximum inner iterations
# Terminated - min grad norm reached after 3 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.5343937851377000e+03	7.91658850e+03
#     1	+1.8453573820124959e+02	2.87519284e+03
#     2	+1.9561884027628437e+01	7.57605605e+02
#     3	+8.2248637130613620e+00	1.90040476e+02
#     4	+7.5122233111407501e+00	4.74481643e+01
#     5	+7.4678054710943842e+00	1.18394109e+01
#     6	+7.4650400134968020e+00	2.95386539e+00
#     7	+7.4648678720439872e+00	7.36952975e-01
#     8	+7.4648571572718154e+00	1.83859484e-01
#     9	+7.4648564903494137e+00	4.58703017e-02
#    10	+7.4648564488381126e+00	1.14439772e-02
#    11	+7.4648564462543323e+00	2.85510659e-03
#    12	+7.4648564460935019e+00	7.12307732e-04
#    13	+7.4648564460834903e+00	1.77710459e-04
#    14	+7.4648564460828659e+00	4.43361848e-05
#    15	+7.4648564460828277e+00	1.10612355e-05
#    16	+7.4648564460828206e+00	5.54199957e-06
#    17	+7.4648564460828206e+00	5.54199957e-06
# Terminated - min stepsize reached after 18 iterations, 0.01 seconds.
#
# v_steepest = [-0.99931321 -0.03705555]
#
# v_trust = [0.99808205 0.06190501]
#
# v_cg = [0.99808205 0.06190501]
#
# Optimizing...
#                                             f: +9.703507e+02   |grad|: 5.108564e+03
# acc       k:     1     num_inner:     0     f: +3.877799e+02   |grad|: 2.577285e+02   maximum inner iterations
# acc       k:     2     num_inner:     0     f: +3.863592e+02   |grad|: 8.551066e-02   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +3.863592e+02   |grad|: 5.927720e-09   maximum inner iterations
# Terminated - min grad norm reached after 3 iterations, 0.01 seconds.
#
#
#  New perturbation : [-11.12425594  -4.81549624]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.022769799231475263
#
# NextGrad = 0.4533325204104058
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.024252388733592145
#
# NextGrad = 0.46769556698027387
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.026300809495547695
#
# NextGrad = 0.48681421183011037
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.029158941151614215
#
# NextGrad = 0.5122450726300467
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.033194243536566415
#
# NextGrad = 0.5460365535948931
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.03897069327422753
#
# NextGrad = 0.5908652723809883
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.04736875714315003
#
# NextGrad = 0.6501881908031278
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.059782257801876515
#
# NextGrad = 0.728382014576795
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.07843660339182912
#
# NextGrad = 0.8307938030051918
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.10688454546654769
#
# NextGrad = 0.9635237756765653
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 3, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.2853246239677851
# |gradf_0| = 0.831159914735202
# f_1 = 1.24330364796727
# |gradf_1| = 0.7178466488045232
# f_2 = 1.2068752896070918
# |gradf_2| = 0.02920199356064166
# f_3 = 1.20679844342946
# |gradf_3| = 7.678740377283097e-05
# f_4 = 1.2067984427435123
# |gradf_4| = 1.1361967508586867e-06
# f_5 = 1.2067984427434029
# |gradf_5| = 1.3227273216609788e-09
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+3.0637806553395767e+03	8.94463786e+03
#     2	+1.9910994326889745e+03	6.68281082e+03
#     3	+1.5152927213547835e+03	5.26807459e+03
#     4	+9.7270401226035483e+02	2.24226123e+03
#     5	+8.6202954198355178e+02	4.15763608e+02
#     6	+8.6051413287584796e+02	3.24461065e+02
#     7	+8.5833383851321241e+02	9.11208886e+01
#     8	+8.5818699522658176e+02	4.20177716e+01
#     9	+8.5817605940382691e+02	3.57618157e+01
#    10	+8.5814896674253760e+02	8.53705460e+00
#    11	+8.5814733135057327e+02	2.91879879e-01
#    12	+8.5814733029292006e+02	1.95231371e-01
#    13	+8.5814732948398921e+02	4.59113910e-02
#    14	+8.5814732943685135e+02	3.10613747e-03
#    15	+8.5814732943674039e+02	2.17125857e-03
#    16	+8.5814732943663489e+02	1.03466555e-04
#    17	+8.5814732943663466e+02	7.38293394e-05
#    18	+8.5814732943663444e+02	5.28656644e-06
#    19	+8.5814732943663421e+02	2.19180404e-06
# Terminated - min stepsize reached after 19 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.194308e+04   |grad|: 3.361139e+03
# acc TR+   k:     1     num_inner:     0     f: +9.304560e+03   |grad|: 1.011069e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +1.996026e+03   |grad|: 8.622814e+03   negative curvature
# acc       k:     3     num_inner:     0     f: +1.671213e+02   |grad|: 1.788439e+03   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +9.704501e+01   |grad|: 1.442056e+01   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +9.704049e+01   |grad|: 2.182792e-04   maximum inner iterations
# acc       k:     6     num_inner:     0     f: +9.704049e+01   |grad|: 1.992135e-13   maximum inner iterations
# Terminated - min grad norm reached after 6 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+2.9387900247074986e+03	8.74558032e+03
#     1	+1.3009199048264020e+03	4.36502932e+03
#     2	+9.2295620449877902e+02	1.69574708e+03
#     3	+8.6681254190197546e+02	6.21115980e+02
#     4	+8.5929356452548438e+02	2.25908358e+02
#     5	+8.5829891301701309e+02	8.21469867e+01
#     6	+8.5816738342742565e+02	2.98779327e+01
#     7	+8.5814998306086500e+02	1.08683506e+01
#     8	+8.5814768060425854e+02	3.95365550e+00
#     9	+8.5814737590990740e+02	1.43827641e+00
#    10	+8.5814733558694616e+02	5.23225582e-01
#    11	+8.5814733025057535e+02	1.90342911e-01
#    12	+8.5814732954435271e+02	6.92444317e-02
#    13	+8.5814732945089020e+02	2.51902891e-02
#    14	+8.5814732943852118e+02	9.16392452e-03
#    15	+8.5814732943688409e+02	3.33372579e-03
#    16	+8.5814732943666741e+02	1.21276946e-03
#    17	+8.5814732943663898e+02	4.41190989e-04
#    18	+8.5814732943663512e+02	1.60499992e-04
#    19	+8.5814732943663466e+02	5.83879727e-05
#    20	+8.5814732943663444e+02	2.12408446e-05
#    21	+8.5814732943663444e+02	1.44840051e-05
#    22	+8.5814732943663444e+02	9.87655586e-06
#    23	+8.5814732943663444e+02	6.73476438e-06
#    24	+8.5814732943663444e+02	4.59239497e-06
# Terminated - min stepsize reached after 25 iterations, 0.02 seconds.
#
# v_steepest = [-0.99614431 -0.08772979]
#
# v_trust = [0.99855968 0.05365225]
#
# v_cg = [-0.99614431 -0.08772979]
#
# Optimizing...
#                                             f: +1.125299e+04   |grad|: 2.705643e+03
# acc TR+   k:     1     num_inner:     0     f: +8.874039e+03   |grad|: 9.428080e+03   negative curvature
# acc       k:     2     num_inner:     0     f: +1.903511e+03   |grad|: 8.317942e+03   negative curvature
# acc       k:     3     num_inner:     0     f: +1.813144e+02   |grad|: 1.965334e+03   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +9.704269e+01   |grad|: 1.006805e+01   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +9.704049e+01   |grad|: 1.110170e-04   maximum inner iterations
# acc       k:     6     num_inner:     0     f: +9.704049e+01   |grad|: 1.518967e-13   maximum inner iterations
# Terminated - min grad norm reached after 6 iterations, 0.01 seconds.
#
#
#  New perturbation : [12.41865339  6.42169488]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.03526919495527303
#
# NextGrad = 0.6074614831339065
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.0372444656982458
#
# NextGrad = 0.623972885672258
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.0399602434631352
#
# NextGrad = 0.6459453845956041
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.04372662493419477
#
# NextGrad = 0.6751620643491301
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.04900537760584345
#
# NextGrad = 0.7139659014402203
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.05649662350054241
#
# NextGrad = 0.7654122981392559
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.06728008962606369
#
# NextGrad = 0.8334364312739285
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.08304484260849088
#
# NextGrad = 0.9230004458759808
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.10645739025486844
#
# NextGrad = 1.040129486678086
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.14172956883996446
#
# NextGrad = 1.1916258993651618
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 4, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.4941489032586317
# |gradf_0| = 1.0403498977854957
# f_1 = 1.468863545509307
# |gradf_1| = 1.0925481220362305
# f_2 = 1.3876765050308455
# |gradf_2| = 0.029206060954086746
# f_3 = 1.3875798810762916
# |gradf_3| = 0.0012964352831741754
# f_4 = 1.3875797213200187
# |gradf_4| = 3.4000251860839e-05
# f_5 = 1.387579721248145
# |gradf_5| = 1.364376053942903e-06
# f_6 = 1.3875797212480134
# |gradf_6| = 3.487561729752763e-09
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+8.2615013905262495e+03	1.22891458e+04
#     2	+2.8648315520366714e+02	3.74996834e+03
#     3	+1.5101207722367553e+02	2.72295527e+03
#     4	+9.7880815930669172e+01	2.19334328e+03
#     5	+2.9282143998109396e+00	2.32355948e+02
#     6	+2.0154004186228329e+00	8.94161929e+01
#     7	+1.8872990994006518e+00	3.92197310e+01
#     8	+1.8568543783796878e+00	1.93599091e+00
#     9	+1.8568067194970035e+00	1.16014389e+00
#    10	+1.8567964596485287e+00	9.10392672e-01
#    11	+1.8567810258919177e+00	2.25646514e-01
#    12	+1.8567808517697666e+00	2.05280769e-01
#    13	+1.8567803003327683e+00	1.19776698e-01
#    14	+1.8567802657707864e+00	1.12269539e-01
#    15	+1.8567801466294953e+00	8.12369777e-02
#    16	+1.8567801037030272e+00	6.66021869e-02
#    17	+1.8567800157470580e+00	1.63147235e-03
#    18	+1.8567800157149765e+00	1.02213467e-03
#    19	+1.8567800157004672e+00	5.59830117e-04
#    20	+1.8567800156944210e+00	9.33164540e-05
#    21	+1.8567800156942493e+00	8.73768536e-06
#    22	+1.8567800156942484e+00	6.73245685e-06
#    23	+1.8567800156942480e+00	6.56619426e-06
#    24	+1.8567800156942473e+00	2.51498899e-07
# Terminated - min grad norm reached after 24 iterations, 0.02 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +9.979742e+03   |grad|: 1.064016e+04
# acc TR+   k:     1     num_inner:     0     f: +5.466781e+03   |grad|: 1.234558e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +3.433731e+02   |grad|: 7.366261e+02   exceeded trust region
# acc       k:     3     num_inner:     0     f: +3.324606e+02   |grad|: 3.479792e-01   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +3.324606e+02   |grad|: 6.765933e-08   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+1.1150811957866576e+03	7.17477654e+03
#     1	+4.1867249245310099e+01	1.41855533e+03
#     2	+2.4701316186424505e+00	1.75831640e+02
#     3	+1.8658847160472360e+00	2.14220723e+01
#     4	+1.8569152473266635e+00	2.61074846e+00
#     5	+1.8567820245670896e+00	3.18201157e-01
#     6	+1.8567800455367016e+00	3.87831217e-02
#     7	+1.8567800161375656e+00	4.72698580e-03
#     8	+1.8567800157008354e+00	5.76137172e-04
#     9	+1.8567800156943459e+00	7.02210795e-05
#    10	+1.8567800156942520e+00	8.55872594e-06
#    11	+1.8567800156942500e+00	1.04315953e-06
#    12	+1.8567800156942491e+00	7.88873492e-07
# Terminated - min grad norm reached after 13 iterations, 0.01 seconds.
#
# v_steepest = [0.99845407 0.05558296]
#
# v_trust = [-0.99930276 -0.03733632]
#
# v_cg = [0.99845407 0.05558296]
#
# Optimizing...
#                                             f: +1.207851e+02   |grad|: 2.434641e+03
# acc       k:     1     num_inner:     0     f: +1.870843e+00   |grad|: 2.662388e+01   maximum inner iterations
# acc       k:     2     num_inner:     0     f: +1.856780e+00   |grad|: 3.507561e-04   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +1.856780e+00   |grad|: 2.757165e-13   maximum inner iterations
# Terminated - min grad norm reached after 3 iterations, 0.01 seconds.
#
#
#  New perturbation : [9.38318047 7.50611866]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.035215843972558725
#
# NextGrad = 0.6716030094368937
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.03740181251928543
#
# NextGrad = 0.6918597019399552
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.04041714648720318
#
# NextGrad = 0.7188210050417135
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.04461597674480733
#
# NextGrad = 0.7546797630394755
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.05052987278246035
#
# NextGrad = 0.8023203640053398
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.058971525123053814
#
# NextGrad = 0.8655096493924737
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.07120480141620478
#
# NextGrad = 0.949108934951141
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.08922304162379291
#
# NextGrad = 1.0592663792254542
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.11619771811171331
#
# NextGrad = 1.203481473701349
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.15717534043209813
#
# NextGrad = 1.390288102150635
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 5, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.627077250822553
# |gradf_0| = 1.203836072481027
# f_1 = 1.5584005620586947
# |gradf_1| = 0.9094315362963207
# f_2 = 1.5110279617678943
# |gradf_2| = 0.05722554903283471
# f_3 = 1.5107510801084325
# |gradf_3| = 0.0034815900979385766
# f_4 = 1.5107502388546528
# |gradf_4| = 0.00027447253571637187
# f_5 = 1.510750234232873
# |gradf_5| = 6.137808829388208e-07
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+8.1964850952660599e+03	1.84395604e+04
#     2	+1.2740468238089974e+02	2.30631877e+03
#     3	+9.6191973223454070e+01	1.73521013e+03
#     4	+6.7330375782592427e+01	9.33020713e+02
#     5	+5.6250290882848645e+01	2.16627913e+02
#     6	+5.5625335796652699e+01	2.11314063e+01
#     7	+5.5621688743902013e+01	1.32391316e+01
#     8	+5.5620038948551439e+01	7.25022890e+00
#     9	+5.5619351968116355e+01	1.21218797e+00
#    10	+5.5619332360769548e+01	1.05068714e-01
#    11	+5.5619332212499309e+01	3.36927229e-03
#    12	+5.5619332212469615e+01	3.02356892e-03
#    13	+5.5619332212379504e+01	1.56267495e-03
#    14	+5.5619332212351239e+01	5.81821392e-04
#    15	+5.5619332212348070e+01	3.21518744e-04
#    16	+5.5619332212346691e+01	4.50325615e-05
#    17	+5.5619332212346691e+01	2.61152108e-05
# Terminated - min stepsize reached after 17 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +8.208966e+03   |grad|: 1.840193e+04
# acc TR+   k:     1     num_inner:     0     f: +2.259744e+03   |grad|: 1.189485e+04   exceeded trust region
# acc       k:     2     num_inner:     0     f: +1.459606e+02   |grad|: 1.772452e+03   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +1.035742e+02   |grad|: 3.981409e+00   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.035740e+02   |grad|: 4.709926e-07   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+4.3276615807028948e+03	1.55745399e+04
#     1	+1.2431992447306888e+02	1.24072771e+03
#     2	+1.0696639317633610e+02	5.01952842e+02
#     3	+1.0412738920727155e+02	2.02754479e+02
#     4	+1.0366420831138083e+02	8.18787450e+01
#     5	+1.0358867340719024e+02	3.30640621e+01
#     6	+1.0357635605789119e+02	1.33517866e+01
#     7	+1.0357434750339166e+02	5.39166049e+00
#     8	+1.0357401997423183e+02	2.17723749e+00
#     9	+1.0357396656497598e+02	8.79202949e-01
#    10	+1.0357395785567699e+02	3.55036086e-01
#    11	+1.0357395643547565e+02	1.43369203e-01
#    12	+1.0357395620388729e+02	5.78947586e-02
#    13	+1.0357395616612283e+02	2.33788222e-02
#    14	+1.0357395615996468e+02	9.44073938e-03
#    15	+1.0357395615896048e+02	3.81232037e-03
#    16	+1.0357395615879673e+02	1.53947546e-03
#    17	+1.0357395615877005e+02	6.21664622e-04
#    18	+1.0357395615876568e+02	2.51038039e-04
#    19	+1.0357395615876499e+02	1.01373144e-04
#    20	+1.0357395615876482e+02	1.95009752e-05
#    21	+1.0357395615876482e+02	1.95009752e-05
# Terminated - min stepsize reached after 22 iterations, 0.02 seconds.
#
# v_steepest = [0.99938765 0.03499046]
#
# v_trust = [-0.99943319 -0.03366456]
#
# v_cg = [-0.99943319 -0.03366456]
#
# Optimizing...
#                                             f: +1.235915e+04   |grad|: 1.755729e+04
# acc TR+   k:     1     num_inner:     0     f: +5.586755e+03   |grad|: 1.693183e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +2.575159e+02   |grad|: 3.367746e+03   exceeded trust region
# acc       k:     3     num_inner:     0     f: +1.035846e+02   |grad|: 2.808630e+01   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.035740e+02   |grad|: 3.723178e-05   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +1.035740e+02   |grad|: 2.060574e-13   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
#
#  New perturbation : [-11.06849568  -5.74463746]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.030997007046172476
#
# NextGrad = 0.5680000797670716
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.03285037230428256
#
# NextGrad = 0.5845284271511489
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.035403772962415925
#
# NextGrad = 0.6065260476365866
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.03895397297764158
#
# NextGrad = 0.6357806878761713
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.043945127283236074
#
# NextGrad = 0.6746430125573868
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.051054223080108985
#
# NextGrad = 0.7261812508899476
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.06133089195837016
#
# NextGrad = 0.7943521649401918
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.07642571119463604
#
# NextGrad = 0.8841543979419775
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.09895746591756782
#
# NextGrad = 1.0016747820917251
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.133082250694464
#
# NextGrad = 1.1538190596129636
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 6, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.4533124275299172
# |gradf_0| = 1.002123460247845
# f_1 = 1.4295503764701816
# |gradf_1| = 1.051109022658217
# f_2 = 1.3542812219291986
# |gradf_2| = 0.02162509009146234
# f_3 = 1.354247158822056
# |gradf_3| = 0.0007123706444352062
# f_4 = 1.3542471116767985
# |gradf_4| = 1.5849776188124554e-05
# f_5 = 1.3542471116543113
# |gradf_5| = 7.91062202055424e-07
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+7.5564268761987614e+03	1.33137835e+04
#     2	+3.7267106357612494e+02	1.07467977e+03
#     3	+3.5272193756600961e+02	3.10478469e+02
#     4	+3.5116092575915229e+02	1.16139672e+02
#     5	+3.5098030574945346e+02	6.23835242e+01
#     6	+3.5091102573041837e+02	1.45275443e+01
#     7	+3.5090708555711319e+02	1.30788052e+00
#     8	+3.5090708015112807e+02	1.19303739e+00
#     9	+3.5090706289067805e+02	7.11551874e-01
#    10	+3.5090705963225258e+02	5.77225021e-01
#    11	+3.5090705337055687e+02	2.26002170e-02
#    12	+3.5090705336165502e+02	6.15002903e-03
#    13	+3.5090705336116878e+02	3.46266881e-03
#    14	+3.5090705336094436e+02	2.67604584e-04
#    15	+3.5090705336094322e+02	8.04809630e-05
#    16	+3.5090705336094305e+02	1.33312131e-05
#    17	+3.5090705336094300e+02	7.90680379e-06
#    18	+3.5090705336094300e+02	1.59653397e-05
# Terminated - min stepsize reached after 18 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +2.053193e+03   |grad|: 9.651936e+03
# acc TR+   k:     1     num_inner:     0     f: +1.249977e+01   |grad|: 7.334605e+02   exceeded trust region
# acc       k:     2     num_inner:     0     f: +2.494799e+00   |grad|: 7.116406e-01   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +2.494789e+00   |grad|: 1.578710e-07   maximum inner iterations
# Terminated - min grad norm reached after 3 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+7.5870444249094617e+03	1.35214341e+04
#     1	+5.1244164546819732e+01	1.61749627e+03
#     2	+2.4978142703271793e+00	1.27599195e+01
#     3	+2.4947895036031742e+00	6.12390630e-02
#     4	+2.4947894339316559e+00	2.94135983e-04
#     5	+2.4947894339300460e+00	1.41276363e-06
#     6	+2.4947894339300456e+00	7.09774551e-07
# Terminated - min grad norm reached after 7 iterations, 0.00 seconds.
#
# v_steepest = [-0.99867978 -0.05136815]
#
# v_trust = [0.99919921 0.04001181]
#
# v_cg = [0.99919921 0.04001181]
#
# Optimizing...
#                                             f: +7.870436e+03   |grad|: 1.324956e+04
# acc TR+   k:     1     num_inner:     0     f: +3.139214e+03   |grad|: 1.084734e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +5.855505e+02   |grad|: 3.496568e+03   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +3.509963e+02   |grad|: 6.884652e+01   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +3.509071e+02   |grad|: 1.075760e-03   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +3.509071e+02   |grad|: 5.435652e-13   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
#
#  New perturbation : [-9.82544882 -7.17311708]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.023841935729742136
#
# NextGrad = 0.4630856090560817
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.025360322055573592
#
# NextGrad = 0.47744808371065955
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.027456602512458073
#
# NextGrad = 0.49656518689795526
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.030378770096173513
#
# NextGrad = 0.5219926081834817
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.03449982828949261
#
# NextGrad = 0.5557770425223261
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.04039123277457324
#
# NextGrad = 0.6005919853602167
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.04894353578504029
#
# NextGrad = 0.6598887263666415
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.061564108044038335
#
# NextGrad = 0.7380337101317159
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.08049636213504696
#
# NextGrad = 0.8403555219925182
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.10931639243146773
#
# NextGrad = 0.9729213816230462
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 7, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.2989243670013642
# |gradf_0| = 0.8407222983863426
# f_1 = 1.2544782748637384
# |gradf_1| = 0.7132252788090768
# f_2 = 1.2184395152660625
# |gradf_2| = 0.030552508084265347
# f_3 = 1.2183371871178765
# |gradf_3| = 0.0004030834931058715
# f_4 = 1.218337168533492
# |gradf_4| = 7.838995236890924e-06
# f_5 = 1.2183371685290856
# |gradf_5| = 5.2367074847690885e-08
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+1.1538140819539436e+04	3.35052669e+02
#     2	+5.8291155222362795e+03	1.09311583e+04
#     3	+2.4070498135846751e+03	7.94755409e+03
#     4	+1.9383016101436333e+03	6.76352146e+03
#     5	+8.2917125424860558e+02	1.22213109e+03
#     6	+7.9599463564639552e+02	5.29404144e+01
#     7	+7.9593268905341267e+02	2.32854656e+00
#     8	+7.9593256897570313e+02	1.75490851e-02
#     9	+7.9593256896892035e+02	1.30790125e-03
#    10	+7.9593256896888852e+02	5.21493262e-04
#    11	+7.9593256896888317e+02	1.67545777e-04
#    12	+7.9593256896888261e+02	1.24527188e-05
#    13	+7.9593256896888261e+02	5.19568409e-05
# Terminated - min stepsize reached after 13 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +9.520723e+03   |grad|: 9.843232e+03
# acc TR+   k:     1     num_inner:     0     f: +5.380906e+03   |grad|: 1.123893e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +8.009681e+02   |grad|: 4.768946e+02   exceeded trust region
# acc       k:     3     num_inner:     0     f: +7.959326e+02   |grad|: 3.825062e-02   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +7.959326e+02   |grad|: 1.636527e-09   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+6.1280368709275290e+03	1.14401934e+04
#     1	+8.9777082101920911e+01	5.76160746e+02
#     2	+8.4365674753229854e+01	2.83397739e+02
#     3	+8.3056921611922604e+01	1.39248994e+02
#     4	+8.2740990404899733e+01	6.83954247e+01
#     5	+8.2664775521098534e+01	3.35891167e+01
#     6	+8.2646394360228840e+01	1.64946344e+01
#     7	+8.2641961780218722e+01	8.09979901e+00
#     8	+8.2640892928388610e+01	3.97740522e+00
#     9	+8.2640635196801412e+01	1.95309139e+00
#    10	+8.2640573050885877e+01	9.59055846e-01
#    11	+8.2640558065946138e+01	4.70938878e-01
#    12	+8.2640554452711427e+01	2.31251659e-01
#    13	+8.2640553581473554e+01	1.13554672e-01
#    14	+8.2640553371397260e+01	5.57602966e-02
#    15	+8.2640553320742896e+01	2.73807351e-02
#    16	+8.2640553308528922e+01	1.34451333e-02
#    17	+8.2640553305583794e+01	6.60214585e-03
#    18	+8.2640553304873720e+01	3.24194102e-03
#    19	+8.2640553304702479e+01	1.59193416e-03
#    20	+8.2640553304661182e+01	7.81708969e-04
#    21	+8.2640553304651206e+01	3.83853130e-04
#    22	+8.2640553304648819e+01	1.88488595e-04
#    23	+8.2640553304648250e+01	9.25561044e-05
#    24	+8.2640553304648108e+01	4.54490760e-05
#    25	+8.2640553304648051e+01	8.14126583e-07
# Terminated - min grad norm reached after 26 iterations, 0.02 seconds.
#
# v_steepest = [-0.99650413 -0.08354346]
#
# v_trust = [-0.99650413 -0.08354346]
#
# v_cg = [0.99869962 0.05098097]
#
# Optimizing...
#                                             f: +8.330810e+03   |grad|: 1.027419e+04
# acc TR+   k:     1     num_inner:     0     f: +4.156938e+03   |grad|: 1.098425e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +9.286574e+01   |grad|: 6.901647e+02   exceeded trust region
# acc       k:     3     num_inner:     0     f: +8.264055e+01   |grad|: 1.113670e-01   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +8.264055e+01   |grad|: 1.263929e-08   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
#
#  New perturbation : [12.26160168  6.19991521]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.035266284626380706
#
# NextGrad = 0.6124320126652038
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.03725783836448304
#
# NextGrad = 0.6292211543872699
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.0399966970693284
#
# NextGrad = 0.6515635958556903
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.04379628368447608
#
# NextGrad = 0.6812727956403779
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.0491236161540094
#
# NextGrad = 0.7207318574675474
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.056687250511916254
#
# NextGrad = 0.7730489032716313
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.06758066122854922
#
# NextGrad = 0.8422277251266893
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.08351556014558459
#
# NextGrad = 0.9333183165294262
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.10719593441966735
#
# NextGrad = 1.0524550036075162
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.14289542497451047
#
# NextGrad = 1.2065683449395603
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 8, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.5045358934327062
# |gradf_0| = 1.0526843113313893
# f_1 = 1.483766686651888
# |gradf_1| = 1.1303211453715112
# f_2 = 1.3972986719257174
# |gradf_2| = 0.0252926127163498
# f_3 = 1.3972269647495534
# |gradf_3| = 0.0010430981945372957
# f_4 = 1.3972268534437462
# |gradf_4| = 1.9060329136188997e-05
# f_5 = 1.397226853421359
# |gradf_5| = 9.366942096507225e-07
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+8.7192615121098515e+03	1.20388890e+04
#     2	+4.1239201311353463e+02	4.54762251e+03
#     3	+2.7093449745775320e+01	1.17750653e+03
#     4	+1.7472644274850289e+01	9.41617228e+02
#     5	+6.5435002229128458e-01	1.18754530e+02
#     6	+6.2131337892527982e-01	1.11281914e+02
#     7	+5.0748918128969822e-01	8.04228707e+01
#     8	+4.6866003875597828e-01	6.67086649e+01
#     9	+3.8378952863017179e-01	6.19586590e+00
#    10	+3.8351844365149901e-01	4.92927329e+00
#    11	+3.8306293529869917e-01	7.87910447e-01
#    12	+3.8305143164208721e-01	1.51164058e-01
#    13	+3.8305116957085811e-01	9.60640207e-02
#    14	+3.8305103228286075e-01	4.57401532e-02
#    15	+3.8305101206343689e-01	3.22671701e-02
#    16	+3.8305099203474235e-01	3.04372224e-04
#    17	+3.8305099203320514e-01	1.13158175e-04
#    18	+3.8305099203303733e-01	6.33720403e-05
#    19	+3.8305099203296056e-01	5.44898113e-06
#    20	+3.8305099203295961e-01	5.99395707e-06
# Terminated - min stepsize reached after 20 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.318474e+04   |grad|: 2.173180e+03
# acc TR+   k:     1     num_inner:     0     f: +1.072275e+04   |grad|: 1.037973e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +2.578840e+03   |grad|: 1.041529e+04   negative curvature
# acc       k:     3     num_inner:     0     f: +1.760141e+02   |grad|: 2.998316e+03   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +4.232884e-01   |grad|: 4.573359e+01   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +3.830510e-01   |grad|: 7.941236e-04   maximum inner iterations
# acc       k:     6     num_inner:     0     f: +3.830510e-01   |grad|: 4.700809e-13   maximum inner iterations
# Terminated - min grad norm reached after 6 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+2.3575696546548083e+03	1.00602467e+04
#     1	+4.8460850084098877e+02	4.93064013e+03
#     2	+6.8009547084705417e+01	1.87106737e+03
#     3	+8.9782850373909255e+00	6.68324784e+02
#     4	+1.4620644654695680e+00	2.36832523e+02
#     5	+5.1836084816987960e-01	8.38665018e+01
#     6	+4.0001980997822745e-01	2.96991873e+01
#     7	+3.8517915019994481e-01	1.05176445e+01
#     8	+3.8331790507991181e-01	3.72477967e+00
#     9	+3.8308446859737516e-01	1.31912460e+00
#    10	+3.8305519072323480e-01	4.67167034e-01
#    11	+3.8305151864097881e-01	1.65447026e-01
#    12	+3.8305105808121243e-01	5.85930202e-02
#    13	+3.8305100031686745e-01	2.07507050e-02
#    14	+3.8305099307194379e-01	7.34885782e-03
#    15	+3.8305099216327065e-01	2.60259650e-03
#    16	+3.8305099204930571e-01	9.21709023e-04
#    17	+3.8305099203501047e-01	3.26423065e-04
#    18	+3.8305099203321680e-01	1.15602663e-04
#    19	+3.8305099203299298e-01	4.09406596e-05
#    20	+3.8305099203296389e-01	1.44991262e-05
#    21	+3.8305099203295967e-01	5.13486271e-06
#    22	+3.8305099203295928e-01	1.81851067e-06
#    23	+3.8305099203295867e-01	1.23126786e-06
# Terminated - min stepsize reached after 24 iterations, 0.02 seconds.
#
# v_steepest = [0.99860356 0.05282932]
#
# v_trust = [0.99860356 0.05282932]
#
# v_cg = [0.99860356 0.05282932]
#
# Optimizing...
#                                             f: +2.164328e+02   |grad|: 3.319909e+03
# acc       k:     1     num_inner:     0     f: +4.573589e-01   |grad|: 6.214979e+01   maximum inner iterations
# acc       k:     2     num_inner:     0     f: +3.830510e-01   |grad|: 1.373207e-03   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +3.830510e-01   |grad|: 7.115058e-13   maximum inner iterations
# Terminated - min grad norm reached after 3 iterations, 0.01 seconds.
#
#
#  New perturbation : [9.52282338 7.27764909]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.03572264040028994
#
# NextGrad = 0.6843346304384681
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.03794974025001596
#
# NextGrad = 0.705068008313272
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.0410222575456789
#
# NextGrad = 0.7326639659234255
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.045301482317428476
#
# NextGrad = 0.7693671715386435
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.051329915850282015
#
# NextGrad = 0.8181303117857746
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.059937254796632145
#
# NextGrad = 0.8828096644451192
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.07241426876236257
#
# NextGrad = 0.9683824193501651
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.09079742046380868
#
# NextGrad = 1.0811441337954142
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.11832783648363976
#
# NextGrad = 1.2287757346806452
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.16016442224702354
#
# NextGrad = 1.4200208399383771
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 9, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.6408073276806265
# |gradf_0| = 1.2291487979347462
# f_1 = 1.5754175756665922
# |gradf_1| = 0.9640882291470856
# f_2 = 1.5226554545531783
# |gradf_2| = 0.060863471251302405
# f_3 = 1.5223482524127852
# |gradf_3| = 0.0033221861520819685
# f_4 = 1.5223475112230236
# |gradf_4| = 0.0002559360135529524
# f_5 = 1.5223475072292767
# |gradf_5| = 3.7524783394069446e-07
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+5.9334836133956378e+02	6.28747112e+03
#     2	+1.9114265875315894e+02	3.06948106e+03
#     3	+1.1838402733227838e+02	1.95904059e+03
#     4	+7.9356291973023360e+01	9.08180450e+02
#     5	+7.6048075768373053e+01	7.54225326e+02
#     6	+6.8772583098286773e+01	7.51298005e+01
#     7	+6.8722524147246475e+01	4.20462427e+01
#     8	+6.8699907398520196e+01	4.05307299e+00
#     9	+6.8699789336161317e+01	2.69898859e+00
#    10	+6.8699701392067496e+01	6.88524772e-01
#    11	+6.8699699146849355e+01	5.47900126e-01
#    12	+6.8699695367671893e+01	8.67841733e-02
#    13	+6.8699695274884860e+01	1.86004864e-02
#    14	+6.8699695270814104e+01	5.54375833e-03
#    15	+6.8699695270448814e+01	1.56430737e-03
#    16	+6.8699695270423504e+01	6.96150156e-04
#    17	+6.8699695270417237e+01	7.71881931e-06
#    18	+6.8699695270417237e+01	7.63154132e-06
# Terminated - min stepsize reached after 18 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +1.730931e+04   |grad|: 1.213030e+04
# acc TR+   k:     1     num_inner:     0     f: +1.116706e+04   |grad|: 1.915161e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +7.968229e+02   |grad|: 7.256898e+03   negative curvature
# acc       k:     3     num_inner:     0     f: +9.175030e+01   |grad|: 2.846348e+02   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +9.070346e+01   |grad|: 1.629782e-02   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +9.070346e+01   |grad|: 2.817704e-12   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+4.6899237522364956e+02	5.35756875e+03
#     1	+9.5613802462820757e+01	6.16396964e+02
#     2	+9.0749983310798214e+01	6.00035473e+01
#     3	+9.0703902880929547e+01	5.82696887e+00
#     4	+9.0703468323771332e+01	5.65843222e-01
#     5	+9.0703464225943463e+01	5.49476585e-02
#     6	+9.0703464187301478e+01	5.33583310e-03
#     7	+9.0703464186937097e+01	5.18149735e-04
#     8	+9.0703464186933630e+01	5.03162568e-05
#     9	+9.0703464186933587e+01	4.88608864e-06
#    10	+9.0703464186933587e+01	4.74476369e-07
# Terminated - min grad norm reached after 11 iterations, 0.01 seconds.
#
# v_steepest = [0.99942576 0.03388449]
#
# v_trust = [-0.99944484 -0.03331692]
#
# v_cg = [-0.99944484 -0.03331692]
#
# Optimizing...
#                                             f: +9.352231e+03   |grad|: 1.933680e+04
# acc TR+   k:     1     num_inner:     0     f: +2.884501e+03   |grad|: 1.360331e+04   exceeded trust region
# acc       k:     2     num_inner:     0     f: +1.830272e+02   |grad|: 2.666682e+03   maximum inner iterations
# ...
#
# NextObj = 0.05653964005501044
#
# NextGrad = 1.0170213300631212
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.06451170030822051
#
# NextGrad = 1.0853363549783335
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.07593791644431591
#
# NextGrad = 1.1759713099940898
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.0925736180301715
#
# NextGrad = 1.2959239205893331
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.11720203493764503
#
# NextGrad = 1.454061015581025
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.15427361781464644
#
# NextGrad = 1.6612301313848121
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.21090323914814735
#
# NextGrad = 1.9298377225661727
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 47, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.8269010021628345
# |gradf_0| = 1.6619218821309838
# f_1 = 1.7308106058491715
# |gradf_1| = 1.128481154235532
# f_2 = 1.6740131980232626
# |gradf_2| = 0.17434299907473036
# f_3 = 1.6724541086132485
# |gradf_3| = 0.010307741033426888
# f_4 = 1.6724492493958727
# |gradf_4| = 0.0006180280795630172
# f_5 = 1.6724492272091727
# |gradf_5| = 1.615526648714986e-05
# f_6 = 1.6724492271887184
# |gradf_6| = 6.182586982869836e-07
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+3.5901194805283107e+04	8.61569017e+03
#     2	+1.4088867052520241e+04	3.49778322e+04
#     3	+9.4300382165290848e+03	3.11388889e+04
#     4	+4.0749512139129138e+02	1.01508091e+03
#     5	+4.0071204924080939e+02	2.33613959e+02
#     6	+4.0033798090854020e+02	2.74839683e+01
#     7	+4.0033279838050333e+02	3.11425765e+00
#     8	+4.0033273370537717e+02	6.26946578e-01
#     9	+4.0033273160204232e+02	3.00718249e-01
#    10	+4.0033273125841941e+02	2.02461269e-01
#    11	+4.0033273098563546e+02	4.17380606e-02
#    12	+4.0033273097554445e+02	1.70339953e-02
#    13	+4.0033273097365492e+02	4.27498278e-03
#    14	+4.0033273097362161e+02	3.67441505e-03
#    15	+4.0033273097353572e+02	1.06571643e-03
#    16	+4.0033273097352884e+02	3.83780589e-04
#    17	+4.0033273097352833e+02	2.60873709e-04
#    18	+4.0033273097352787e+02	2.12871100e-05
#    19	+4.0033273097352782e+02	7.47652002e-05
#    20	+4.0033273097352782e+02	3.46266603e-05
# Terminated - min stepsize reached after 20 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +3.582398e+04   |grad|: 6.523689e+03
# acc TR+   k:     1     num_inner:     0     f: +2.886716e+04   |grad|: 2.891768e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +6.572157e+03   |grad|: 2.786316e+04   negative curvature
# acc       k:     3     num_inner:     0     f: +4.006096e+02   |grad|: 7.534003e+03   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +4.150507e+00   |grad|: 8.161251e+01   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +4.104468e+00   |grad|: 3.897703e-04   maximum inner iterations
# acc       k:     6     num_inner:     0     f: +4.104468e+00   |grad|: 4.958361e-14   maximum inner iterations
# Terminated - min grad norm reached after 6 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+7.7724120260134114e+03	2.97515835e+04
#     1	+1.5721517369599010e+01	1.29625164e+03
#     2	+5.8922577185442666e+00	5.08567690e+02
#     3	+4.3794260251860573e+00	1.99447811e+02
#     4	+4.1467527413480525e+00	7.82149558e+01
#     5	+4.1109704828746940e+00	3.06725743e+01
#     6	+4.1054676161278962e+00	1.20285090e+01
#     7	+4.1046213395017830e+00	4.71708824e+00
#     8	+4.1044911916986173e+00	1.84984985e+00
#     9	+4.1044711764109367e+00	7.25435946e-01
#    10	+4.1044680982803934e+00	2.84486530e-01
#    11	+4.1044676248977634e+00	1.11564073e-01
#    12	+4.1044675520967147e+00	4.37509033e-02
#    13	+4.1044675409007132e+00	1.71573294e-02
#    14	+4.1044675391788958e+00	6.72840854e-03
#    15	+4.1044675389140872e+00	2.63860887e-03
#    16	+4.1044675388733722e+00	1.03475536e-03
#    17	+4.1044675388671124e+00	4.05789075e-04
#    18	+4.1044675388661442e+00	1.59134013e-04
#    19	+4.1044675388660039e+00	6.24059045e-05
#    20	+4.1044675388659702e+00	2.44730638e-05
#    21	+4.1044675388659666e+00	9.59734271e-06
#    22	+4.1044675388659666e+00	9.59734271e-06
# Terminated - min stepsize reached after 23 iterations, 0.02 seconds.
#
# v_steepest = [0.99968906 0.02493566]
#
# v_trust = [-0.99957648 -0.02910076]
#
# v_cg = [-0.99957648 -0.02910076]
#
# Optimizing...
#                                             f: +6.711753e+03   |grad|: 2.738638e+04
# acc TR+   k:     1     num_inner:     0     f: +5.205310e+02   |grad|: 4.152175e+03   exceeded trust region
# acc       k:     2     num_inner:     0     f: +4.003339e+02   |grad|: 1.324050e+01   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +4.003327e+02   |grad|: 8.106890e-06   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +4.003327e+02   |grad|: 1.263213e-13   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
#
#  New perturbation : [14.3558255   6.08116458]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.058925030225883246
#
# NextGrad = 1.3009561667434577
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.06316275707957408
#
# NextGrad = 1.3464700878701543
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.06903901567961479
#
# NextGrad = 1.407061244607575
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.07727442867645795
#
# NextGrad = 1.4876711795609907
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.08896344898500019
#
# NextGrad = 1.5948081889906747
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.1057994880422688
#
# NextGrad = 1.736986981610986
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.13044734911661027
#
# NextGrad = 1.925224243447182
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.16715760347360398
#
# NextGrad = 2.173504784818383
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.22276489204453798
#
# NextGrad = 2.498985237340021
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.3082519742718062
#
# NextGrad = 2.921380426285849
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 48, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 2.055158191538175
# |gradf_0| = 2.5002643921966112
# f_1 = 1.944750428161069
# |gradf_1| = 1.865431213895918
# f_2 = 1.8350964292472633
# |gradf_2| = 0.2825711593762806
# f_3 = 1.8321384033725445
# |gradf_3| = 0.018745057014453743
# f_4 = 1.8321254340005015
# |gradf_4| = 0.0019033970267586325
# f_5 = 1.8321252665655394
# |gradf_5| = 1.586664424098881e-05
# f_6 = 1.8321252665527588
# |gradf_6| = 5.88082459512576e-07
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+1.2501271398863482e+04	5.88249803e+04
#     2	+2.1957064931435129e+03	1.76580388e+04
#     3	+1.4848266597683157e+03	7.90928393e+03
#     4	+1.3080535891062191e+03	4.25874228e+01
#     5	+1.3080484906072681e+03	2.33818402e+00
#     6	+1.3080484765062142e+03	6.82689024e-01
#     7	+1.3080484753451610e+03	2.32998878e-01
#     8	+1.3080484753150438e+03	2.08822888e-01
#     9	+1.3080484752240829e+03	1.06522848e-01
#    10	+1.3080484751977729e+03	4.48996818e-02
#    11	+1.3080484751922286e+03	7.05538259e-03
#    12	+1.3080484751920958e+03	1.65392025e-03
#    13	+1.3080484751920883e+03	1.25699802e-04
# Terminated - min stepsize reached after 13 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +5.588126e+04   |grad|: 8.562232e+04
# acc TR+   k:     1     num_inner:     0     f: +2.391577e+04   |grad|: 7.712395e+04   negative curvature
# acc       k:     2     num_inner:     0     f: +2.937915e+03   |grad|: 2.382788e+04   exceeded trust region
# acc       k:     3     num_inner:     0     f: +1.308603e+03   |grad|: 4.434769e+02   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.308048e+03   |grad|: 6.808269e-03   maximum inner iterations
# acc       k:     5     num_inner:     0     f: +1.308048e+03   |grad|: 1.204705e-12   maximum inner iterations
# Terminated - min grad norm reached after 5 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+4.7250384078929585e+02	1.27547164e+04
#     1	+2.2265333402640657e+01	1.65213792e+03
#     2	+1.4742811601713830e+01	2.06242852e+02
#     3	+1.4625595847928205e+01	2.57248150e+01
#     4	+1.4623772244020433e+01	3.20855267e+00
#     5	+1.4623743875014576e+01	4.00188383e-01
#     6	+1.4623743433693468e+01	4.99136798e-02
#     7	+1.4623743426828085e+01	6.22550628e-03
#     8	+1.4623743426721285e+01	7.76479079e-04
#     9	+1.4623743426719610e+01	9.68467023e-05
#    10	+1.4623743426719605e+01	7.56548395e-05
#    11	+1.4623743426719594e+01	4.25454619e-05
#    12	+1.4623743426719592e+01	4.13817442e-05
# Terminated - min stepsize reached after 13 iterations, 0.01 seconds.
#
# v_steepest = [0.99978932 0.02052588]
#
# v_trust = [0.99978932 0.02052588]
#
# v_cg = [-0.99967921 -0.02532736]
#
# Optimizing...
#                                             f: +2.749351e+04   |grad|: 8.069573e+04
# acc TR+   k:     1     num_inner:     0     f: +4.837088e+03   |grad|: 3.464733e+04   exceeded trust region
# acc       k:     2     num_inner:     0     f: +1.314669e+03   |grad|: 1.532249e+03   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +1.308048e+03   |grad|: 6.678692e-02   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.308048e+03   |grad|: 9.156919e-11   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
#
#  New perturbation : [21.45414992  7.98663259]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.09428404718220618
#
# NextGrad = 2.3502728545624736
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.10197165938859554
#
# NextGrad = 2.4434556763769626
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.11268555663719182
#
# NextGrad = 2.5675263686702148
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.12779278368803082
#
# NextGrad = 2.7326236978326572
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.14939085836846377
#
# NextGrad = 2.9521131426205365
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.18075846440497356
#
# NextGrad = 3.2435023852768965
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.2271060256170485
#
# NextGrad = 3.6294830165704126
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.2968214640880462
#
# NextGrad = 4.1389320477800755
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.4035064730119644
#
# NextGrad = 4.807408984996102
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.5691872032201251
#
# NextGrad = 5.676029799611598
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 49, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 2.446773682520734
# |gradf_0| = 4.810272133353974
# f_1 = 2.227325753665376
# |gradf_1| = 3.3015103301942528
# f_2 = 2.0554200216550895
# |gradf_2| = 0.8300066557377592
# f_3 = 2.0428623171415143
# |gradf_3| = 0.06921615325010387
# f_4 = 2.0427540498636594
# |gradf_4| = 0.011129391760213611
# f_5 = 2.042750522690049
# |gradf_5| = 7.011914367325282e-05
# f_6 = 2.0427505225154787
# |gradf_6| = 7.190272832164886e-06
# f_7 = 2.0427505225142975
# |gradf_7| = 2.7851280607741258e-08
# Compiling cost function...
# Computing gradient of cost function...
#  iter		   cost val	    grad. norm
#     1	+1.4083182899710216e+05	3.97186115e+05
#     2	+1.8919906481279337e+04	1.53040243e+05
#     3	+4.7270445187085779e+03	1.05392646e+04
#     4	+4.6935154591344181e+03	7.35200337e+03
#     5	+4.6618303377146976e+03	4.04389074e+02
#     6	+4.6617421354953667e+03	1.16209001e+02
#     7	+4.6617353953077063e+03	4.51658751e+01
#     8	+4.6617343927110551e+03	1.82923431e+01
#     9	+4.6617342107724080e+03	5.01448500e+00
#    10	+4.6617342002744927e+03	2.69978633e+00
#    11	+4.6617341962060236e+03	6.07181298e-01
#    12	+4.6617341959957776e+03	1.05144897e-01
#    13	+4.6617341959892801e+03	1.14108345e-03
#    14	+4.6617341959892792e+03	1.22347761e-03
#    15	+4.6617341959892792e+03	1.30535692e-03
# Terminated - min stepsize reached after 15 iterations, 0.01 seconds.
#
# Computing Hessian of cost function...
# Optimizing...
#                                             f: +8.560438e+04   |grad|: 3.341129e+05
# acc TR+   k:     1     num_inner:     0     f: +7.185471e+03   |grad|: 6.533267e+04   exceeded trust region
# acc       k:     2     num_inner:     0     f: +4.661819e+03   |grad|: 3.795067e+02   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +4.661734e+03   |grad|: 5.325213e-04   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +4.661734e+03   |grad|: 7.854593e-12   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
# Optimizing...
#  iter		   cost val	    grad. norm
#     0	+2.0373104745368319e+05	4.28514390e+05
#     1	+3.6733267710336135e+04	2.39746480e+05
#     2	+2.7386563742617227e+02	2.09884382e+04
#     3	+1.6157490984253819e+01	5.82133842e+01
#     4	+1.6155509496976574e+01	1.30302633e-01
#     5	+1.6155509487048779e+01	2.91687485e-04
#     6	+1.6155509487048690e+01	6.52955338e-07
# Terminated - min grad norm reached after 7 iterations, 0.00 seconds.
#
# v_steepest = [0.99985243 0.01717877]
#
# v_trust = [0.99985243 0.01717877]
#
# v_cg = [-0.9997846  -0.02075465]
#
# Optimizing...
#                                             f: +1.098380e+05   |grad|: 3.732837e+05
# acc TR+   k:     1     num_inner:     0     f: +1.053380e+04   |grad|: 1.324231e+05   exceeded trust region
# acc       k:     2     num_inner:     0     f: +2.322315e+01   |grad|: 3.476665e+03   maximum inner iterations
# acc       k:     3     num_inner:     0     f: +1.615551e+01   |grad|: 1.960398e-02   maximum inner iterations
# acc       k:     4     num_inner:     0     f: +1.615551e+01   |grad|: 3.148218e-12   maximum inner iterations
# Terminated - min grad norm reached after 4 iterations, 0.01 seconds.
#
#
#  New perturbation : [-41.79305137 -17.90455271]
#
# ----- Step Size Selection-----
#
# Initial stepSize = 1
#
# NextObj = 0.166131513951701
#
# NextGrad = 1.5819316627279323
#
#
# Potential new step size = 0.13333333333333333
#
# NextObj = 0.1712857220149171
#
# NextGrad = 1.6054457450673116
#
#
# Potential new step size = 0.17777777777777778
#
# NextObj = 0.17827386175078397
#
# NextGrad = 1.63668965117402
#
#
# Potential new step size = 0.23703703703703705
#
# NextObj = 0.18779594038052672
#
# NextGrad = 1.6781501712098124
#
#
# Potential new step size = 0.3160493827160494
#
# NextObj = 0.20085220293179695
#
# NextGrad = 1.7330655846266698
#
#
# Potential new step size = 0.4213991769547325
#
# NextObj = 0.2188920953766995
#
# NextGrad = 1.8056059276395087
#
#
# Potential new step size = 0.5618655692729767
#
# NextObj = 0.24404597731171118
#
# NextGrad = 1.9010459444344223
#
#
# Potential new step size = 0.7491540923639689
#
# NextObj = 0.2794849522606748
#
# NextGrad = 2.025860536137056
#
#
# Potential new step size = 0.9988721231519585
#
# NextObj = 0.32997002124588715
#
# NextGrad = 2.187580837525619
#
#
# Potential new step size = 1.3318294975359446
#
# NextObj = 0.40265210734624857
#
# NextGrad = 2.3940657253815885
#
#  --> Maximum step size exceeded.
#
#  --> End of continuation exceeded
#
# Next step size = 1
#
#
# ----- Step 50, L = 1 -----
#
# Compiling cost function...
# Computing gradient of cost function...
# f_0 = 1.9348125049954543
# |gradf_0| = 2.1882633062864563
# f_1 = 1.8115900280116575
# |gradf_1| = 1.9620105935252046
# f_2 = 1.6110353231929828
# |gradf_2| = 0.2831895341519754
# f_3 = 1.604878261498334
# |gradf_3| = 0.05941507914062547
# f_4 = 1.6046138443614473
# |gradf_4| = 0.011370692752360474
# f_5 = 1.6046063910280808
# |gradf_5| = 0.00031593854768411907
# f_6 = 1.604606385672868
# |gradf_6| = 4.5291950478020836e-06
# f_7 = 1.6046063856713986
# |gradf_7| = 1.7623002826860142e-08

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

parameters = [p for (a,(x,p)) in results]

x = [x for (x,y) in parameters]
y = [y for (x,y) in parameters]

fig = plt.figure()
ax = fig.add_subplot(111, autoscale_on=True, xlim=(-30, 45), ylim=(-30, 55))
ax.grid()

line, = ax.plot([], [], 'o', lw=2)
time_template = 'iteration = %.1i'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)

#Other stuff
ax.grid()

def init():
    line.set_data([], [])
    time_text.set_text('')
    return line, time_text


def animate(i):
    thisx = [x[i], targetParameter[0]]
    thisy = [y[i], targetParameter[1]]

    line.set_data(thisx, thisy)
    #line.set_colors(['b', 'r'])
    time_text.set_text(time_template % (i))
    return line, time_text

ani = animation.FuncAnimation(fig, animate, np.arange(1, len(y)),
                              interval=500, blit=True, init_func=init)
# Out:
# <img src="data:image/png;base64,..." width="639.1129136709624">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-026b3a0004ac> in <module>
#      35     return line, time_text
#      36
# ---> 37 ani = animation.FuncAnimation(fig, animate, np.arange(1, len(y)),
#      38                               interval=500, blit=True, init_func=init)
#
# NameError: name 'animation' is not defined

# %%
parameters
# Out:
# [array([1, 2]),
#  array([4.99659948, 7.74434195]),
#  array([ 8.75425391, 12.48967602]),
#  array([ 3.14781857, 10.78401514]),
#  array([ 7.44616221, 15.42977037]),
#  array([ 1.75974265, 13.47155354]),
#  array([-4.02461213, 10.40453176]),
#  array([-10.16010899,   5.03538152]),
#  array([-3.26413703, 14.04078289]),
#  array([-9.45629038,  9.45007826]),
#  array([-15.75027365,   1.00125032]),
#  array([-17.79173729, -13.707107  ]),
#  array([-15.17975597,   1.00745527]),
#  array([-8.30370523, 13.7842336 ]),
#  array([-14.98439477,   6.92996974]),
#  array([-20.10464949,  -6.05345993]),
#  array([-15.82841859,  10.31990783]),
#  array([-6.80909092, 21.17096698]),
#  array([-13.46465216,  15.98580754]),
#  array([-20.80571764,   6.60136159]),
#  array([-23.95271212, -11.00836406]),
#  array([-21.86170145,   6.66566332]),
#  array([-12.9682802 ,  23.04002543]),
#  array([-20.61708486,  15.44020489]),
#  array([-9.46400677, 27.95585102]),
#  array([-1.62122735, 32.17810127]),
#  array([-7.70233716, 28.45874857]),
#  array([-0.31236306, 32.31051598]),
#  array([-6.36510714, 28.75814991]),
#  array([-12.85548613,  24.13723464]),
#  array([-3.96201133, 29.91507914]),
#  array([ 2.72361864, 33.17367596]),
#  array([-3.40375081, 29.87604603]),
#  array([-9.58522823, 25.91345165]),
#  array([-16.60796616,  20.14910088]),
#  array([-6.38321841, 28.49811933]),
#  array([-12.88068788,  23.86544831]),
#  array([-20.51795242,  16.44600493]),
#  array([-28.16822866,   1.79576713]),
#  array([-22.39815174,  23.67252511]),
#  array([-9.64368239, 34.3659135 ]),
#  array([-16.44247483,  29.05202864]),
#  array([-24.78682014,  20.68325343]),
#  array([-11.43546751,  34.4949511 ]),
#  array([-18.52587215,  28.68671272]),
#  array([-7.40313409, 35.51727282]),
#  array([-13.87449434,  30.73871673]),
#  array([-4.62889473, 35.46499923]),
#  array([-10.85408963,  31.19682531]),
#  array([-17.9580405 ,  25.39198922]),
#  array([-26.62514316,  15.40343042])]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

(solutions, parameters) = [(x, p) for (a,(x,p)) in results]

x = [x for (x,y) in parameters]
y = [y for (x,y) in parameters]

fig = plt.figure()
ax = fig.add_subplot(111, autoscale_on=True, xlim=(-30, 45), ylim=(-30, 55))
ax.grid()

line, = ax.plot([], [], 'o', lw=2)
time_template = 'iteration = %.1i'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)


ax = plt.axes(projection='3d')

# draw sphere
u, v = np.mgrid[0 : 2* np.pi : 100j, 0 : np.pi : 100j]
x = np.cos(u) * np.sin(v)
y = np.sin(u) * np.sin(v)
z = np.cos(v)

ax.plot_wireframe(x, y, z, color="r")

ax.scatter([1/np.sqrt(2)], [-1/np.sqrt(2)], [0.0], marker='o', color='b')

def init():
    line.set_data([], [])
    time_text.set_text('')
    return line, time_text


def animate(i):
    thisx = [x[i], targetParameter[0]]
    thisy = [y[i], targetParameter[1]]

    line.set_data(thisx, thisy)
    #line.set_colors(['b', 'r'])
    time_text.set_text(time_template % (i))
    return line, time_text

ani = animation.FuncAnimation(fig, animate, np.arange(1, len(y)),
                              interval=500, blit=True, init_func=init)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-bf90510ae00a> in <module>
#       3 import matplotlib.animation as animation
#       4
# ----> 5 (solutions, parameters) = [(x, p) for (a,(x,p)) in results]
#       6
#       7 x = [x for (x,y) in parameters]
#
# ValueError: too many values to unpack (expected 2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.animation as animation


class SubplotAnimation(animation.TimedAnimation):
    def __init__(self):
        parameters = [p for (a,(x,p)) in results]
        solutions = [x for (a,(x,p)) in results]

        self.data = [np.reshape(solution, (1, 3)) for solution in solutions]

        self.xParameters = [x for (x,y) in parameters]
        self.yParameters = [y for (x,y) in parameters]

        fig = plt.figure()
        ax1 = fig.add_subplot(1, 2, 1, projection="3d")
        ax2 = fig.add_subplot(1, 2, 2)

        ax1.set_xlabel('x')
        ax1.set_ylabel('y')
        ax1.set_zlabel('z')

        ax1.set_xlim(-1.2, 1.2)
        ax1.set_ylim(-1.2, 1.2)
        ax1.set_zlim(-1.2, 1.2)

        ax2.set_xlabel('x')
        ax2.set_ylabel('y')
        ax2.set_xlim(-40, 50)
        ax2.set_ylim(-40, 50)

        # draw sphere
        u, v = np.mgrid[0 : 2* np.pi : 15j, 0 : np.pi : 15j]
        x = np.cos(u) * np.sin(v)
        y = np.sin(u) * np.sin(v)
        z = np.cos(v)

        ax1.plot_wireframe(x, y, z, color="y")
        
        ax1.scatter(finalSolution[0], finalSolution[1], finalSolution[2])
        
        ax1.view_init(5, 225)
        
        self.scatters = [ ax1.scatter(data[0][i,0:1], data[0][i,1:2], data[0][i,2:], 'o-') for i in range(data[0].shape[0]) ]
        
        self.line, = ax2.plot([], [], 'o', lw=2)
        self.time_template = 'iteration = %.1i'
        self.time_text = ax2.text(0.05, 0.9, '', transform=ax.transAxes)


        animation.TimedAnimation.__init__(self, fig, interval=800, blit=True)

    def _draw_frame(self, framedata):
                
        for i in range(data[0].shape[0]):
            self.scatters[i]._offsets3d = (self.data[framedata][i,0:1], self.data[framedata][i,1:2], self.data[framedata][i,2:])

        thisx = [self.xParameters[framedata], targetParameter[0]]
        thisy = [self.yParameters[framedata], targetParameter[1]]

        self.line.set_data(thisx, thisy)
        
        
        self.time_text.set_text(self.time_template % (framedata))        

    def new_frame_seq(self):
        return iter(range(len(self.xParameters)))

    def _init_draw(self):
        self.line.set_data([], [])
        self.time_text.set_text('')

ani = SubplotAnimation()
# ani.save('test_sub.mp4')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fdc8abb96715> in <module>
#      73         self.time_text.set_text('')
#      74
# ---> 75 ani = SubplotAnimation()
#      76 # ani.save('test_sub.mp4')
#      77 plt.show()
#
# <ipython-input-2-fdc8abb96715> in __init__(self)
#       7 class SubplotAnimation(animation.TimedAnimation):
#       8     def __init__(self):
# ----> 9         parameters = [p for (a,(x,p)) in results]
#      10         solutions = [x for (a,(x,p)) in results]
#      11
#
# NameError: name 'results' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation

def animate_scatters(iteration, data, scatters):
    """
    Update the data held by the scatter plot and therefore animates it.
    Args:
        iteration (int): Current iteration of the animation
        data (list): List of the data positions at each iteration.
        scatters (list): List of all the scatters (One per element)
    Returns:
        list: List of scatters (One per element) with new coordinates
    """
    for i in range(data[0].shape[0]):
        scatters[i]._offsets3d = (data[iteration][i,0:1], data[iteration][i,1:2], data[iteration][i,2:])
    return scatters


"""
Creates the 3D figure and animates it with the input data.
Args:
    data (list): List of the data positions at each iteration.
    save (bool): Whether to save the recording of the animation. (Default to False).
"""

solutions = [x for (a,(x,p)) in results]
data = [np.reshape(solution, (1, 3)) for solution in solutions]

# Attaching 3D axis to the figure
fig = plt.figure()
ax = p3.Axes3D(fig)

# draw sphere
u, v = np.mgrid[0 : 2* np.pi : 15j, 0 : np.pi : 15j]
x = np.cos(u) * np.sin(v)
y = np.sin(u) * np.sin(v)
z = np.cos(v)

ax.plot_wireframe(x, y, z, color="y")

ax.scatter(finalSolution[0], finalSolution[1], finalSolution[2])
# Initialize scatters
scatters = [ ax.scatter(data[0][i,0:1], data[0][i,1:2], data[0][i,2:], 'o-') for i in range(data[0].shape[0]) ]

# Number of iterations
iterations = len(data)

# Setting the axes properties
ax.set_xlim3d([-1.5, 1.5])
ax.set_xlabel('X')

ax.set_ylim3d([-1.5, 1.5])
ax.set_ylabel('Y')

ax.set_zlim3d([-1.5, 1.5])
ax.set_zlabel('Z')

ax.set_title('3D Animated Scatter Example')

# Provide starting angle for the view.
ax.view_init(5, 225)

ani = animation.FuncAnimation(fig, animate_scatters, iterations, fargs=(data, scatters),
                                   interval=500, blit=False, repeat=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.1129136709624">
